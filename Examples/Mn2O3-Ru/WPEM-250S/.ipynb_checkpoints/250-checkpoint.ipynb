# %% [markdown]
# ## 1: background intensity

# %%
import sys
import pandas as pd
Yourdir = '/Users/CaoBin/Documents/WpenPattern'
sys.path.append(Yourdir)
import WpenPattern.BacDeduct as BacDeduct

# %%
TF = BacDeduct.TwiceFilter()
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
Var = TF.FFTandSGFilter(intensity_csv,lowAngleRange=22,poly_n=8,bac_split=8,bac_num=1000 )
Var
# Out:
# 242.17469498502933

# %% [markdown]
# ## 2: cal HKL list

# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/WpenPattern'
sys.path.append(Yourdir)

import WpenPattern.InitialHKL as xrd

# %%
xrd.profile(wavelength='CuKa2').generate('Mn2O3.cif',two_theta_range=(15, 80))
# Out:
# cif file parse complete...
# xrd pattern calculate compelete...
# result saved at: output_xrd/Mn2O3.csv

# %% [markdown]
# ## 3: Wpen fitting

# %%
structure_factor =   [
    [['Mn' , 0.25, 0.25 ,0.25 ],
 ['Mn', 0.0217, 0., 0.25],
['Mn' , 0.54214 ,0. ,0.25 ,],
[ 'O-2' , 0.125 ,0.125, 0.375 ],
['O-2' ,0.125, 0.375 ,0.375] ]
,
[[ 'Ru', 0., 0., 0., ],
['O-2', 0.30531, 0.30531, 0.]]
,
[['Ru' , 0.25, 0.25 ,0.25 ],
 ['Ru', 0.0217, 0., 0.25],
['Ru' , 0.54214 ,0. ,0.25 ,],
[ 'O-2' , 0.125 ,0.125, 0.375 ],
['O-2' ,0.125, 0.375 ,0.375] ]
]

# %%
if __name__ == "__main__":

    import WpenPattern.WPEMModel as WPEMModel


    # The wavelength is set according to the actual light source
    wavelength = [1.540593, 1.544414]
    
    # Enter the file name to read on the right side of the equal sign. 
    # Please remember to quote, string.
    
    # The file name of non-background data (2theta-intensity data)
    no_bac_intensity_file = "no_bac_intensity.csv" 
    # The file name of raw/original data (2theta-intensity data)
    original_file = "intensity.csv"  
    # The file name of background data (2theta-intensity data)
    bacground_file = "bac.csv"  


    # Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.
    Lattice_constants = [[9.411, 9.411, 9.411, 90, 90, 90],[4.49682,4.49682,3.10491,90,90,90],[9.420, 9.420, 9.420, 90, 90, 90]]

    # Execute the model
    WPEMModel.Built().fit(
        wavelength, Var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
        subset_number=11,low_bound=30,up_bound=60,bta = 0.85,structure_factor = structure_factor,iter_max = 200,Macromolecule = True, EXACT=True,LogPrint = True, asy_C = 0,cpu=6
        )
# Out:
# Started at Mon Nov 21 16:54:04 2022
# WPEM package : Whole Pattern fitting of powder X-ray diffraction by Expectation Maximum
# WPEM V2.0.0, March 2, 2022, MGI, SHU, Shanghai, CHINA.
# Reference paper : Doi
# ------------------------------------------------------------------
# Diffraction indexs have been obtained by WPEM
# Diffraction indexs have been obtained by WPEM
# Diffraction indexs have been obtained by WPEM
# The input crystal system is: Cubic The initial inputs : 9.411 9.411 9.411 90 90 90
# The input crystal system is: Tetragonal The initial inputs : 4.49682 4.49682 3.10491 90 90 90
# The input crystal system is: Cubic The initial inputs : 9.42 9.42 9.42 90 90 90
# 1-th iterations
# [[9.41034243890612, 9.41034243890612, 9.41034243890612, 90, 90, 90], [4.49668369876472, 4.49668369876472, 3.1048642872382346, 90, 90, 90], [9.419939711347451, 9.419939711347451, 9.419939711347451, 90, 90, 90]]
# Rp:4.741    Rwp:6.530    Raquare:7.276
# 2-th iterations
# [[9.409792261600122, 9.409792261600122, 9.409792261600122, 90, 90, 90], [4.496617676964137, 4.496617676964137, 3.1047060102197297, 90, 90, 90], [9.4194035435123, 9.4194035435123, 9.4194035435123, 90, 90, 90]]
# Rp:4.323    Rwp:5.730    Raquare:4.389
# 3-th iterations
# [[9.409528921361547, 9.409528921361547, 9.409528921361547, 90, 90, 90], [4.496618014894783, 4.496618014894783, 3.1045293031183268, 90, 90, 90], [9.418613786573333, 9.418613786573333, 9.418613786573333, 90, 90, 90]]
# Rp:4.231    Rwp:5.597    Raquare:3.979
# 4-th iterations
# [[9.409238817373064, 9.409238817373064, 9.409238817373064, 90, 90, 90], [4.4966455909364855, 4.4966455909364855, 3.1043617957335155, 90, 90, 90], [9.418509195519182, 9.418509195519182, 9.418509195519182, 90, 90, 90]]
# Rp:4.196    Rwp:5.545    Raquare:3.840
# 5-th iterations
# [[9.409008171630221, 9.409008171630221, 9.409008171630221, 90, 90, 90], [4.496686202546505, 4.496686202546505, 3.1042084735859325, 90, 90, 90], [9.418424502688051, 9.418424502688051, 9.418424502688051, 90, 90, 90]]
# Rp:4.170    Rwp:5.508    Raquare:3.760
# 6-th iterations
# [[9.408810955506087, 9.408810955506087, 9.408810955506087, 90, 90, 90], [4.496734022197711, 4.496734022197711, 3.1040705435826643, 90, 90, 90], [9.418372036313555, 9.418372036313555, 9.418372036313555, 90, 90, 90]]
# Rp:4.150    Rwp:5.478    Raquare:3.704
# 7-th iterations
# [[9.40806242774804, 9.40806242774804, 9.40806242774804, 90, 90, 90], [4.496785451937654, 4.496785451937654, 3.10395446890797, 90, 90, 90], [9.417925705125421, 9.417925705125421, 9.417925705125421, 90, 90, 90]]
# Rp:4.129    Rwp:5.440    Raquare:3.610
# 8-th iterations
# [[9.407414983979809, 9.407414983979809, 9.407414983979809, 90, 90, 90], [4.496836230447984, 4.496836230447984, 3.1038633559066846, 90, 90, 90], [9.417811710340112, 9.417811710340112, 9.417811710340112, 90, 90, 90]]
# Rp:4.108    Rwp:5.412    Raquare:3.542
# 9-th iterations
# [[9.406815749393795, 9.406815749393795, 9.406815749393795, 90, 90, 90], [4.496882772711925, 4.496882772711925, 3.10380258963758, 90, 90, 90], [9.41756126523723, 9.41756126523723, 9.41756126523723, 90, 90, 90]]
# Rp:4.093    Rwp:5.392    Raquare:3.496
# 10-th iterations
# [[9.406235464679492, 9.406235464679492, 9.406235464679492, 90, 90, 90], [4.496922855358439, 4.496922855358439, 3.103770884648267, 90, 90, 90], [9.417365035045748, 9.417365035045748, 9.417365035045748, 90, 90, 90]]
# Rp:4.079    Rwp:5.376    Raquare:3.459
# 11-th iterations
# [[9.406627790839513, 9.406627790839513, 9.406627790839513, 90, 90, 90], [4.496955332335786, 4.496955332335786, 3.103766905617803, 90, 90, 90], [9.417185709651365, 9.417185709651365, 9.417185709651365, 90, 90, 90]]
# Rp:4.077    Rwp:5.372    Raquare:3.468
# 12-th iterations
# [[9.406978827893438, 9.406978827893438, 9.406978827893438, 90, 90, 90], [4.4969789667646305, 4.4969789667646305, 3.1037947899803546, 90, 90, 90], [9.4170661999415, 9.4170661999415, 9.4170661999415, 90, 90, 90]]
# Rp:4.077    Rwp:5.372    Raquare:3.477
# 13-th iterations
# [[9.407293169360575, 9.407293169360575, 9.407293169360575, 90, 90, 90], [4.4969933136288684, 4.4969933136288684, 3.1038542541255514, 90, 90, 90], [9.416979974783171, 9.416979974783171, 9.416979974783171, 90, 90, 90]]
# Rp:4.079    Rwp:5.372    Raquare:3.484
# 14-th iterations
# [[9.407574938302199, 9.407574938302199, 9.407574938302199, 90, 90, 90], [4.496998179452861, 4.496998179452861, 3.1039454563761284, 90, 90, 90], [9.416910337657221, 9.416910337657221, 9.416910337657221, 90, 90, 90]]
# Rp:4.080    Rwp:5.372    Raquare:3.489
# 15-th iterations
# [[9.40782809719165, 9.40782809719165, 9.40782809719165, 90, 90, 90], [4.496993610445084, 4.496993610445084, 3.1040686817143204, 90, 90, 90], [9.416855034305879, 9.416855034305879, 9.416855034305879, 90, 90, 90]]
# Rp:4.080    Rwp:5.372    Raquare:3.491
# 16-th iterations
# [[9.408055909179732, 9.408055909179732, 9.408055909179732, 90, 90, 90], [4.4969798174282305, 4.4969798174282305, 3.1042242626090393, 90, 90, 90], [9.416809142841647, 9.416809142841647, 9.416809142841647, 90, 90, 90]]
# Rp:4.079    Rwp:5.371    Raquare:3.490
# 17-th iterations
# [[9.408261258346645, 9.408261258346645, 9.408261258346645, 90, 90, 90], [4.496957068760311, 4.496957068760311, 3.1044126894401676, 90, 90, 90], [9.416767615368522, 9.416767615368522, 9.416767615368522, 90, 90, 90]]
# Rp:4.078    Rwp:5.370    Raquare:3.488
# 18-th iterations
# [[9.408447293740489, 9.408447293740489, 9.408447293740489, 90, 90, 90], [4.496925503931759, 4.496925503931759, 3.1046352167625013, 90, 90, 90], [9.416728158572319, 9.416728158572319, 9.416728158572319, 90, 90, 90]]
# Rp:4.077    Rwp:5.368    Raquare:3.484
# 19-th iterations
# [[9.408616948438434, 9.408616948438434, 9.408616948438434, 90, 90, 90], [4.496884381862206, 4.496884381862206, 3.1048973507664877, 90, 90, 90], [9.416748958974582, 9.416748958974582, 9.416748958974582, 90, 90, 90]]
# Rp:4.074    Rwp:5.366    Raquare:3.477
# 20-th iterations
# [[9.408770991830096, 9.408770991830096, 9.408770991830096, 90, 90, 90], [4.496833142420414, 4.496833142420414, 3.1052034209718102, 90, 90, 90], [9.416763770327785, 9.416763770327785, 9.416763770327785, 90, 90, 90]]
# Rp:4.071    Rwp:5.363    Raquare:3.470
# 21-th iterations
# [[9.40891228901618, 9.40891228901618, 9.40891228901618, 90, 90, 90], [4.49677223716182, 4.49677223716182, 3.1055525105497983, 90, 90, 90], [9.416773449743955, 9.416773449743955, 9.416773449743955, 90, 90, 90]]
# Rp:4.068    Rwp:5.360    Raquare:3.463
# 22-th iterations
# [[9.409042878031592, 9.409042878031592, 9.409042878031592, 90, 90, 90], [4.496702936208258, 4.496702936208258, 3.10593966085481, 90, 90, 90], [9.416779109143942, 9.416779109143942, 9.416779109143942, 90, 90, 90]]
# Rp:4.065    Rwp:5.358    Raquare:3.456
# 23-th iterations
# [[9.409165169982197, 9.409165169982197, 9.409165169982197, 90, 90, 90], [4.496625165020586, 4.496625165020586, 3.1063589171604815, 90, 90, 90], [9.416781634197788, 9.416781634197788, 9.416781634197788, 90, 90, 90]]
# Rp:4.063    Rwp:5.355    Raquare:3.449
# 24-th iterations
# [[9.409279306356023, 9.409279306356023, 9.409279306356023, 90, 90, 90], [4.496541928456931, 4.496541928456931, 3.1068043048743292, 90, 90, 90], [9.416781673363865, 9.416781673363865, 9.416781673363865, 90, 90, 90]]
# Rp:4.061    Rwp:5.353    Raquare:3.442
# 25-th iterations
# [[9.409387305738194, 9.409387305738194, 9.409387305738194, 90, 90, 90], [4.496453575923077, 4.496453575923077, 3.107270737469566, 90, 90, 90], [9.41677974497691, 9.41677974497691, 9.41677974497691, 90, 90, 90]]
# Rp:4.058    Rwp:5.350    Raquare:3.435
# 26-th iterations
# [[9.409490285271765, 9.409490285271765, 9.409490285271765, 90, 90, 90], [4.496361481584846, 4.496361481584846, 3.107753364775474, 90, 90, 90], [9.416776185716408, 9.416776185716408, 9.416776185716408, 90, 90, 90]]
# Rp:4.056    Rwp:5.348    Raquare:3.428
# 27-th iterations
# [[9.409589210514202, 9.409589210514202, 9.409589210514202, 90, 90, 90], [4.496266981734799, 4.496266981734799, 3.1082479267183687, 90, 90, 90], [9.416771225724974, 9.416771225724974, 9.416771225724974, 90, 90, 90]]
# Rp:4.053    Rwp:5.345    Raquare:3.422
# 28-th iterations
# [[9.409686516585918, 9.409686516585918, 9.409686516585918, 90, 90, 90], [4.496162883536246, 4.496162883536246, 3.1087367114940188, 90, 90, 90], [9.416764636007638, 9.416764636007638, 9.416764636007638, 90, 90, 90]]
# Rp:4.051    Rwp:5.343    Raquare:3.416
# 29-th iterations
# [[9.40978240143124, 9.40978240143124, 9.40978240143124, 90, 90, 90], [4.4960484708645705, 4.4960484708645705, 3.1092113418923977, 90, 90, 90], [9.416756602055985, 9.416756602055985, 9.416756602055985, 90, 90, 90]]
# Rp:4.049    Rwp:5.341    Raquare:3.410
# 30-th iterations
# [[9.409876858467124, 9.409876858467124, 9.409876858467124, 90, 90, 90], [4.4959268359737745, 4.4959268359737745, 3.109671492785399, 90, 90, 90], [9.416712375416521, 9.416712375416521, 9.416712375416521, 90, 90, 90]]
# Rp:4.047    Rwp:5.339    Raquare:3.405
# 31-th iterations
# [[9.409971986232032, 9.409971986232032, 9.409971986232032, 90, 90, 90], [4.495800037653943, 4.495800037653943, 3.1101144684647655, 90, 90, 90], [9.416687891723255, 9.416687891723255, 9.416687891723255, 90, 90, 90]]
# Rp:4.046    Rwp:5.338    Raquare:3.400
# 32-th iterations
# [[9.410066347611568, 9.410066347611568, 9.410066347611568, 90, 90, 90], [4.495669096821491, 4.495669096821491, 3.110538438197376, 90, 90, 90], [9.416675976806477, 9.416675976806477, 9.416675976806477, 90, 90, 90]]
# Rp:4.044    Rwp:5.336    Raquare:3.395
# 33-th iterations
# [[9.410159305469417, 9.410159305469417, 9.410159305469417, 90, 90, 90], [4.495534595332047, 4.495534595332047, 3.1109422569236624, 90, 90, 90], [9.416673613423516, 9.416673613423516, 9.416673613423516, 90, 90, 90]]
# Rp:4.042    Rwp:5.334    Raquare:3.390
# 34-th iterations
# [[9.410250604058344, 9.410250604058344, 9.410250604058344, 90, 90, 90], [4.495396802455429, 4.495396802455429, 3.11132599583275, 90, 90, 90], [9.41667866715083, 9.41667866715083, 9.41667866715083, 90, 90, 90]]
# Rp:4.041    Rwp:5.333    Raquare:3.385
# After update the background intensity :    Rp:2.287    Rwp:4.552    Rsquare:2.410
# volume fraction (based on structure factor) in % : [81.80394464447261, 1.1305061728957597, 17.065549182631628]
#  Saved at the result documents
# 34-th iterations, reach the limit of ϵ.
#  Rp: 2.287
# Rwp: 4.552
# WPEM program running time :  0 hours 22 minute  10 second

# %% [markdown]
# # amorphous

# %%
import WpenPattern.MeasureFunctionGaussianMixture as MGMM
MGMM.Amorphous_fit(mix_component = 1, ang_range=(18,45), sigma2_coef = 100, max_iter = 200)
# Out:
# Convergence get at 3 iterations!
# W_list: [41066.68373338]
# mu_list: [30.01918889]
# sigma2_list: [36.71721391]
# interatomic distances : 2.976746
# Rp =  19.775800263322566

# %% [markdown]
# # decompose

# %%
import WpenPattern.Decomposedpeaks as DP
wavelength = [1.540593, 1.544414]
DP.Decomposedpeaks().decomposition_peak(lowboundary=15, upboundary=80,wavelength = wavelength, name = ['Mn2O3','RuO2','Ru2O3'],Macromolecule = True,phase=3)
# Out:
# Name assigned successfully
# volume fraction estimate in % (calculated by integral area): [50.232444355505, 5.18101842211138, 44.58653722238362]
#  Saved at the WPEMFittingResults
# Relative bulk crystallinity % (calculated by integral area): 91.79737540496217
#  Saved at the WPEMFittingResults

# %% [markdown]
# # simulation

# %%
import WpenPattern.Simulation as Simulation
import numpy as np

# %%
data = pd.read_csv('result2.csv')
peak = pd.read_csv('peak2.csv')
mu_list = data['mu_i'].tolist()
gamma_list = data['gamma_i'].tolist()
sigma2_list = data['sigma_i'].tolist()
Mult = peak['Mult'].tolist()
HKL_list = np.array(peak[['H','K','L']]).tolist()
LatticCs= [9.39288540711103, 9.39288540711103, 9.39288540711103, 90, 90, 90]

# %%
 k = [['Mn' , 0.25, 0.25 ,0.25 ],
 ['Mn', 0.0217, 0., 0.25],
['Mn' , 0.54214 ,0. ,0.25 ,],
[ 'O-2' , 0.125 ,0.125, 0.375 ],
['O-2' ,0.125, 0.375 ,0.375] ]

# %%
xrd = Simulation.XRD_profile(k , mu_list,gamma_list, sigma2_list,Mult, HKL_list,   LatticCs,)

# %%
F1 = xrd.Simulate(two_theta_range=(15, 80,0.025))
# Out:
# The simulation process has done

# %%
data = pd.read_csv('result0.csv')
peak = pd.read_csv('peak2.csv')
mu_list = data['mu_i'].tolist()
gamma_list = data['gamma_i'].tolist()
sigma2_list = data['sigma_i'].tolist()
Mult = peak['Mult'].tolist()
HKL_list = np.array(peak[['H','K','L']]).tolist()
LatticCs= [9.39288540711103, 9.39288540711103, 9.39288540711103, 90, 90, 90]

# %%
 k = [['Ru' , 0.25, 0.25 ,0.25 ],
 ['Ru', 0.0217, 0., 0.25],
['Ru' , 0.54214 ,0. ,0.25 ,],
[ 'O-2' , 0.125 ,0.125, 0.375 ],
['O-2' ,0.125, 0.375 ,0.375] ]

# %%
xrd = Simulation.XRD_profile(k , mu_list,gamma_list, sigma2_list,Mult, HKL_list, 
                                LatticCs,)

# %%
F2 = xrd.Simulate(two_theta_range=(15, 80,0.025))
# Out:
# The simulation process has done
