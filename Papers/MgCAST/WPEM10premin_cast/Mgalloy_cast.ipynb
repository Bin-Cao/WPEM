# %% [markdown]
# ## 1: background intensity

# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2024-01-13 15:40:54  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
Var = WPEM.BackgroundFit(intensity_csv, LFctg=0.2,bac_split=14, lowAngleRange=15,window_length = 7, bac_num=700)
Var
# Out:
# 23.987808383589552

# %% [markdown]
# ## 2: Wpen fitting

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]
# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.

Lattice_constants = [ [3.45058, 3.45058, 3.45058, 90.0, 90.0, 90.0,'fixed'],
                     [3.51631, 3.51631, 3.51631, 90.0, 90.0, 90.0,'fixed'],
                     [ 7.8631,  7.8631,  7.8631, 90.0, 90.0, 90.0,'fixed'],
                    [7.89886, 7.89886, 7.89886, 90.0, 90.0, 90.0,'fixed'],
                    [6.32643, 6.32643, 6.32643, 90.0, 90.0, 90.0,'fixed']]

# Execute the model
WPEM.XRDfit(
    wavelength, Var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=9 ,low_bound=30,up_bound=90,bta = 0.92,iter_max = 80, asy_C = 0, Ave_Waves=True,
    InitializationEpoch=3,)
# Out:
# Started at Sat Jan 13 15:41:01 2024
#
# The lattice constants of input system 0 are fixed
# viz., fixed : [3.45058, 3.45058, 3.45058, 90.0, 90.0, 90.0]
# The lattice constants of input system 1 are fixed
# viz., fixed : [3.51631, 3.51631, 3.51631, 90.0, 90.0, 90.0]
# The lattice constants of input system 2 are fixed
# viz., fixed : [7.8631, 7.8631, 7.8631, 90.0, 90.0, 90.0]
# The lattice constants of input system 3 are fixed
# viz., fixed : [7.89886, 7.89886, 7.89886, 90.0, 90.0, 90.0]
# The lattice constants of input system 4 are fixed
# viz., fixed : [6.32643, 6.32643, 6.32643, 90.0, 90.0, 90.0]
# Initialization
# --------------------------------------------------------------------------------
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Cubic  |  The initial lattice constants : 3.45058 3.45058 3.45058 90.0 90.0 90.0
# The input crystal system is: Cubic  |  The initial lattice constants : 3.51631 3.51631 3.51631 90.0 90.0 90.0
# The input crystal system is: Cubic  |  The initial lattice constants : 7.8631 7.8631 7.8631 90.0 90.0 90.0
# The input crystal system is: Cubic  |  The initial lattice constants : 7.89886 7.89886 7.89886 90.0 90.0 90.0
# The input crystal system is: Cubic  |  The initial lattice constants : 6.32643 6.32643 6.32643 90.0 90.0 90.0
# —————————— Initilize the parameters by WPEM ——————————
# Parameter initialization has been completed
#   0%|                                                    | 0/80 [00:00<?, ?it/s]
# WPEM 1-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#   1%|▌                                           | 1/80 [00:04<05:33,  4.23s/it]
# Rp:19.675 | Rwp:38.590 | Rsquare:26.048
# WPEM 2-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#   2%|█                                           | 2/80 [00:08<05:13,  4.02s/it]
# Rp:16.855 | Rwp:31.812 | Rsquare:20.729
# WPEM 3-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#   4%|█▋                                          | 3/80 [00:11<05:02,  3.93s/it]
# Rp:13.147 | Rwp:22.833 | Rsquare:9.650
# WPEM 4-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#   5%|██▏                                         | 4/80 [00:15<04:55,  3.89s/it]
# Rp:12.484 | Rwp:20.900 | Rsquare:9.198
# WPEM 5-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#   6%|██▊                                         | 5/80 [00:19<04:50,  3.88s/it]
# Rp:12.077 | Rwp:19.920 | Rsquare:8.846
# WPEM 6-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#   8%|███▎                                        | 6/80 [00:23<04:45,  3.86s/it]
# Rp:11.778 | Rwp:19.283 | Rsquare:8.531
# WPEM 7-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#   9%|███▊                                        | 7/80 [00:27<04:41,  3.85s/it]
# Rp:11.548 | Rwp:18.820 | Rsquare:8.282
# WPEM 8-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  10%|████▍                                       | 8/80 [00:31<04:36,  3.84s/it]
# Rp:11.366 | Rwp:18.467 | Rsquare:8.096
# WPEM 9-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  11%|████▉                                       | 9/80 [00:34<04:32,  3.84s/it]
# Rp:11.212 | Rwp:18.191 | Rsquare:7.955
# WPEM 10-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  12%|█████▍                                     | 10/80 [00:38<04:29,  3.85s/it]
# Rp:11.081 | Rwp:17.972 | Rsquare:7.845
# WPEM 11-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  14%|█████▉                                     | 11/80 [00:42<04:25,  3.84s/it]
# Rp:10.964 | Rwp:17.791 | Rsquare:7.752
# WPEM 12-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  15%|██████▍                                    | 12/80 [00:46<04:21,  3.84s/it]
# Rp:10.865 | Rwp:17.637 | Rsquare:7.670
# WPEM 13-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  16%|██████▉                                    | 13/80 [00:50<04:17,  3.84s/it]
# Rp:10.780 | Rwp:17.503 | Rsquare:7.595
# WPEM 14-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  18%|███████▌                                   | 14/80 [00:54<04:13,  3.85s/it]
# Rp:10.703 | Rwp:17.382 | Rsquare:7.523
# WPEM 15-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  19%|████████                                   | 15/80 [00:58<04:10,  3.86s/it]
# Rp:10.639 | Rwp:17.273 | Rsquare:7.455
# WPEM 16-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  20%|████████▌                                  | 16/80 [01:01<04:06,  3.86s/it]
# Rp:10.581 | Rwp:17.173 | Rsquare:7.389
# WPEM 17-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  21%|█████████▏                                 | 17/80 [01:05<04:03,  3.86s/it]
# Rp:10.530 | Rwp:17.082 | Rsquare:7.324
# WPEM 18-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  22%|█████████▋                                 | 18/80 [01:09<03:59,  3.86s/it]
# Rp:10.486 | Rwp:16.997 | Rsquare:7.262
# WPEM 19-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  24%|██████████▏                                | 19/80 [01:13<03:55,  3.86s/it]
# Rp:10.448 | Rwp:16.920 | Rsquare:7.202
# WPEM 20-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  25%|██████████▊                                | 20/80 [01:17<03:52,  3.87s/it]
# Rp:10.413 | Rwp:16.848 | Rsquare:7.144
# WPEM 21-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  26%|███████████▎                               | 21/80 [01:21<03:48,  3.87s/it]
# Rp:10.383 | Rwp:16.782 | Rsquare:7.089
# WPEM 22-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  28%|███████████▊                               | 22/80 [01:25<03:44,  3.87s/it]
# Rp:10.356 | Rwp:16.721 | Rsquare:7.035
# WPEM 23-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  29%|████████████▎                              | 23/80 [01:28<03:40,  3.86s/it]
# Rp:10.331 | Rwp:16.664 | Rsquare:6.984
# WPEM 24-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  30%|████████████▉                              | 24/80 [01:32<03:36,  3.86s/it]
# Rp:10.308 | Rwp:16.612 | Rsquare:6.936
# WPEM 25-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  31%|█████████████▍                             | 25/80 [01:36<03:32,  3.87s/it]
# Rp:10.286 | Rwp:16.563 | Rsquare:6.890
# WPEM 26-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  32%|█████████████▉                             | 26/80 [01:40<03:28,  3.87s/it]
# Rp:10.267 | Rwp:16.518 | Rsquare:6.846
# WPEM 27-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  34%|██████████████▌                            | 27/80 [01:44<03:25,  3.87s/it]
# Rp:10.249 | Rwp:16.477 | Rsquare:6.804
# WPEM 28-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  35%|███████████████                            | 28/80 [01:48<03:21,  3.87s/it]
# Rp:10.232 | Rwp:16.438 | Rsquare:6.765
# WPEM 29-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  36%|███████████████▌                           | 29/80 [01:52<03:17,  3.87s/it]
# Rp:10.216 | Rwp:16.402 | Rsquare:6.728
# WPEM 30-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  38%|████████████████▏                          | 30/80 [01:56<03:13,  3.87s/it]
# Rp:10.202 | Rwp:16.369 | Rsquare:6.693
# WPEM 31-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  39%|████████████████▋                          | 31/80 [02:00<03:11,  3.91s/it]
# Rp:10.188 | Rwp:16.338 | Rsquare:6.661
# WPEM 32-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  40%|█████████████████▏                         | 32/80 [02:03<03:06,  3.89s/it]
# Rp:10.175 | Rwp:16.309 | Rsquare:6.630
# WPEM 33-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  41%|█████████████████▋                         | 33/80 [02:07<03:02,  3.88s/it]
# Rp:10.164 | Rwp:16.282 | Rsquare:6.601
# WPEM 34-th iteration
# [array([ 3.45058,  3.45058,  3.45058, 90.     , 90.     , 90.     ]), array([ 3.51631,  3.51631,  3.51631, 90.     , 90.     , 90.     ]), array([ 7.8631,  7.8631,  7.8631, 90.    , 90.    , 90.    ]), array([ 7.89886,  7.89886,  7.89886, 90.     , 90.     , 90.     ]), array([ 6.32643,  6.32643,  6.32643, 90.     , 90.     , 90.     ])]
#  41%|█████████████████▋                         | 33/80 [02:11<03:07,  3.99s/it]
# Rp:10.153 | Rwp:16.257 | Rsquare:6.573
# After update the background :   Rp = 8.874 | Rwp = 15.848 | Rsquare = 6.528
# Mass fraction without structure factor estimate in % : [0.5781290972949618, 84.65452997129606, 6.535086810913902, 6.892069511602187, 1.3401846088928813]
#  Saved at the result documents
# 34-th iterations, reach the limit of ϵ.
#  Rp: 8.874
# Rwp: 15.848
#
#
# WPEM program running time :  0 hours 2 minute  17 second
# '0 hours 2 minute  17 second  '

# %%
name = ['Li','Mg','YAl2','GdAl2','LiAl']
wavelength = [1.540593*2/3+ 1.544414*1/3]
WPEM.Plot_Components(lowboundary=10, upboundary=100,name = name, wavelength = wavelength,phase=5,)
# Out:
# Name assigned successfully
# Mass fraction estimate in % (calculated by integral area): [0.7399444801637397, 75.63014769400439, 9.078348064705356, 10.46578491646308, 4.085774844663435]
#  Saved at the DecomposedComponents document
