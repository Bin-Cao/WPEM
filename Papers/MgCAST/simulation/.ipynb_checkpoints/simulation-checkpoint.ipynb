# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2024-01-13 19:28:10  | Have a great day.
# ...

# %%
_,_,_ = WPEM.XRDSimulation(filepath='Li.cif',two_theta_range=(10, 125, 0.01),GrainSize=3,thermo_vib=0.2,)
# Out:
# the space group of input crystal is : P 1
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 6 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Cubic  |  The initial lattice constants : 3.43931245 3.43931245 3.43931245 90.0 90.0 90.0
#
#
# WPEM simulates the peaks as the default Voigt functions
# Initilized with default peak's shape
# The nearest neighbor atoms are : ['Li', 'Li', 2.9785]
# XRD simulation process of WPEM is completed !

# %%
_,_,_ = WPEM.XRDSimulation(filepath='Mg.cif',two_theta_range=(10, 125, 0.01),GrainSize=3,thermo_vib=0.2,)
# Out:
# the space group of input crystal is : P 1
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 6 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Cubic  |  The initial lattice constants : 3.54552899 3.54552899 3.54552899 90.0 90.0 90.0
#
#
# WPEM simulates the peaks as the default Voigt functions
# Initilized with default peak's shape
# The nearest neighbor atoms are : ['Mg', 'Mg', 3.0705]
# XRD simulation process of WPEM is completed !

# %%
_,_,_ = WPEM.XRDSimulation(filepath='LiAl.cif',two_theta_range=(10, 125, 0.01),GrainSize=3,thermo_vib=0.2,)
# Out:
# the space group of input crystal is : P 1
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 32 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Cubic  |  The initial lattice constants : 6.32678542 6.32678542 6.32678542 90.0 90.0 90.0
#
#
# WPEM simulates the peaks as the default Voigt functions
# Initilized with default peak's shape
# The nearest neighbor atoms are : ['Li', 'Li', 2.7396]
# XRD simulation process of WPEM is completed !

# %%
_,_,_ = WPEM.XRDSimulation(filepath='GdAl2.cif',two_theta_range=(10, 125, 0.01),GrainSize=3,thermo_vib=0.2,)
# Out:
# the space group of input crystal is : P 1
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 47 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Cubic  |  The initial lattice constants : 7.88438782 7.88438782 7.88438782 90.0 90.0 90.0
#
#
# WPEM simulates the peaks as the default Voigt functions
# Initilized with default peak's shape
# The nearest neighbor atoms are : ['Al', 'Al', 2.7876]
# XRD simulation process of WPEM is completed !

# %%
_,_,_ = WPEM.XRDSimulation(filepath='YAl2.cif',two_theta_range=(10, 125, 0.01),GrainSize=3,thermo_vib=0.2,)
# Out:
# the space group of input crystal is : P 1
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 46 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Cubic  |  The initial lattice constants : 7.84887349 7.84887349 7.84887349 90.0 90.0 90.0
#
#
# WPEM simulates the peaks as the default Voigt functions
# Initilized with default peak's shape
# The nearest neighbor atoms are : ['Al', 'Al', 2.775]
# XRD simulation process of WPEM is completed !
