# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2023-11-11 17:59:56  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,lowAngleRange=25,poly_n=11,bac_split=10,bac_num=300)
var
# Out:
# 22.286813533846363

# %%
latt1, AtomCoordinates = WPEM.CIFpreprocess(filepath='Li2MnO3.cif',two_theta_range=(10, 80),show_unitcell=True,cal_extinction=True)
# Out:
# the space group of input crystal is : C2/m
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 68 extinction peaks
# Diffraction condition judgment end !
# interactive(children=(IntSlider(value=30, description='elevation', max=90, min=-90), IntSlider(value=60, descr…

# %%
latt2, AtomCoordinates = WPEM.CIFpreprocess(filepath='LiTMO2.cif',two_theta_range=(10, 80),show_unitcell=True,cal_extinction=False)
# Out:
# the space group of input crystal is : R -3 m :H
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 0 extinction peaks
# Diffraction condition judgment end !
# interactive(children=(IntSlider(value=30, description='elevation', max=90, min=-90), IntSlider(value=60, descr…

# %% [markdown]
# # WPEM fitting

# %%
latt1
# Out:
# [4.937, 8.532, 5.03, 90.0, 109.46, 90.0]

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]

# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.

Lattice_constants = [latt1,latt2]
# Execute the model


WPEM.XRDfit(
    wavelength, var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=5,low_bound=15,up_bound=50,bta = 0.90,iter_max = 200, asy_C = 0,InitializationEpoch=0
    )
# Out:
# Started at Sat Nov 11 21:21:05 2023
#
# Initialization
# --------------------------------------------------------------------------------
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Monoclinic  |  The initial lattice constants : 4.90398827 8.48049408 4.98416942 90.0 109.43865752 90.0
# The input crystal system is: Hexagonal  |  The initial lattice constants : 2.86 2.86 14.227 90.0 90.0 120.0
# —————————— Initilize the parameters by WPEM ——————————
# Parameter initialization has been completed
#
# WPEM 1-th iteration
# [array([  4.90364,   8.47985,   4.98419,  90.     , 109.43866,  90.     ]), array([  2.85986,   2.85986,  14.2245 ,  90.     ,  90.     , 120.     ])]
# Rp:13.718 | Rwp:19.623 | Rsquare:19.419
# WPEM 2-th iteration
# [array([  4.90328,   8.47886,   4.98428,  90.     , 109.43866,  90.     ]), array([  2.85955,   2.85955,  14.22425,  90.     ,  90.     , 120.     ])]
# Rp:12.078 | Rwp:17.422 | Rsquare:16.078
# WPEM 3-th iteration
# [array([  4.90316,   8.47824,   4.98448,  90.     , 109.43866,  90.     ]), array([  2.85926,   2.85926,  14.22399,  90.     ,  90.     , 120.     ])]
# Rp:10.990 | Rwp:15.895 | Rsquare:13.695
# WPEM 4-th iteration
# [array([  4.90315,   8.47842,   4.98477,  90.     , 109.43866,  90.     ]), array([  2.859  ,   2.859  ,  14.22386,  90.     ,  90.     , 120.     ])]
# Rp:10.288 | Rwp:14.858 | Rsquare:12.034

# %%
name = ['Li2MnO3','LiMnO2',]
wavelength = [1.540593*2/3+ 1.544414*1/3]
WPEM.Plot_Components(lowboundary=10, upboundary=110,name = name, wavelength = wavelength, phase=2)
# Out:
# Name assigned successfully
# volume fraction estimate in % (calculated by integral area): [22.15667905150157, 77.84332094849843]
#  Saved at the DecomposedComponents document
