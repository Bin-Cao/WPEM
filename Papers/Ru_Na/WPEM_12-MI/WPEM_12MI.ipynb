# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2023-12-10 13:24:00  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,lowAngleRange=17,poly_n=8,bac_split=16,bac_num=500)
var
# Out:
# 120.14693638499993

# %%
latt, AtomCoordinates,des = WPEM.CIFpreprocess(filepath='RuO2.cif',two_theta_range=(15,90),show_unitcell=True,)
# Out:
# the space group of input crystal is : P 42/m n m
# cif file parse completed
# atom locations claculated by wyckoff site
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 5 extinction peaks
# Diffraction condition judgment end !
# interactive(children=(IntSlider(value=30, description='elevation', max=90, min=-90), IntSlider(value=60, descr…

# %%
AtomCoordinates
# Out:
# [['Ru4+', 0.0, 0.0, 0.0],
#  ['O2-', 0.305, 0.305, 0.0],
#  ['Ru4+', 0.5, 0.5, 0.5],
#  ['O2-', 0.694, 0.694, 0.0],
#  ['O2-', 0.194, 0.805, 0.5],
#  ['O2-', 0.805, 0.194, 0.5]]

# %%
np.sqrt((0.305*4.4968)**2 *2)
# Out:
# 1.939627841920197

# %%
np.sqrt((4.4968)**2 *2 + 3.1049**2) / 2
# Out:
# 3.5384609821926825

# %%
latt
# Out:
# [4.4968, 4.4968, 3.1049, 90.0, 90.0, 90.0]

# %% [markdown]
# # WPEM fitting

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]

# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.

Lattice_constants = [[4.54227,  4.54227,  3.12752, 90.     , 90.     , 90.    ],]

# Execute the model

WPEM.XRDfit(
    wavelength, var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=5,low_bound=15,up_bound=60,bta = 0.9,iter_max = 50, asy_C = 0,InitializationEpoch=1, 
    )
# Out:
# Started at Fri Dec  8 18:55:04 2023
#
# Initialization
# --------------------------------------------------------------------------------
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Tetragonal  |  The initial lattice constants : 4.54227 4.54227 3.12752 90.0 90.0 90.0
# —————————— Initilize the parameters by WPEM ——————————
# Parameter initialization has been completed
#   0%|                                                    | 0/50 [00:00<?, ?it/s]
# WPEM 1-th iteration
# [array([ 4.54227,  4.54227,  3.12752, 90.     , 90.     , 90.     ])]
#   2%|▉                                           | 1/50 [00:03<02:49,  3.46s/it]
# Rp:17.797 | Rwp:22.488 | Rsquare:6.211
# WPEM 2-th iteration
# [array([ 4.54259,  4.54259,  3.12814, 90.     , 90.     , 90.     ])]
#   4%|█▊                                          | 2/50 [00:07<02:56,  3.67s/it]
# Rp:16.012 | Rwp:20.013 | Rsquare:5.443
# WPEM 3-th iteration
# [array([ 4.54277,  4.54277,  3.12837, 90.     , 90.     , 90.     ])]
#   6%|██▋                                         | 3/50 [00:10<02:53,  3.68s/it]
# Rp:15.101 | Rwp:18.786 | Rsquare:4.819
# WPEM 4-th iteration
# [array([ 4.54328,  4.54328,  3.12856, 90.     , 90.     , 90.     ])]
#   8%|███▌                                        | 4/50 [00:14<02:51,  3.73s/it]
# Rp:14.517 | Rwp:18.046 | Rsquare:4.357
# WPEM 5-th iteration
# [array([ 4.54378,  4.54378,  3.12868, 90.     , 90.     , 90.     ])]
#  10%|████▍                                       | 5/50 [00:18<02:48,  3.75s/it]
# Rp:14.098 | Rwp:17.532 | Rsquare:3.998
# WPEM 6-th iteration
# [array([ 4.54425,  4.54425,  3.12876, 90.     , 90.     , 90.     ])]
#  12%|█████▎                                      | 6/50 [00:22<02:45,  3.76s/it]
# Rp:13.783 | Rwp:17.155 | Rsquare:3.726
# WPEM 7-th iteration
# [array([ 4.54469,  4.54469,  3.12881, 90.     , 90.     , 90.     ])]
#  14%|██████▏                                     | 7/50 [00:26<02:42,  3.77s/it]
# Rp:13.529 | Rwp:16.867 | Rsquare:3.520
# WPEM 8-th iteration
# [array([ 4.54509,  4.54509,  3.12883, 90.     , 90.     , 90.     ])]
#  16%|███████                                     | 8/50 [00:29<02:38,  3.78s/it]
# Rp:13.323 | Rwp:16.640 | Rsquare:3.362
# WPEM 9-th iteration
# [array([ 4.54546,  4.54546,  3.12883, 90.     , 90.     , 90.     ])]
#  18%|███████▉                                    | 9/50 [00:33<02:35,  3.79s/it]
# Rp:13.147 | Rwp:16.454 | Rsquare:3.238
# WPEM 10-th iteration
# [array([ 4.54578,  4.54578,  3.12881, 90.     , 90.     , 90.     ])]
#  20%|████████▌                                  | 10/50 [00:37<02:31,  3.80s/it]
# Rp:12.992 | Rwp:16.297 | Rsquare:3.139
# WPEM 11-th iteration
# [array([ 4.54606,  4.54606,  3.12879, 90.     , 90.     , 90.     ])]
#  22%|█████████▍                                 | 11/50 [00:41<02:28,  3.80s/it]
# Rp:12.854 | Rwp:16.159 | Rsquare:3.057
# WPEM 12-th iteration
# [array([ 4.5463 ,  4.5463 ,  3.12876, 90.     , 90.     , 90.     ])]
#  24%|██████████▎                                | 12/50 [00:45<02:24,  3.79s/it]
# Rp:12.729 | Rwp:16.035 | Rsquare:2.989
# WPEM 13-th iteration
# [array([ 4.54652,  4.54652,  3.12873, 90.     , 90.     , 90.     ])]
#  26%|███████████▏                               | 13/50 [00:48<02:19,  3.78s/it]
# Rp:12.615 | Rwp:15.921 | Rsquare:2.929
# WPEM 14-th iteration
# [array([ 4.5467 ,  4.5467 ,  3.12869, 90.     , 90.     , 90.     ])]
#  28%|████████████                               | 14/50 [00:52<02:15,  3.77s/it]
# Rp:12.509 | Rwp:15.815 | Rsquare:2.878
# WPEM 15-th iteration
# [array([ 4.54686,  4.54686,  3.12865, 90.     , 90.     , 90.     ])]
#  30%|████████████▉                              | 15/50 [00:56<02:11,  3.77s/it]
# Rp:12.409 | Rwp:15.714 | Rsquare:2.831
# WPEM 16-th iteration
# [array([ 4.547  ,  4.547  ,  3.12861, 90.     , 90.     , 90.     ])]
#  32%|█████████████▊                             | 16/50 [01:00<02:08,  3.78s/it]
# Rp:12.317 | Rwp:15.618 | Rsquare:2.789
# WPEM 17-th iteration
# [array([ 4.54712,  4.54712,  3.12856, 90.     , 90.     , 90.     ])]
#  34%|██████████████▌                            | 17/50 [01:04<02:05,  3.80s/it]
# Rp:12.230 | Rwp:15.526 | Rsquare:2.750
# WPEM 18-th iteration
# [array([ 4.54723,  4.54723,  3.12852, 90.     , 90.     , 90.     ])]
#  36%|███████████████▍                           | 18/50 [01:07<02:01,  3.78s/it]
# Rp:12.145 | Rwp:15.436 | Rsquare:2.713
# WPEM 19-th iteration
# [array([ 4.54732,  4.54732,  3.12848, 90.     , 90.     , 90.     ])]
#  38%|████████████████▎                          | 19/50 [01:11<01:57,  3.78s/it]
# Rp:12.064 | Rwp:15.349 | Rsquare:2.677
# WPEM 20-th iteration
# [array([ 4.5474 ,  4.5474 ,  3.12844, 90.     , 90.     , 90.     ])]
#  40%|█████████████████▏                         | 20/50 [01:15<01:53,  3.78s/it]
# Rp:11.984 | Rwp:15.264 | Rsquare:2.643
# WPEM 21-th iteration
# [array([ 4.54747,  4.54747,  3.1284 , 90.     , 90.     , 90.     ])]
#  42%|██████████████████                         | 21/50 [01:19<01:49,  3.77s/it]
# Rp:11.906 | Rwp:15.180 | Rsquare:2.609
# WPEM 22-th iteration
# [array([ 4.54752,  4.54752,  3.12837, 90.     , 90.     , 90.     ])]
#  44%|██████████████████▉                        | 22/50 [01:22<01:45,  3.76s/it]
# Rp:11.830 | Rwp:15.097 | Rsquare:2.576
# WPEM 23-th iteration
# [array([ 4.54757,  4.54757,  3.12833, 90.     , 90.     , 90.     ])]
#  46%|███████████████████▊                       | 23/50 [01:26<01:41,  3.76s/it]
# Rp:11.755 | Rwp:15.014 | Rsquare:2.542
# WPEM 24-th iteration
# [array([ 4.54762,  4.54762,  3.1283 , 90.     , 90.     , 90.     ])]
#  48%|████████████████████▋                      | 24/50 [01:30<01:37,  3.75s/it]
# Rp:11.680 | Rwp:14.931 | Rsquare:2.509
# WPEM 25-th iteration
# [array([ 4.54766,  4.54766,  3.12826, 90.     , 90.     , 90.     ])]
#  50%|█████████████████████▌                     | 25/50 [01:34<01:34,  3.77s/it]
# Rp:11.605 | Rwp:14.849 | Rsquare:2.476
# WPEM 26-th iteration
# [array([ 4.54769,  4.54769,  3.12823, 90.     , 90.     , 90.     ])]
#  52%|██████████████████████▎                    | 26/50 [01:37<01:30,  3.77s/it]
# Rp:11.532 | Rwp:14.766 | Rsquare:2.443
# WPEM 27-th iteration
# [array([ 4.54771,  4.54771,  3.1282 , 90.     , 90.     , 90.     ])]
#  54%|███████████████████████▏                   | 27/50 [01:41<01:26,  3.78s/it]
# Rp:11.458 | Rwp:14.684 | Rsquare:2.410
# WPEM 28-th iteration
# [array([ 4.54774,  4.54774,  3.12817, 90.     , 90.     , 90.     ])]
#  56%|████████████████████████                   | 28/50 [01:45<01:23,  3.78s/it]
# Rp:11.384 | Rwp:14.601 | Rsquare:2.376
# WPEM 29-th iteration
# [array([ 4.54775,  4.54775,  3.12814, 90.     , 90.     , 90.     ])]
#  58%|████████████████████████▉                  | 29/50 [01:49<01:19,  3.77s/it]
# Rp:11.310 | Rwp:14.518 | Rsquare:2.343
# WPEM 30-th iteration
# [array([ 4.54777,  4.54777,  3.12811, 90.     , 90.     , 90.     ])]
#  60%|█████████████████████████▊                 | 30/50 [01:53<01:15,  3.78s/it]
# Rp:11.236 | Rwp:14.436 | Rsquare:2.310
# WPEM 31-th iteration
# [array([ 4.54778,  4.54778,  3.12809, 90.     , 90.     , 90.     ])]
#  62%|██████████████████████████▋                | 31/50 [01:56<01:11,  3.78s/it]
# Rp:11.162 | Rwp:14.354 | Rsquare:2.278
# WPEM 32-th iteration
# [array([ 4.5478 ,  4.5478 ,  3.12806, 90.     , 90.     , 90.     ])]
#  64%|███████████████████████████▌               | 32/50 [02:00<01:08,  3.79s/it]
# Rp:11.090 | Rwp:14.273 | Rsquare:2.246
# WPEM 33-th iteration
# [array([ 4.54781,  4.54781,  3.12804, 90.     , 90.     , 90.     ])]
#  66%|████████████████████████████▍              | 33/50 [02:04<01:04,  3.80s/it]
# Rp:11.019 | Rwp:14.193 | Rsquare:2.214
# WPEM 34-th iteration
# [array([ 4.54782,  4.54782,  3.12801, 90.     , 90.     , 90.     ])]
#  68%|█████████████████████████████▏             | 34/50 [02:08<01:00,  3.79s/it]
# Rp:10.950 | Rwp:14.114 | Rsquare:2.183
# WPEM 35-th iteration
# [array([ 4.54783,  4.54783,  3.12798, 90.     , 90.     , 90.     ])]
#  70%|██████████████████████████████             | 35/50 [02:11<00:56,  3.78s/it]
# Rp:10.881 | Rwp:14.036 | Rsquare:2.152
# WPEM 36-th iteration
# [array([ 4.54783,  4.54783,  3.12796, 90.     , 90.     , 90.     ])]
#  72%|██████████████████████████████▉            | 36/50 [02:15<00:52,  3.76s/it]
# Rp:10.814 | Rwp:13.959 | Rsquare:2.122
# WPEM 37-th iteration
# [array([ 4.54784,  4.54784,  3.12794, 90.     , 90.     , 90.     ])]
#  74%|███████████████████████████████▊           | 37/50 [02:19<00:48,  3.75s/it]
# Rp:10.747 | Rwp:13.884 | Rsquare:2.093
# WPEM 38-th iteration
# [array([ 4.54785,  4.54785,  3.12791, 90.     , 90.     , 90.     ])]
#  76%|████████████████████████████████▋          | 38/50 [02:23<00:45,  3.78s/it]
# Rp:10.682 | Rwp:13.810 | Rsquare:2.064
# WPEM 39-th iteration
# [array([ 4.54786,  4.54786,  3.12789, 90.     , 90.     , 90.     ])]
#  78%|█████████████████████████████████▌         | 39/50 [02:27<00:43,  3.98s/it]
# Rp:10.618 | Rwp:13.738 | Rsquare:2.037
# WPEM 40-th iteration
# [array([ 4.54787,  4.54787,  3.12786, 90.     , 90.     , 90.     ])]
#  80%|██████████████████████████████████▍        | 40/50 [02:35<00:51,  5.12s/it]
# Rp:10.555 | Rwp:13.667 | Rsquare:2.010
# WPEM 41-th iteration
# [array([ 4.54788,  4.54788,  3.12784, 90.     , 90.     , 90.     ])]
#  82%|███████████████████████████████████▎       | 41/50 [02:39<00:43,  4.83s/it]
# Rp:10.493 | Rwp:13.598 | Rsquare:1.983
# WPEM 42-th iteration
# [array([ 4.54789,  4.54789,  3.12781, 90.     , 90.     , 90.     ])]
#  84%|████████████████████████████████████       | 42/50 [02:43<00:36,  4.50s/it]
# Rp:10.433 | Rwp:13.531 | Rsquare:1.958
# WPEM 43-th iteration
# [array([ 4.54791,  4.54791,  3.12779, 90.     , 90.     , 90.     ])]
#  86%|████████████████████████████████████▉      | 43/50 [02:47<00:30,  4.31s/it]
# Rp:10.374 | Rwp:13.465 | Rsquare:1.933
# WPEM 44-th iteration
# [array([ 4.54792,  4.54792,  3.12776, 90.     , 90.     , 90.     ])]
#  88%|█████████████████████████████████████▊     | 44/50 [02:51<00:24,  4.15s/it]
# Rp:10.318 | Rwp:13.401 | Rsquare:1.909
# WPEM 45-th iteration
# [array([ 4.54793,  4.54793,  3.12774, 90.     , 90.     , 90.     ])]
#  90%|██████████████████████████████████████▋    | 45/50 [02:54<00:20,  4.03s/it]
# Rp:10.262 | Rwp:13.339 | Rsquare:1.886
# WPEM 46-th iteration
# [array([ 4.54794,  4.54794,  3.12771, 90.     , 90.     , 90.     ])]
#  92%|███████████████████████████████████████▌   | 46/50 [02:58<00:15,  3.98s/it]
# Rp:10.208 | Rwp:13.279 | Rsquare:1.863
# WPEM 47-th iteration
# [array([ 4.54796,  4.54796,  3.12769, 90.     , 90.     , 90.     ])]
#  94%|████████████████████████████████████████▍  | 47/50 [03:02<00:11,  3.93s/it]
# Rp:10.154 | Rwp:13.220 | Rsquare:1.841
# WPEM 48-th iteration
# [array([ 4.54797,  4.54797,  3.12766, 90.     , 90.     , 90.     ])]
#  96%|█████████████████████████████████████████▎ | 48/50 [03:06<00:07,  3.93s/it]
# Rp:10.103 | Rwp:13.164 | Rsquare:1.820
# WPEM 49-th iteration
# [array([ 4.54799,  4.54799,  3.12763, 90.     , 90.     , 90.     ])]
#  98%|██████████████████████████████████████████▏| 49/50 [03:10<00:03,  3.91s/it]
# Rp:10.053 | Rwp:13.109 | Rsquare:1.800
# WPEM 50-th iteration
# [array([ 4.54801,  4.54801,  3.12761, 90.     , 90.     , 90.     ])]
# 100%|███████████████████████████████████████████| 50/50 [03:14<00:00,  3.88s/it]
# Rp:10.004 | Rwp:13.056 | Rsquare:1.780
# After update the background :   Rp = 7.796 | Rwp = 12.177 | Rsquare = 1.626
# Mass fraction without structure factor estimate in % : [100.0]
#  Saved at the result documents
# 50-th iterations, reach the maximum number of iteration steps.
#  Rp: 7.796
# Rwp: 12.177
#
#
# WPEM program running time :  0 hours 3 minute  19 second
# '0 hours 3 minute  19 second  '
