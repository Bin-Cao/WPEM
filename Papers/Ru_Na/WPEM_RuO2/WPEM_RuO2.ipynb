# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2023-12-08 17:24:10  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,lowAngleRange=17,poly_n=6,bac_split=16,bac_num=500)
var
# Out:
# 93.05645607623303

# %%
latt, AtomCoordinates,des = WPEM.CIFpreprocess(filepath='RuO2.cif',two_theta_range=(15,90),show_unitcell=True,)
# Out:
# the space group of input crystal is : P 42/m n m
# cif file parse completed
# atom locations claculated by wyckoff site
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 5 extinction peaks
# Diffraction condition judgment end !
# interactive(children=(IntSlider(value=30, description='elevation', max=90, min=-90), IntSlider(value=60, descr…
# The input crystal system is: Tetragonal  |  The initial lattice constants : 4.4968 4.4968 3.1049 90.0 90.0 90.0

# %%
latt
# Out:
# [4.4968, 4.4968, 3.1049, 90.0, 90.0, 90.0]

# %% [markdown]
# # WPEM fitting

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]

# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.

Lattice_constants = [[4.53062,  4.53062,  3.12544, 90.     , 90.     , 90.    ],]

# Execute the model

WPEM.XRDfit(
    wavelength, var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=5,low_bound=15,up_bound=60,bta = 0.9,iter_max = 100, asy_C = 0,InitializationEpoch=1, 
    )
# Out:
# Started at Fri Dec  8 17:37:54 2023
#
# Initialization
# --------------------------------------------------------------------------------
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Tetragonal  |  The initial lattice constants : 4.53062 4.53062 3.12544 90.0 90.0 90.0
# —————————— Initilize the parameters by WPEM ——————————
# Parameter initialization has been completed
#   0%|                                                   | 0/100 [00:00<?, ?it/s]
# WPEM 1-th iteration
# [array([ 4.53062,  4.53062,  3.12544, 90.     , 90.     , 90.     ])]
#   1%|▍                                          | 1/100 [00:03<05:33,  3.37s/it]
# Rp:26.379 | Rwp:34.528 | Rsquare:7.114
# WPEM 2-th iteration
# [array([ 4.5301 ,  4.5301 ,  3.12597, 90.     , 90.     , 90.     ])]
#   2%|▊                                          | 2/100 [00:07<05:47,  3.54s/it]
# Rp:23.506 | Rwp:30.483 | Rsquare:6.579
# WPEM 3-th iteration
# [array([ 4.53103,  4.53103,  3.12617, 90.     , 90.     , 90.     ])]
#   3%|█▎                                         | 3/100 [00:10<05:53,  3.64s/it]
# Rp:21.561 | Rwp:28.111 | Rsquare:5.635
# WPEM 4-th iteration
# [array([ 4.53185,  4.53185,  3.12628, 90.     , 90.     , 90.     ])]
#   4%|█▋                                         | 4/100 [00:14<05:54,  3.69s/it]
# Rp:20.330 | Rwp:26.661 | Rsquare:4.913
# WPEM 5-th iteration
# [array([ 4.53258,  4.53258,  3.12634, 90.     , 90.     , 90.     ])]
#   5%|██▏                                        | 5/100 [00:18<05:53,  3.72s/it]
# Rp:19.414 | Rwp:25.647 | Rsquare:4.346
# WPEM 6-th iteration
# [array([ 4.53322,  4.53322,  3.12635, 90.     , 90.     , 90.     ])]
#   6%|██▌                                        | 6/100 [00:22<05:51,  3.74s/it]
# Rp:18.699 | Rwp:24.879 | Rsquare:3.903
# WPEM 7-th iteration
# [array([ 4.53378,  4.53378,  3.12633, 90.     , 90.     , 90.     ])]
#   7%|███                                        | 7/100 [00:25<05:47,  3.74s/it]
# Rp:18.131 | Rwp:24.270 | Rsquare:3.555
# WPEM 8-th iteration
# [array([ 4.53427,  4.53427,  3.1263 , 90.     , 90.     , 90.     ])]
#   8%|███▍                                       | 8/100 [00:29<05:45,  3.76s/it]
# Rp:17.651 | Rwp:23.768 | Rsquare:3.279
# WPEM 9-th iteration
# [array([ 4.53468,  4.53468,  3.12626, 90.     , 90.     , 90.     ])]
#   9%|███▊                                       | 9/100 [00:33<05:40,  3.74s/it]
# Rp:17.240 | Rwp:23.341 | Rsquare:3.057
# WPEM 10-th iteration
# [array([ 4.53502,  4.53502,  3.12622, 90.     , 90.     , 90.     ])]
#  10%|████▏                                     | 10/100 [00:37<05:36,  3.73s/it]
# Rp:16.877 | Rwp:22.970 | Rsquare:2.875
# WPEM 11-th iteration
# [array([ 4.53531,  4.53531,  3.12617, 90.     , 90.     , 90.     ])]
#  11%|████▌                                     | 11/100 [00:40<05:33,  3.74s/it]
# Rp:16.559 | Rwp:22.639 | Rsquare:2.724
# WPEM 12-th iteration
# [array([ 4.53554,  4.53554,  3.12612, 90.     , 90.     , 90.     ])]
#  12%|█████                                     | 12/100 [00:44<05:29,  3.74s/it]
# Rp:16.274 | Rwp:22.339 | Rsquare:2.596
# WPEM 13-th iteration
# [array([ 4.53573,  4.53573,  3.12607, 90.     , 90.     , 90.     ])]
#  13%|█████▍                                    | 13/100 [00:48<05:25,  3.74s/it]
# Rp:16.014 | Rwp:22.062 | Rsquare:2.486
# WPEM 14-th iteration
# [array([ 4.53589,  4.53589,  3.12602, 90.     , 90.     , 90.     ])]
#  14%|█████▉                                    | 14/100 [00:52<05:21,  3.74s/it]
# Rp:15.775 | Rwp:21.804 | Rsquare:2.391
# WPEM 15-th iteration
# [array([ 4.53602,  4.53602,  3.12598, 90.     , 90.     , 90.     ])]
#  15%|██████▎                                   | 15/100 [00:55<05:17,  3.73s/it]
# Rp:15.552 | Rwp:21.561 | Rsquare:2.308
# WPEM 16-th iteration
# [array([ 4.53613,  4.53613,  3.12593, 90.     , 90.     , 90.     ])]
#  16%|██████▋                                   | 16/100 [00:59<05:12,  3.72s/it]
# Rp:15.343 | Rwp:21.331 | Rsquare:2.233
# WPEM 17-th iteration
# [array([ 4.53622,  4.53622,  3.12589, 90.     , 90.     , 90.     ])]
#  17%|███████▏                                  | 17/100 [01:03<05:09,  3.73s/it]
# Rp:15.146 | Rwp:21.113 | Rsquare:2.166
# WPEM 18-th iteration
# [array([ 4.5363 ,  4.5363 ,  3.12585, 90.     , 90.     , 90.     ])]
#  18%|███████▌                                  | 18/100 [01:07<05:07,  3.75s/it]
# Rp:14.959 | Rwp:20.903 | Rsquare:2.105
# WPEM 19-th iteration
# [array([ 4.53636,  4.53636,  3.12582, 90.     , 90.     , 90.     ])]
#  19%|███████▉                                  | 19/100 [01:10<05:04,  3.75s/it]
# Rp:14.779 | Rwp:20.703 | Rsquare:2.049
# WPEM 20-th iteration
# [array([ 4.53641,  4.53641,  3.12578, 90.     , 90.     , 90.     ])]
#  20%|████████▍                                 | 20/100 [01:14<04:59,  3.75s/it]
# Rp:14.607 | Rwp:20.511 | Rsquare:1.997
# WPEM 21-th iteration
# [array([ 4.53645,  4.53645,  3.12575, 90.     , 90.     , 90.     ])]
#  21%|████████▊                                 | 21/100 [01:18<04:55,  3.74s/it]
# Rp:14.443 | Rwp:20.327 | Rsquare:1.947
# WPEM 22-th iteration
# [array([ 4.53648,  4.53648,  3.12572, 90.     , 90.     , 90.     ])]
#  22%|█████████▏                                | 22/100 [01:21<04:51,  3.73s/it]
# Rp:14.283 | Rwp:20.150 | Rsquare:1.901
# WPEM 23-th iteration
# [array([ 4.5365 ,  4.5365 ,  3.12569, 90.     , 90.     , 90.     ])]
#  23%|█████████▋                                | 23/100 [01:25<04:51,  3.79s/it]
# Rp:14.128 | Rwp:19.981 | Rsquare:1.856
# WPEM 24-th iteration
# [array([ 4.53651,  4.53651,  3.12566, 90.     , 90.     , 90.     ])]
#  24%|██████████                                | 24/100 [01:29<04:49,  3.81s/it]
# Rp:13.977 | Rwp:19.820 | Rsquare:1.813
# WPEM 25-th iteration
# [array([ 4.53651,  4.53651,  3.12563, 90.     , 90.     , 90.     ])]
#  25%|██████████▌                               | 25/100 [01:33<04:43,  3.78s/it]
# Rp:13.829 | Rwp:19.667 | Rsquare:1.772
# WPEM 26-th iteration
# [array([ 4.5365 ,  4.5365 ,  3.12561, 90.     , 90.     , 90.     ])]
#  26%|██████████▉                               | 26/100 [01:37<04:38,  3.76s/it]
# Rp:13.686 | Rwp:19.521 | Rsquare:1.732
# WPEM 27-th iteration
# [array([ 4.53648,  4.53648,  3.12559, 90.     , 90.     , 90.     ])]
#  27%|███████████▎                              | 27/100 [01:40<04:34,  3.76s/it]
# Rp:13.546 | Rwp:19.384 | Rsquare:1.694
# WPEM 28-th iteration
# [array([ 4.53646,  4.53646,  3.12557, 90.     , 90.     , 90.     ])]
#  28%|███████████▊                              | 28/100 [01:44<04:30,  3.75s/it]
# Rp:13.409 | Rwp:19.255 | Rsquare:1.656
# WPEM 29-th iteration
# [array([ 4.53642,  4.53642,  3.12555, 90.     , 90.     , 90.     ])]
#  29%|████████████▏                             | 29/100 [01:48<04:25,  3.74s/it]
# Rp:13.276 | Rwp:19.133 | Rsquare:1.620
# WPEM 30-th iteration
# [array([ 4.53638,  4.53638,  3.12553, 90.     , 90.     , 90.     ])]
#  30%|████████████▌                             | 30/100 [01:52<04:20,  3.73s/it]
# Rp:13.148 | Rwp:19.018 | Rsquare:1.585
# WPEM 31-th iteration
# [array([ 4.53633,  4.53633,  3.12551, 90.     , 90.     , 90.     ])]
#  31%|█████████████                             | 31/100 [01:55<04:16,  3.72s/it]
# Rp:13.025 | Rwp:18.909 | Rsquare:1.551
# WPEM 32-th iteration
# [array([ 4.53635,  4.53635,  3.12554, 90.     , 90.     , 90.     ])]
#  32%|█████████████▍                            | 32/100 [01:59<04:14,  3.75s/it]
# Rp:12.885 | Rwp:18.791 | Rsquare:1.509
# WPEM 33-th iteration
# [array([ 4.53635,  4.53635,  3.12555, 90.     , 90.     , 90.     ])]
#  33%|█████████████▊                            | 33/100 [02:03<04:11,  3.76s/it]
# Rp:12.754 | Rwp:18.682 | Rsquare:1.471
# WPEM 34-th iteration
# [array([ 4.53633,  4.53633,  3.12556, 90.     , 90.     , 90.     ])]
#  34%|██████████████▎                           | 34/100 [02:07<04:08,  3.76s/it]
# Rp:12.631 | Rwp:18.581 | Rsquare:1.436
# WPEM 35-th iteration
# [array([ 4.53654,  4.53654,  3.1255 , 90.     , 90.     , 90.     ])]
#  35%|██████████████▋                           | 35/100 [02:10<04:05,  3.77s/it]
# Rp:12.506 | Rwp:18.469 | Rsquare:1.413
# WPEM 36-th iteration
# [array([ 4.53716,  4.53716,  3.12539, 90.     , 90.     , 90.     ])]
#  36%|███████████████                           | 36/100 [02:15<04:08,  3.88s/it]
# Rp:12.355 | Rwp:18.332 | Rsquare:1.398
# WPEM 37-th iteration
# [array([ 4.53751,  4.53751,  3.12533, 90.     , 90.     , 90.     ])]
#  37%|███████████████▌                          | 37/100 [02:19<04:06,  3.91s/it]
# Rp:12.222 | Rwp:18.223 | Rsquare:1.380
# WPEM 38-th iteration
# [array([ 4.53771,  4.53771,  3.12529, 90.     , 90.     , 90.     ])]
#  38%|███████████████▉                          | 38/100 [02:23<04:03,  3.93s/it]
# Rp:12.103 | Rwp:18.125 | Rsquare:1.359
# WPEM 39-th iteration
# [array([ 4.53784,  4.53784,  3.12526, 90.     , 90.     , 90.     ])]
#  39%|████████████████▍                         | 39/100 [02:26<03:59,  3.93s/it]
# Rp:11.993 | Rwp:18.034 | Rsquare:1.337
# WPEM 40-th iteration
# [array([ 4.53793,  4.53793,  3.12523, 90.     , 90.     , 90.     ])]
#  40%|████████████████▊                         | 40/100 [02:30<03:57,  3.95s/it]
# Rp:11.889 | Rwp:17.946 | Rsquare:1.314
# WPEM 41-th iteration
# [array([ 4.53799,  4.53799,  3.12521, 90.     , 90.     , 90.     ])]
#  41%|█████████████████▏                        | 41/100 [02:34<03:50,  3.91s/it]
# Rp:11.790 | Rwp:17.863 | Rsquare:1.292
# WPEM 42-th iteration
# [array([ 4.53803,  4.53803,  3.12519, 90.     , 90.     , 90.     ])]
#  42%|█████████████████▋                        | 42/100 [02:38<03:46,  3.90s/it]
# Rp:11.696 | Rwp:17.783 | Rsquare:1.270
# WPEM 43-th iteration
# [array([ 4.53806,  4.53806,  3.12516, 90.     , 90.     , 90.     ])]
#  43%|██████████████████                        | 43/100 [02:42<03:41,  3.89s/it]
# Rp:11.605 | Rwp:17.707 | Rsquare:1.248
# WPEM 44-th iteration
# [array([ 4.53808,  4.53808,  3.12515, 90.     , 90.     , 90.     ])]
#  44%|██████████████████▍                       | 44/100 [02:46<03:36,  3.87s/it]
# Rp:11.518 | Rwp:17.634 | Rsquare:1.227
# WPEM 45-th iteration
# [array([ 4.53809,  4.53809,  3.12513, 90.     , 90.     , 90.     ])]
#  45%|██████████████████▉                       | 45/100 [02:50<03:33,  3.88s/it]
# Rp:11.434 | Rwp:17.564 | Rsquare:1.207
# WPEM 46-th iteration
# [array([ 4.5381 ,  4.5381 ,  3.12511, 90.     , 90.     , 90.     ])]
#  46%|███████████████████▎                      | 46/100 [02:54<03:31,  3.91s/it]
# Rp:11.354 | Rwp:17.497 | Rsquare:1.188
# WPEM 47-th iteration
# [array([ 4.53811,  4.53811,  3.12509, 90.     , 90.     , 90.     ])]
#  47%|███████████████████▋                      | 47/100 [02:58<03:27,  3.92s/it]
# Rp:11.278 | Rwp:17.434 | Rsquare:1.169
# WPEM 48-th iteration
# [array([ 4.53811,  4.53811,  3.12508, 90.     , 90.     , 90.     ])]
#  48%|████████████████████▏                     | 48/100 [03:01<03:21,  3.88s/it]
# Rp:11.205 | Rwp:17.373 | Rsquare:1.151
# WPEM 49-th iteration
# [array([ 4.53812,  4.53812,  3.12506, 90.     , 90.     , 90.     ])]
#  49%|████████████████████▌                     | 49/100 [03:05<03:17,  3.88s/it]
# Rp:11.135 | Rwp:17.315 | Rsquare:1.133
# WPEM 50-th iteration
# [array([ 4.53812,  4.53812,  3.12505, 90.     , 90.     , 90.     ])]
#  50%|█████████████████████                     | 50/100 [03:09<03:12,  3.86s/it]
# Rp:11.068 | Rwp:17.259 | Rsquare:1.117
# WPEM 51-th iteration
# [array([ 4.53811,  4.53811,  3.12504, 90.     , 90.     , 90.     ])]
#  51%|█████████████████████▍                    | 51/100 [03:13<03:09,  3.86s/it]
# Rp:11.004 | Rwp:17.207 | Rsquare:1.101
# WPEM 52-th iteration
# [array([ 4.53811,  4.53811,  3.12503, 90.     , 90.     , 90.     ])]
#  52%|█████████████████████▊                    | 52/100 [03:17<03:07,  3.91s/it]
# Rp:10.943 | Rwp:17.157 | Rsquare:1.085
# WPEM 53-th iteration
# [array([ 4.53811,  4.53811,  3.12502, 90.     , 90.     , 90.     ])]
#  53%|██████████████████████▎                   | 53/100 [03:21<03:04,  3.92s/it]
# Rp:10.884 | Rwp:17.109 | Rsquare:1.071
# WPEM 54-th iteration
# [array([ 4.5381,  4.5381,  3.125 , 90.    , 90.    , 90.    ])]
#  54%|██████████████████████▋                   | 54/100 [03:25<03:01,  3.95s/it]
# Rp:10.828 | Rwp:17.064 | Rsquare:1.057
# WPEM 55-th iteration
# [array([ 4.5381 ,  4.5381 ,  3.12499, 90.     , 90.     , 90.     ])]
#  55%|███████████████████████                   | 55/100 [03:29<02:58,  3.96s/it]
# Rp:10.774 | Rwp:17.022 | Rsquare:1.043
# WPEM 56-th iteration
# [array([ 4.53809,  4.53809,  3.12499, 90.     , 90.     , 90.     ])]
#  56%|███████████████████████▌                  | 56/100 [03:33<02:55,  3.98s/it]
# Rp:10.722 | Rwp:16.981 | Rsquare:1.031
# WPEM 57-th iteration
# [array([ 4.53809,  4.53809,  3.12498, 90.     , 90.     , 90.     ])]
#  57%|███████████████████████▉                  | 57/100 [03:37<02:51,  3.99s/it]
# Rp:10.672 | Rwp:16.943 | Rsquare:1.018
# WPEM 58-th iteration
# [array([ 4.53808,  4.53808,  3.12497, 90.     , 90.     , 90.     ])]
#  58%|████████████████████████▎                 | 58/100 [03:41<02:46,  3.96s/it]
# Rp:10.624 | Rwp:16.906 | Rsquare:1.007
# WPEM 59-th iteration
# [array([ 4.53808,  4.53808,  3.12496, 90.     , 90.     , 90.     ])]
#  59%|████████████████████████▊                 | 59/100 [03:45<02:40,  3.92s/it]
# Rp:10.578 | Rwp:16.871 | Rsquare:0.995
# WPEM 60-th iteration
# [array([ 4.53807,  4.53807,  3.12495, 90.     , 90.     , 90.     ])]
#  60%|█████████████████████████▏                | 60/100 [03:49<02:35,  3.88s/it]
# Rp:10.534 | Rwp:16.839 | Rsquare:0.985
# WPEM 61-th iteration
# [array([ 4.53807,  4.53807,  3.12495, 90.     , 90.     , 90.     ])]
#  61%|█████████████████████████▌                | 61/100 [03:53<02:33,  3.92s/it]
# Rp:10.492 | Rwp:16.808 | Rsquare:0.974
# WPEM 62-th iteration
# [array([ 4.53806,  4.53806,  3.12494, 90.     , 90.     , 90.     ])]
#  62%|██████████████████████████                | 62/100 [03:56<02:28,  3.90s/it]
# Rp:10.451 | Rwp:16.778 | Rsquare:0.965
# WPEM 63-th iteration
# [array([ 4.53806,  4.53806,  3.12493, 90.     , 90.     , 90.     ])]
#  63%|██████████████████████████▍               | 63/100 [04:00<02:23,  3.89s/it]
# Rp:10.413 | Rwp:16.750 | Rsquare:0.955
# WPEM 64-th iteration
# [array([ 4.53806,  4.53806,  3.12493, 90.     , 90.     , 90.     ])]
#  64%|██████████████████████████▉               | 64/100 [04:04<02:19,  3.88s/it]
# Rp:10.375 | Rwp:16.724 | Rsquare:0.946
# WPEM 65-th iteration
# [array([ 4.53805,  4.53805,  3.12492, 90.     , 90.     , 90.     ])]
#  65%|███████████████████████████▎              | 65/100 [04:08<02:15,  3.87s/it]
# Rp:10.340 | Rwp:16.698 | Rsquare:0.938
# WPEM 66-th iteration
# [array([ 4.53805,  4.53805,  3.12492, 90.     , 90.     , 90.     ])]
#  66%|███████████████████████████▋              | 66/100 [04:12<02:11,  3.86s/it]
# Rp:10.305 | Rwp:16.675 | Rsquare:0.929
# WPEM 67-th iteration
# [array([ 4.53805,  4.53805,  3.12491, 90.     , 90.     , 90.     ])]
#  67%|████████████████████████████▏             | 67/100 [04:16<02:11,  3.99s/it]
# Rp:10.272 | Rwp:16.652 | Rsquare:0.921
# WPEM 68-th iteration
# [array([ 4.53804,  4.53804,  3.12491, 90.     , 90.     , 90.     ])]
#  68%|████████████████████████████▌             | 68/100 [04:20<02:06,  3.95s/it]
# Rp:10.240 | Rwp:16.631 | Rsquare:0.914
# WPEM 69-th iteration
# [array([ 4.53804,  4.53804,  3.1249 , 90.     , 90.     , 90.     ])]
#  69%|████████████████████████████▉             | 69/100 [04:24<02:02,  3.94s/it]
# Rp:10.210 | Rwp:16.610 | Rsquare:0.907
# WPEM 70-th iteration
# [array([ 4.53804,  4.53804,  3.1249 , 90.     , 90.     , 90.     ])]
#  70%|█████████████████████████████▍            | 70/100 [04:28<01:57,  3.92s/it]
# Rp:10.180 | Rwp:16.591 | Rsquare:0.900
# WPEM 71-th iteration
# [array([ 4.53804,  4.53804,  3.12489, 90.     , 90.     , 90.     ])]
#  71%|█████████████████████████████▊            | 71/100 [04:32<01:53,  3.91s/it]
# Rp:10.152 | Rwp:16.572 | Rsquare:0.893
# WPEM 72-th iteration
# [array([ 4.53804,  4.53804,  3.12489, 90.     , 90.     , 90.     ])]
#  72%|██████████████████████████████▏           | 72/100 [04:35<01:48,  3.89s/it]
# Rp:10.125 | Rwp:16.555 | Rsquare:0.887
# WPEM 73-th iteration
# [array([ 4.53804,  4.53804,  3.12489, 90.     , 90.     , 90.     ])]
#  73%|██████████████████████████████▋           | 73/100 [04:39<01:45,  3.90s/it]
# Rp:10.099 | Rwp:16.538 | Rsquare:0.881
# WPEM 74-th iteration
# [array([ 4.53804,  4.53804,  3.12488, 90.     , 90.     , 90.     ])]
#  74%|███████████████████████████████           | 74/100 [04:43<01:41,  3.90s/it]
# Rp:10.073 | Rwp:16.522 | Rsquare:0.875
# WPEM 75-th iteration
# [array([ 4.53804,  4.53804,  3.12488, 90.     , 90.     , 90.     ])]
#  75%|███████████████████████████████▌          | 75/100 [04:47<01:36,  3.86s/it]
# Rp:10.049 | Rwp:16.507 | Rsquare:0.869
# WPEM 76-th iteration
# [array([ 4.53804,  4.53804,  3.12488, 90.     , 90.     , 90.     ])]
#  76%|███████████████████████████████▉          | 76/100 [04:51<01:32,  3.85s/it]
# Rp:10.026 | Rwp:16.493 | Rsquare:0.864
# WPEM 77-th iteration
# [array([ 4.53804,  4.53804,  3.12487, 90.     , 90.     , 90.     ])]
#  77%|████████████████████████████████▎         | 77/100 [04:55<01:28,  3.85s/it]
# Rp:10.003 | Rwp:16.479 | Rsquare:0.859
# WPEM 78-th iteration
# [array([ 4.53804,  4.53804,  3.12487, 90.     , 90.     , 90.     ])]
#  78%|████████████████████████████████▊         | 78/100 [04:59<01:24,  3.84s/it]
# Rp:9.981 | Rwp:16.466 | Rsquare:0.854
# WPEM 79-th iteration
# [array([ 4.53804,  4.53804,  3.12487, 90.     , 90.     , 90.     ])]
#  79%|█████████████████████████████████▏        | 79/100 [05:02<01:20,  3.83s/it]
# Rp:9.960 | Rwp:16.454 | Rsquare:0.849
# WPEM 80-th iteration
# [array([ 4.53804,  4.53804,  3.12487, 90.     , 90.     , 90.     ])]
#  80%|█████████████████████████████████▌        | 80/100 [05:06<01:16,  3.82s/it]
# Rp:9.939 | Rwp:16.442 | Rsquare:0.844
# WPEM 81-th iteration
# [array([ 4.53805,  4.53805,  3.12487, 90.     , 90.     , 90.     ])]
#  81%|██████████████████████████████████        | 81/100 [05:10<01:12,  3.81s/it]
# Rp:9.920 | Rwp:16.431 | Rsquare:0.840
# WPEM 82-th iteration
# [array([ 4.53805,  4.53805,  3.12486, 90.     , 90.     , 90.     ])]
#  82%|██████████████████████████████████▍       | 82/100 [05:14<01:09,  3.85s/it]
# Rp:9.901 | Rwp:16.420 | Rsquare:0.835
# WPEM 83-th iteration
# [array([ 4.53805,  4.53805,  3.12486, 90.     , 90.     , 90.     ])]
#  83%|██████████████████████████████████▊       | 83/100 [05:18<01:05,  3.87s/it]
# Rp:9.883 | Rwp:16.409 | Rsquare:0.831
# WPEM 84-th iteration
# [array([ 4.53806,  4.53806,  3.12486, 90.     , 90.     , 90.     ])]
#  84%|███████████████████████████████████▎      | 84/100 [05:22<01:01,  3.86s/it]
# Rp:9.865 | Rwp:16.399 | Rsquare:0.827
# WPEM 85-th iteration
# [array([ 4.53806,  4.53806,  3.12486, 90.     , 90.     , 90.     ])]
#  85%|███████████████████████████████████▋      | 85/100 [05:25<00:57,  3.83s/it]
# Rp:9.848 | Rwp:16.390 | Rsquare:0.824
# WPEM 86-th iteration
# [array([ 4.53807,  4.53807,  3.12486, 90.     , 90.     , 90.     ])]
#  86%|████████████████████████████████████      | 86/100 [05:29<00:53,  3.81s/it]
# Rp:9.831 | Rwp:16.381 | Rsquare:0.820
# WPEM 87-th iteration
# [array([ 4.53807,  4.53807,  3.12486, 90.     , 90.     , 90.     ])]
#  87%|████████████████████████████████████▌     | 87/100 [05:33<00:49,  3.82s/it]
# Rp:9.815 | Rwp:16.372 | Rsquare:0.816
# WPEM 88-th iteration
# [array([ 4.53808,  4.53808,  3.12486, 90.     , 90.     , 90.     ])]
#  88%|████████████████████████████████████▉     | 88/100 [05:37<00:45,  3.81s/it]
# Rp:9.800 | Rwp:16.364 | Rsquare:0.813
# WPEM 89-th iteration
# [array([ 4.53808,  4.53808,  3.12485, 90.     , 90.     , 90.     ])]
#  89%|█████████████████████████████████████▍    | 89/100 [05:41<00:41,  3.81s/it]
# Rp:9.785 | Rwp:16.355 | Rsquare:0.810
# WPEM 90-th iteration
# [array([ 4.53809,  4.53809,  3.12485, 90.     , 90.     , 90.     ])]
#  90%|█████████████████████████████████████▊    | 90/100 [05:44<00:38,  3.82s/it]
# Rp:9.770 | Rwp:16.348 | Rsquare:0.807
# WPEM 91-th iteration
# [array([ 4.5381 ,  4.5381 ,  3.12485, 90.     , 90.     , 90.     ])]
#  91%|██████████████████████████████████████▏   | 91/100 [05:48<00:34,  3.84s/it]
# Rp:9.756 | Rwp:16.340 | Rsquare:0.804
# WPEM 92-th iteration
# [array([ 4.5381 ,  4.5381 ,  3.12485, 90.     , 90.     , 90.     ])]
#  92%|██████████████████████████████████████▋   | 92/100 [05:52<00:30,  3.82s/it]
# Rp:9.742 | Rwp:16.333 | Rsquare:0.801
# WPEM 93-th iteration
# [array([ 4.53811,  4.53811,  3.12485, 90.     , 90.     , 90.     ])]
#  93%|███████████████████████████████████████   | 93/100 [05:56<00:26,  3.82s/it]
# Rp:9.729 | Rwp:16.326 | Rsquare:0.798
# WPEM 94-th iteration
# [array([ 4.53812,  4.53812,  3.12485, 90.     , 90.     , 90.     ])]
#  94%|███████████████████████████████████████▍  | 94/100 [06:00<00:22,  3.81s/it]
# Rp:9.716 | Rwp:16.319 | Rsquare:0.795
# WPEM 95-th iteration
# [array([ 4.53812,  4.53812,  3.12485, 90.     , 90.     , 90.     ])]
#  95%|███████████████████████████████████████▉  | 95/100 [06:03<00:19,  3.80s/it]
# Rp:9.704 | Rwp:16.313 | Rsquare:0.793
# WPEM 96-th iteration
# [array([ 4.53813,  4.53813,  3.12485, 90.     , 90.     , 90.     ])]
#  96%|████████████████████████████████████████▎ | 96/100 [06:07<00:15,  3.82s/it]
# Rp:9.692 | Rwp:16.306 | Rsquare:0.790
# WPEM 97-th iteration
# [array([ 4.53814,  4.53814,  3.12485, 90.     , 90.     , 90.     ])]
#  97%|████████████████████████████████████████▋ | 97/100 [06:11<00:11,  3.81s/it]
# Rp:9.680 | Rwp:16.300 | Rsquare:0.788
# WPEM 98-th iteration
# [array([ 4.53815,  4.53815,  3.12485, 90.     , 90.     , 90.     ])]
#  98%|█████████████████████████████████████████▏| 98/100 [06:15<00:07,  3.81s/it]
# Rp:9.668 | Rwp:16.294 | Rsquare:0.785
# WPEM 99-th iteration
# [array([ 4.53816,  4.53816,  3.12484, 90.     , 90.     , 90.     ])]
#  99%|█████████████████████████████████████████▌| 99/100 [06:19<00:03,  3.81s/it]
# Rp:9.657 | Rwp:16.289 | Rsquare:0.783
# WPEM 100-th iteration
# [array([ 4.53817,  4.53817,  3.12484, 90.     , 90.     , 90.     ])]
# 100%|█████████████████████████████████████████| 100/100 [06:23<00:00,  3.83s/it]
# Rp:9.646 | Rwp:16.283 | Rsquare:0.781
# After update the background :   Rp = 8.078 | Rwp = 16.799 | Rsquare = 0.724
# Mass fraction without structure factor estimate in % : [100.0]
#  Saved at the result documents
# 100-th iterations, reach the maximum number of iteration steps.
#  Rp: 8.078
# Rwp: 16.799
#
#
# WPEM program running time :  0 hours 6 minute  28 second
# '0 hours 6 minute  28 second  '
