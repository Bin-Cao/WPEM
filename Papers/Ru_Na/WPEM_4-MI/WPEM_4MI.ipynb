# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2023-12-08 17:46:52  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,lowAngleRange=17,poly_n=6,bac_split=16,bac_num=500)
var
# Out:
# 110.12414147377027

# %%
latt, AtomCoordinates,des = WPEM.CIFpreprocess(filepath='RuO2.cif',two_theta_range=(15,90),show_unitcell=True,)
# Out:
# the space group of input crystal is : P 42/m n m
# cif file parse completed
# atom locations claculated by wyckoff site
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 5 extinction peaks
# Diffraction condition judgment end !
# interactive(children=(IntSlider(value=30, description='elevation', max=90, min=-90), IntSlider(value=60, descr…
# The input crystal system is: Tetragonal  |  The initial lattice constants : 4.4968 4.4968 3.1049 90.0 90.0 90.0

# %%
latt
# Out:
# [4.4968, 4.4968, 3.1049, 90.0, 90.0, 90.0]

# %% [markdown]
# # WPEM fitting

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]

# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.

Lattice_constants = [[4.53062,  4.53062,  3.12544, 90.     , 90.     , 90.    ],]

# Execute the model

WPEM.XRDfit(
    wavelength, var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=5,low_bound=15,up_bound=60,bta = 0.9,iter_max = 100, asy_C = 0,InitializationEpoch=1, 
    )
# Out:
# Started at Fri Dec  8 17:47:35 2023
#
# Initialization
# --------------------------------------------------------------------------------
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Tetragonal  |  The initial lattice constants : 4.53062 4.53062 3.12544 90.0 90.0 90.0
# —————————— Initilize the parameters by WPEM ——————————
# Parameter initialization has been completed
#   0%|                                                   | 0/100 [00:00<?, ?it/s]
# WPEM 1-th iteration
# [array([ 4.53062,  4.53062,  3.12544, 90.     , 90.     , 90.     ])]
#   1%|▍                                          | 1/100 [00:03<05:31,  3.35s/it]
# Rp:23.540 | Rwp:29.643 | Rsquare:8.621
# WPEM 2-th iteration
# [array([ 4.53212,  4.53212,  3.12666, 90.     , 90.     , 90.     ])]
#   2%|▊                                          | 2/100 [00:07<05:51,  3.58s/it]
# Rp:20.688 | Rwp:25.953 | Rsquare:7.425
# WPEM 3-th iteration
# [array([ 4.53291,  4.53291,  3.12714, 90.     , 90.     , 90.     ])]
#   3%|█▎                                         | 3/100 [00:10<05:57,  3.69s/it]
# Rp:18.824 | Rwp:23.756 | Rsquare:6.083
# WPEM 4-th iteration
# [array([ 4.53366,  4.53366,  3.1275 , 90.     , 90.     , 90.     ])]
#   4%|█▋                                         | 4/100 [00:14<05:57,  3.72s/it]
# Rp:17.567 | Rwp:22.324 | Rsquare:5.091
# WPEM 5-th iteration
# [array([ 4.53426,  4.53426,  3.12782, 90.     , 90.     , 90.     ])]
#   5%|██▏                                        | 5/100 [00:18<05:57,  3.77s/it]
# Rp:16.606 | Rwp:21.294 | Rsquare:4.338
# WPEM 6-th iteration
# [array([ 4.53482,  4.53482,  3.12806, 90.     , 90.     , 90.     ])]
#   6%|██▌                                        | 6/100 [00:22<05:56,  3.79s/it]
# Rp:15.867 | Rwp:20.509 | Rsquare:3.769
# WPEM 7-th iteration
# [array([ 4.53532,  4.53532,  3.12823, 90.     , 90.     , 90.     ])]
#   7%|███                                        | 7/100 [00:26<05:54,  3.81s/it]
# Rp:15.278 | Rwp:19.888 | Rsquare:3.335
# WPEM 8-th iteration
# [array([ 4.53577,  4.53577,  3.12835, 90.     , 90.     , 90.     ])]
#   8%|███▍                                       | 8/100 [00:30<05:51,  3.82s/it]
# Rp:14.803 | Rwp:19.385 | Rsquare:3.001
# WPEM 9-th iteration
# [array([ 4.53617,  4.53617,  3.12843, 90.     , 90.     , 90.     ])]
#   9%|███▊                                       | 9/100 [00:33<05:48,  3.83s/it]
# Rp:14.418 | Rwp:18.967 | Rsquare:2.739
# WPEM 10-th iteration
# [array([ 4.53651,  4.53651,  3.12848, 90.     , 90.     , 90.     ])]
#  10%|████▏                                     | 10/100 [00:37<05:46,  3.85s/it]
# Rp:14.095 | Rwp:18.612 | Rsquare:2.531
# WPEM 11-th iteration
# [array([ 4.53681,  4.53681,  3.12851, 90.     , 90.     , 90.     ])]
#  11%|████▌                                     | 11/100 [00:41<05:42,  3.85s/it]
# Rp:13.814 | Rwp:18.304 | Rsquare:2.361
# WPEM 12-th iteration
# [array([ 4.53706,  4.53706,  3.12852, 90.     , 90.     , 90.     ])]
#  12%|█████                                     | 12/100 [00:45<05:39,  3.86s/it]
# Rp:13.568 | Rwp:18.034 | Rsquare:2.222
# WPEM 13-th iteration
# [array([ 4.53727,  4.53727,  3.12853, 90.     , 90.     , 90.     ])]
#  13%|█████▍                                    | 13/100 [00:49<05:34,  3.85s/it]
# Rp:13.352 | Rwp:17.792 | Rsquare:2.105
# WPEM 14-th iteration
# [array([ 4.53745,  4.53745,  3.12852, 90.     , 90.     , 90.     ])]
#  14%|█████▉                                    | 14/100 [00:53<05:30,  3.84s/it]
# Rp:13.158 | Rwp:17.572 | Rsquare:2.007
# WPEM 15-th iteration
# [array([ 4.5376 ,  4.5376 ,  3.12852, 90.     , 90.     , 90.     ])]
#  15%|██████▎                                   | 15/100 [00:56<05:25,  3.83s/it]
# Rp:12.980 | Rwp:17.372 | Rsquare:1.922
# WPEM 16-th iteration
# [array([ 4.53771,  4.53771,  3.12851, 90.     , 90.     , 90.     ])]
#  16%|██████▋                                   | 16/100 [01:00<05:21,  3.83s/it]
# Rp:12.816 | Rwp:17.187 | Rsquare:1.849
# WPEM 17-th iteration
# [array([ 4.53781,  4.53781,  3.12849, 90.     , 90.     , 90.     ])]
#  17%|███████▏                                  | 17/100 [01:04<05:16,  3.81s/it]
# Rp:12.664 | Rwp:17.016 | Rsquare:1.784
# WPEM 18-th iteration
# [array([ 4.53788,  4.53788,  3.12848, 90.     , 90.     , 90.     ])]
#  18%|███████▌                                  | 18/100 [01:08<05:12,  3.81s/it]
# Rp:12.525 | Rwp:16.857 | Rsquare:1.728
# WPEM 19-th iteration
# [array([ 4.53792,  4.53792,  3.12847, 90.     , 90.     , 90.     ])]
#  19%|███████▉                                  | 19/100 [01:12<05:07,  3.80s/it]
# Rp:12.396 | Rwp:16.709 | Rsquare:1.677
# WPEM 20-th iteration
# [array([ 4.53795,  4.53795,  3.12846, 90.     , 90.     , 90.     ])]
#  20%|████████▍                                 | 20/100 [01:15<05:03,  3.79s/it]
# Rp:12.275 | Rwp:16.570 | Rsquare:1.632
# WPEM 21-th iteration
# [array([ 4.53796,  4.53796,  3.12846, 90.     , 90.     , 90.     ])]
#  21%|████████▊                                 | 21/100 [01:19<04:58,  3.78s/it]
# Rp:12.162 | Rwp:16.441 | Rsquare:1.591
# WPEM 22-th iteration
# [array([ 4.53795,  4.53795,  3.12845, 90.     , 90.     , 90.     ])]
#  22%|█████████▏                                | 22/100 [01:23<04:54,  3.78s/it]
# Rp:12.056 | Rwp:16.320 | Rsquare:1.553
# WPEM 23-th iteration
# [array([ 4.53792,  4.53792,  3.12845, 90.     , 90.     , 90.     ])]
#  23%|█████████▋                                | 23/100 [01:27<04:51,  3.78s/it]
# Rp:11.955 | Rwp:16.206 | Rsquare:1.518
# WPEM 24-th iteration
# [array([ 4.53787,  4.53787,  3.12845, 90.     , 90.     , 90.     ])]
#  24%|██████████                                | 24/100 [01:31<04:47,  3.78s/it]
# Rp:11.859 | Rwp:16.100 | Rsquare:1.486
# WPEM 25-th iteration
# [array([ 4.5378 ,  4.5378 ,  3.12845, 90.     , 90.     , 90.     ])]
#  25%|██████████▌                               | 25/100 [01:34<04:43,  3.79s/it]
# Rp:11.767 | Rwp:16.002 | Rsquare:1.457
# WPEM 26-th iteration
# [array([ 4.53771,  4.53771,  3.12846, 90.     , 90.     , 90.     ])]
#  26%|██████████▉                               | 26/100 [01:38<04:40,  3.79s/it]
# Rp:11.681 | Rwp:15.910 | Rsquare:1.429
# WPEM 27-th iteration
# [array([ 4.5376 ,  4.5376 ,  3.12847, 90.     , 90.     , 90.     ])]
#  27%|███████████▎                              | 27/100 [01:42<04:37,  3.80s/it]
# Rp:11.598 | Rwp:15.824 | Rsquare:1.403
# WPEM 28-th iteration
# [array([ 4.53748,  4.53748,  3.12848, 90.     , 90.     , 90.     ])]
#  28%|███████████▊                              | 28/100 [01:46<04:34,  3.81s/it]
# Rp:11.521 | Rwp:15.745 | Rsquare:1.379
# WPEM 29-th iteration
# [array([ 4.53813,  4.53813,  3.12835, 90.     , 90.     , 90.     ])]
#  29%|████████████▏                             | 29/100 [01:50<04:33,  3.85s/it]
# Rp:11.401 | Rwp:15.602 | Rsquare:1.357
# WPEM 30-th iteration
# [array([ 4.53849,  4.53849,  3.12827, 90.     , 90.     , 90.     ])]
#  30%|████████████▌                             | 30/100 [01:54<04:30,  3.87s/it]
# Rp:11.307 | Rwp:15.495 | Rsquare:1.340
# WPEM 31-th iteration
# [array([ 4.5387 ,  4.5387 ,  3.12822, 90.     , 90.     , 90.     ])]
#  31%|█████████████                             | 31/100 [01:58<04:28,  3.90s/it]
# Rp:11.220 | Rwp:15.405 | Rsquare:1.323
# WPEM 32-th iteration
# [array([ 4.53883,  4.53883,  3.12818, 90.     , 90.     , 90.     ])]
#  32%|█████████████▍                            | 32/100 [02:01<04:24,  3.89s/it]
# Rp:11.140 | Rwp:15.323 | Rsquare:1.306
# WPEM 33-th iteration
# [array([ 4.53891,  4.53891,  3.12815, 90.     , 90.     , 90.     ])]
#  33%|█████████████▊                            | 33/100 [02:05<04:19,  3.87s/it]
# Rp:11.064 | Rwp:15.247 | Rsquare:1.290
# WPEM 34-th iteration
# [array([ 4.53895,  4.53895,  3.12812, 90.     , 90.     , 90.     ])]
#  34%|██████████████▎                           | 34/100 [02:09<04:15,  3.88s/it]
# Rp:10.992 | Rwp:15.175 | Rsquare:1.274
# WPEM 35-th iteration
# [array([ 4.53898,  4.53898,  3.12809, 90.     , 90.     , 90.     ])]
#  35%|██████████████▋                           | 35/100 [02:13<04:11,  3.88s/it]
# Rp:10.924 | Rwp:15.108 | Rsquare:1.258
# WPEM 36-th iteration
# [array([ 4.539  ,  4.539  ,  3.12806, 90.     , 90.     , 90.     ])]
#  36%|███████████████                           | 36/100 [02:17<04:07,  3.86s/it]
# Rp:10.859 | Rwp:15.045 | Rsquare:1.243
# WPEM 37-th iteration
# [array([ 4.539  ,  4.539  ,  3.12804, 90.     , 90.     , 90.     ])]
#  37%|███████████████▌                          | 37/100 [02:21<04:02,  3.86s/it]
# Rp:10.795 | Rwp:14.985 | Rsquare:1.228
# WPEM 38-th iteration
# [array([ 4.53901,  4.53901,  3.12802, 90.     , 90.     , 90.     ])]
#  38%|███████████████▉                          | 38/100 [02:25<03:58,  3.85s/it]
# Rp:10.735 | Rwp:14.928 | Rsquare:1.213
# WPEM 39-th iteration
# [array([ 4.539,  4.539,  3.128, 90.   , 90.   , 90.   ])]
#  39%|████████████████▍                         | 39/100 [02:29<03:55,  3.87s/it]
# Rp:10.677 | Rwp:14.875 | Rsquare:1.199
# WPEM 40-th iteration
# [array([ 4.53899,  4.53899,  3.12797, 90.     , 90.     , 90.     ])]
#  40%|████████████████▊                         | 40/100 [02:32<03:52,  3.88s/it]
# Rp:10.622 | Rwp:14.824 | Rsquare:1.186
# WPEM 41-th iteration
# [array([ 4.53898,  4.53898,  3.12795, 90.     , 90.     , 90.     ])]
#  41%|█████████████████▏                        | 41/100 [02:36<03:48,  3.87s/it]
# Rp:10.568 | Rwp:14.776 | Rsquare:1.173
# WPEM 42-th iteration
# [array([ 4.53897,  4.53897,  3.12793, 90.     , 90.     , 90.     ])]
#  42%|█████████████████▋                        | 42/100 [02:40<03:44,  3.86s/it]
# Rp:10.518 | Rwp:14.731 | Rsquare:1.160
# WPEM 43-th iteration
# [array([ 4.53896,  4.53896,  3.12791, 90.     , 90.     , 90.     ])]
#  43%|██████████████████                        | 43/100 [02:44<03:39,  3.85s/it]
# Rp:10.469 | Rwp:14.687 | Rsquare:1.148
# WPEM 44-th iteration
# [array([ 4.53894,  4.53894,  3.1279 , 90.     , 90.     , 90.     ])]
#  44%|██████████████████▍                       | 44/100 [02:48<03:35,  3.85s/it]
# Rp:10.423 | Rwp:14.645 | Rsquare:1.137
# WPEM 45-th iteration
# [array([ 4.53892,  4.53892,  3.12788, 90.     , 90.     , 90.     ])]
#  45%|██████████████████▉                       | 45/100 [02:52<03:32,  3.86s/it]
# Rp:10.380 | Rwp:14.605 | Rsquare:1.125
# WPEM 46-th iteration
# [array([ 4.5389 ,  4.5389 ,  3.12786, 90.     , 90.     , 90.     ])]
#  46%|███████████████████▎                      | 46/100 [02:56<03:28,  3.86s/it]
# Rp:10.338 | Rwp:14.567 | Rsquare:1.114
# WPEM 47-th iteration
# [array([ 4.53889,  4.53889,  3.12784, 90.     , 90.     , 90.     ])]
#  47%|███████████████████▋                      | 47/100 [02:59<03:24,  3.86s/it]
# Rp:10.297 | Rwp:14.529 | Rsquare:1.104
# WPEM 48-th iteration
# [array([ 4.53887,  4.53887,  3.12783, 90.     , 90.     , 90.     ])]
#  48%|████████████████████▏                     | 48/100 [03:03<03:19,  3.84s/it]
# Rp:10.257 | Rwp:14.493 | Rsquare:1.094
# WPEM 49-th iteration
# [array([ 4.53884,  4.53884,  3.12781, 90.     , 90.     , 90.     ])]
#  49%|████████████████████▌                     | 49/100 [03:07<03:15,  3.84s/it]
# Rp:10.219 | Rwp:14.458 | Rsquare:1.084
# WPEM 50-th iteration
# [array([ 4.53882,  4.53882,  3.1278 , 90.     , 90.     , 90.     ])]
#  50%|█████████████████████                     | 50/100 [03:11<03:12,  3.84s/it]
# Rp:10.182 | Rwp:14.424 | Rsquare:1.074
# WPEM 51-th iteration
# [array([ 4.5388 ,  4.5388 ,  3.12778, 90.     , 90.     , 90.     ])]
#  51%|█████████████████████▍                    | 51/100 [03:15<03:08,  3.84s/it]
# Rp:10.146 | Rwp:14.391 | Rsquare:1.065
# WPEM 52-th iteration
# [array([ 4.53878,  4.53878,  3.12777, 90.     , 90.     , 90.     ])]
#  52%|█████████████████████▊                    | 52/100 [03:19<03:04,  3.84s/it]
# Rp:10.111 | Rwp:14.359 | Rsquare:1.056
# WPEM 53-th iteration
# [array([ 4.53876,  4.53876,  3.12775, 90.     , 90.     , 90.     ])]
#  53%|██████████████████████▎                   | 53/100 [03:22<03:00,  3.85s/it]
# Rp:10.077 | Rwp:14.328 | Rsquare:1.047
# WPEM 54-th iteration
# [array([ 4.53874,  4.53874,  3.12774, 90.     , 90.     , 90.     ])]
#  54%|██████████████████████▋                   | 54/100 [03:26<02:56,  3.83s/it]
# Rp:10.044 | Rwp:14.298 | Rsquare:1.039
# WPEM 55-th iteration
# [array([ 4.53872,  4.53872,  3.12773, 90.     , 90.     , 90.     ])]
#  55%|███████████████████████                   | 55/100 [03:30<02:52,  3.83s/it]
# Rp:10.012 | Rwp:14.268 | Rsquare:1.031
# WPEM 56-th iteration
# [array([ 4.53869,  4.53869,  3.12771, 90.     , 90.     , 90.     ])]
#  56%|███████████████████████▌                  | 56/100 [03:34<02:48,  3.83s/it]
# Rp:9.981 | Rwp:14.240 | Rsquare:1.023
# WPEM 57-th iteration
# [array([ 4.53867,  4.53867,  3.1277 , 90.     , 90.     , 90.     ])]
#  57%|███████████████████████▉                  | 57/100 [03:38<02:44,  3.83s/it]
# Rp:9.951 | Rwp:14.212 | Rsquare:1.016
# WPEM 58-th iteration
# [array([ 4.53865,  4.53865,  3.12769, 90.     , 90.     , 90.     ])]
#  58%|████████████████████████▎                 | 58/100 [03:42<02:40,  3.83s/it]
# Rp:9.921 | Rwp:14.186 | Rsquare:1.008
# WPEM 59-th iteration
# [array([ 4.53863,  4.53863,  3.12768, 90.     , 90.     , 90.     ])]
#  59%|████████████████████████▊                 | 59/100 [03:45<02:37,  3.83s/it]
# Rp:9.893 | Rwp:14.160 | Rsquare:1.001
# WPEM 60-th iteration
# [array([ 4.53861,  4.53861,  3.12767, 90.     , 90.     , 90.     ])]
#  60%|█████████████████████████▏                | 60/100 [03:49<02:33,  3.83s/it]
# Rp:9.865 | Rwp:14.135 | Rsquare:0.994
# WPEM 61-th iteration
# [array([ 4.53859,  4.53859,  3.12766, 90.     , 90.     , 90.     ])]
#  61%|█████████████████████████▌                | 61/100 [03:53<02:29,  3.83s/it]
# Rp:9.839 | Rwp:14.111 | Rsquare:0.988
# WPEM 62-th iteration
# [array([ 4.53857,  4.53857,  3.12765, 90.     , 90.     , 90.     ])]
#  62%|██████████████████████████                | 62/100 [03:57<02:25,  3.83s/it]
# Rp:9.813 | Rwp:14.088 | Rsquare:0.981
# WPEM 63-th iteration
# [array([ 4.53855,  4.53855,  3.12764, 90.     , 90.     , 90.     ])]
#  63%|██████████████████████████▍               | 63/100 [04:01<02:21,  3.82s/it]
# Rp:9.788 | Rwp:14.066 | Rsquare:0.975
# WPEM 64-th iteration
# [array([ 4.53853,  4.53853,  3.12763, 90.     , 90.     , 90.     ])]
#  64%|██████████████████████████▉               | 64/100 [04:04<02:17,  3.83s/it]
# Rp:9.763 | Rwp:14.044 | Rsquare:0.969
# WPEM 65-th iteration
# [array([ 4.53852,  4.53852,  3.12762, 90.     , 90.     , 90.     ])]
#  65%|███████████████████████████▎              | 65/100 [04:08<02:13,  3.82s/it]
# Rp:9.739 | Rwp:14.023 | Rsquare:0.964
# WPEM 66-th iteration
# [array([ 4.5385 ,  4.5385 ,  3.12761, 90.     , 90.     , 90.     ])]
#  66%|███████████████████████████▋              | 66/100 [04:12<02:10,  3.83s/it]
# Rp:9.716 | Rwp:14.003 | Rsquare:0.958
# WPEM 67-th iteration
# [array([ 4.53848,  4.53848,  3.12761, 90.     , 90.     , 90.     ])]
#  67%|████████████████████████████▏             | 67/100 [04:16<02:05,  3.82s/it]
# Rp:9.694 | Rwp:13.984 | Rsquare:0.953
# WPEM 68-th iteration
# [array([ 4.53846,  4.53846,  3.1276 , 90.     , 90.     , 90.     ])]
#  68%|████████████████████████████▌             | 68/100 [04:20<02:02,  3.82s/it]
# Rp:9.672 | Rwp:13.966 | Rsquare:0.947
# WPEM 69-th iteration
# [array([ 4.53845,  4.53845,  3.12759, 90.     , 90.     , 90.     ])]
#  69%|████████████████████████████▉             | 69/100 [04:24<01:58,  3.82s/it]
# Rp:9.651 | Rwp:13.948 | Rsquare:0.942
# WPEM 70-th iteration
# [array([ 4.53843,  4.53843,  3.12758, 90.     , 90.     , 90.     ])]
#  70%|█████████████████████████████▍            | 70/100 [04:27<01:54,  3.82s/it]
# Rp:9.631 | Rwp:13.930 | Rsquare:0.938
# WPEM 71-th iteration
# [array([ 4.53842,  4.53842,  3.12758, 90.     , 90.     , 90.     ])]
#  71%|█████████████████████████████▊            | 71/100 [04:31<01:50,  3.80s/it]
# Rp:9.611 | Rwp:13.914 | Rsquare:0.933
# WPEM 72-th iteration
# [array([ 4.53841,  4.53841,  3.12757, 90.     , 90.     , 90.     ])]
#  72%|██████████████████████████████▏           | 72/100 [04:35<01:46,  3.81s/it]
# Rp:9.593 | Rwp:13.898 | Rsquare:0.928
# WPEM 73-th iteration
# [array([ 4.53839,  4.53839,  3.12757, 90.     , 90.     , 90.     ])]
#  73%|██████████████████████████████▋           | 73/100 [04:39<01:42,  3.81s/it]
# Rp:9.574 | Rwp:13.882 | Rsquare:0.924
# WPEM 74-th iteration
# [array([ 4.53838,  4.53838,  3.12756, 90.     , 90.     , 90.     ])]
#  74%|███████████████████████████████           | 74/100 [04:43<01:39,  3.81s/it]
# Rp:9.557 | Rwp:13.868 | Rsquare:0.919
# WPEM 75-th iteration
# [array([ 4.53837,  4.53837,  3.12755, 90.     , 90.     , 90.     ])]
#  75%|███████████████████████████████▌          | 75/100 [04:46<01:35,  3.82s/it]
# Rp:9.539 | Rwp:13.853 | Rsquare:0.915
# WPEM 76-th iteration
# [array([ 4.53836,  4.53836,  3.12755, 90.     , 90.     , 90.     ])]
#  76%|███████████████████████████████▉          | 76/100 [04:50<01:31,  3.80s/it]
# Rp:9.523 | Rwp:13.840 | Rsquare:0.911
# WPEM 77-th iteration
# [array([ 4.53835,  4.53835,  3.12755, 90.     , 90.     , 90.     ])]
#  77%|████████████████████████████████▎         | 77/100 [04:54<01:27,  3.81s/it]
# Rp:9.506 | Rwp:13.826 | Rsquare:0.907
# WPEM 78-th iteration
# [array([ 4.53834,  4.53834,  3.12754, 90.     , 90.     , 90.     ])]
#  78%|████████████████████████████████▊         | 78/100 [04:58<01:23,  3.81s/it]
# Rp:9.491 | Rwp:13.813 | Rsquare:0.904
# WPEM 79-th iteration
# [array([ 4.53833,  4.53833,  3.12754, 90.     , 90.     , 90.     ])]
#  79%|█████████████████████████████████▏        | 79/100 [05:02<01:20,  3.81s/it]
# Rp:9.475 | Rwp:13.801 | Rsquare:0.900
# WPEM 80-th iteration
# [array([ 4.53832,  4.53832,  3.12753, 90.     , 90.     , 90.     ])]
#  80%|█████████████████████████████████▌        | 80/100 [05:05<01:16,  3.82s/it]
# Rp:9.460 | Rwp:13.789 | Rsquare:0.896
# WPEM 81-th iteration
# [array([ 4.53831,  4.53831,  3.12753, 90.     , 90.     , 90.     ])]
#  81%|██████████████████████████████████        | 81/100 [05:09<01:12,  3.81s/it]
# Rp:9.446 | Rwp:13.777 | Rsquare:0.893
# WPEM 82-th iteration
# [array([ 4.53831,  4.53831,  3.12753, 90.     , 90.     , 90.     ])]
#  82%|██████████████████████████████████▍       | 82/100 [05:13<01:08,  3.79s/it]
# Rp:9.432 | Rwp:13.766 | Rsquare:0.890
# WPEM 83-th iteration
# [array([ 4.5383 ,  4.5383 ,  3.12752, 90.     , 90.     , 90.     ])]
#  83%|██████████████████████████████████▊       | 83/100 [05:17<01:04,  3.80s/it]
# Rp:9.418 | Rwp:13.755 | Rsquare:0.886
# WPEM 84-th iteration
# [array([ 4.53829,  4.53829,  3.12752, 90.     , 90.     , 90.     ])]
#  84%|███████████████████████████████████▎      | 84/100 [05:21<01:00,  3.79s/it]
# Rp:9.405 | Rwp:13.744 | Rsquare:0.883
# WPEM 85-th iteration
# [array([ 4.53829,  4.53829,  3.12752, 90.     , 90.     , 90.     ])]
#  85%|███████████████████████████████████▋      | 85/100 [05:24<00:56,  3.79s/it]
# Rp:9.392 | Rwp:13.734 | Rsquare:0.880
# WPEM 86-th iteration
# [array([ 4.53828,  4.53828,  3.12751, 90.     , 90.     , 90.     ])]
#  86%|████████████████████████████████████      | 86/100 [05:28<00:52,  3.78s/it]
# Rp:9.379 | Rwp:13.724 | Rsquare:0.877
# WPEM 87-th iteration
# [array([ 4.53828,  4.53828,  3.12751, 90.     , 90.     , 90.     ])]
#  87%|████████████████████████████████████▌     | 87/100 [05:32<00:48,  3.74s/it]
# Rp:9.367 | Rwp:13.715 | Rsquare:0.874
# WPEM 88-th iteration
# [array([ 4.53828,  4.53828,  3.12751, 90.     , 90.     , 90.     ])]
#  88%|████████████████████████████████████▉     | 88/100 [05:36<00:44,  3.75s/it]
# Rp:9.355 | Rwp:13.705 | Rsquare:0.871
# WPEM 89-th iteration
# [array([ 4.53827,  4.53827,  3.12751, 90.     , 90.     , 90.     ])]
#  89%|█████████████████████████████████████▍    | 89/100 [05:39<00:41,  3.76s/it]
# Rp:9.343 | Rwp:13.696 | Rsquare:0.868
# WPEM 90-th iteration
# [array([ 4.53827,  4.53827,  3.1275 , 90.     , 90.     , 90.     ])]
#  90%|█████████████████████████████████████▊    | 90/100 [05:43<00:37,  3.76s/it]
# Rp:9.332 | Rwp:13.687 | Rsquare:0.866
# WPEM 91-th iteration
# [array([ 4.53827,  4.53827,  3.1275 , 90.     , 90.     , 90.     ])]
#  91%|██████████████████████████████████████▏   | 91/100 [05:47<00:33,  3.73s/it]
# Rp:9.320 | Rwp:13.679 | Rsquare:0.863
# WPEM 92-th iteration
# [array([ 4.53827,  4.53827,  3.1275 , 90.     , 90.     , 90.     ])]
#  92%|██████████████████████████████████████▋   | 92/100 [05:50<00:29,  3.73s/it]
# Rp:9.309 | Rwp:13.670 | Rsquare:0.861
# WPEM 93-th iteration
# [array([ 4.53827,  4.53827,  3.1275 , 90.     , 90.     , 90.     ])]
#  93%|███████████████████████████████████████   | 93/100 [05:54<00:26,  3.74s/it]
# Rp:9.299 | Rwp:13.662 | Rsquare:0.858
# WPEM 94-th iteration
# [array([ 4.53827,  4.53827,  3.1275 , 90.     , 90.     , 90.     ])]
#  94%|███████████████████████████████████████▍  | 94/100 [05:58<00:22,  3.75s/it]
# Rp:9.288 | Rwp:13.654 | Rsquare:0.856
# WPEM 95-th iteration
# [array([ 4.53827,  4.53827,  3.12749, 90.     , 90.     , 90.     ])]
#  95%|███████████████████████████████████████▉  | 95/100 [06:02<00:18,  3.76s/it]
# Rp:9.278 | Rwp:13.646 | Rsquare:0.853
# WPEM 96-th iteration
# [array([ 4.53827,  4.53827,  3.12749, 90.     , 90.     , 90.     ])]
#  96%|████████████████████████████████████████▎ | 96/100 [06:05<00:14,  3.74s/it]
# Rp:9.268 | Rwp:13.639 | Rsquare:0.851
# WPEM 97-th iteration
# [array([ 4.53827,  4.53827,  3.12749, 90.     , 90.     , 90.     ])]
#  97%|████████████████████████████████████████▋ | 97/100 [06:09<00:11,  3.71s/it]
# Rp:9.258 | Rwp:13.631 | Rsquare:0.849
# WPEM 98-th iteration
# [array([ 4.53827,  4.53827,  3.12749, 90.     , 90.     , 90.     ])]
#  98%|█████████████████████████████████████████▏| 98/100 [06:13<00:07,  3.70s/it]
# Rp:9.248 | Rwp:13.624 | Rsquare:0.847
# WPEM 99-th iteration
# [array([ 4.53827,  4.53827,  3.12749, 90.     , 90.     , 90.     ])]
#  99%|█████████████████████████████████████████▌| 99/100 [06:17<00:03,  3.70s/it]
# Rp:9.238 | Rwp:13.617 | Rsquare:0.845
# WPEM 100-th iteration
# [array([ 4.53828,  4.53828,  3.12749, 90.     , 90.     , 90.     ])]
# 100%|█████████████████████████████████████████| 100/100 [06:20<00:00,  3.81s/it]
# Rp:9.229 | Rwp:13.610 | Rsquare:0.843
# After update the background :   Rp = 7.403 | Rwp = 13.584 | Rsquare = 0.758
# Mass fraction without structure factor estimate in % : [100.0]
#  Saved at the result documents
# 100-th iterations, reach the maximum number of iteration steps.
#  Rp: 7.403
# Rwp: 13.584
#
#
# WPEM program running time :  0 hours 6 minute  26 second
# '0 hours 6 minute  26 second  '
