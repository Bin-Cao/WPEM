# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2023-12-08 17:24:10  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,lowAngleRange=17,poly_n=6,bac_split=16,bac_num=500)
var
# Out:
# 93.05645607623303

# %%
latt, AtomCoordinates,des = WPEM.CIFpreprocess(filepath='RuO2.cif',two_theta_range=(15,90),show_unitcell=True,)
# Out:
# the space group of input crystal is : P 42/m n m
# cif file parse completed
# atom locations claculated by wyckoff site
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 5 extinction peaks
# Diffraction condition judgment end !
# interactive(children=(IntSlider(value=30, description='elevation', max=90, min=-90), IntSlider(value=60, descr…
# The input crystal system is: Tetragonal  |  The initial lattice constants : 4.4968 4.4968 3.1049 90.0 90.0 90.0

# %%
latt
# Out:
# [4.4968, 4.4968, 3.1049, 90.0, 90.0, 90.0]

# %% [markdown]
# # WPEM fitting

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]

# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.

Lattice_constants = [[4.53062,  4.53062,  3.12544, 90.     , 90.     , 90.    ],]

# Execute the model

WPEM.XRDfit(
    wavelength, var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=5,low_bound=15,up_bound=60,bta = 0.9,iter_max = 100, asy_C = 0,InitializationEpoch=1, 
    )
# Out:
# Started at Fri Dec  8 17:29:05 2023
#
# Initialization
# --------------------------------------------------------------------------------
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Tetragonal  |  The initial lattice constants : 4.4968 4.4968 3.1049 90.0 90.0 90.0
# —————————— Initilize the parameters by WPEM ——————————
# Parameter initialization has been completed
#   0%|                                                   | 0/100 [00:00<?, ?it/s]
# WPEM 1-th iteration
# [array([ 4.4968,  4.4968,  3.1049, 90.    , 90.    , 90.    ])]
#   1%|▍                                          | 1/100 [00:03<05:34,  3.38s/it]
# Rp:51.297 | Rwp:61.518 | Rsquare:34.264
# WPEM 2-th iteration
# [array([ 4.50176,  4.50176,  3.11957, 90.     , 90.     , 90.     ])]
#   2%|▊                                          | 2/100 [00:07<06:09,  3.77s/it]
# Rp:45.597 | Rwp:54.658 | Rsquare:28.799
# WPEM 3-th iteration
# [array([ 4.50537,  4.50537,  3.12356, 90.     , 90.     , 90.     ])]
#   3%|█▎                                         | 3/100 [00:11<06:07,  3.79s/it]
# Rp:38.976 | Rwp:47.040 | Rsquare:20.439
# WPEM 4-th iteration
# [array([ 4.5092 ,  4.5092 ,  3.12517, 90.     , 90.     , 90.     ])]
#   4%|█▋                                         | 4/100 [00:15<06:06,  3.81s/it]
# Rp:33.748 | Rwp:41.175 | Rsquare:14.920
# WPEM 5-th iteration
# [array([ 4.51279,  4.51279,  3.12576, 90.     , 90.     , 90.     ])]
#   5%|██▏                                        | 5/100 [00:18<06:04,  3.84s/it]
# Rp:29.561 | Rwp:36.594 | Rsquare:11.158
# WPEM 6-th iteration
# [array([ 4.51582,  4.51582,  3.12592, 90.     , 90.     , 90.     ])]
#   6%|██▌                                        | 6/100 [00:22<05:58,  3.82s/it]
# Rp:26.411 | Rwp:33.132 | Rsquare:8.620
# WPEM 7-th iteration
# [array([ 4.51819,  4.51819,  3.12593, 90.     , 90.     , 90.     ])]
#   7%|███                                        | 7/100 [00:26<05:54,  3.81s/it]
# Rp:24.077 | Rwp:30.589 | Rsquare:6.925
# WPEM 8-th iteration
# [array([ 4.52   ,  4.52   ,  3.12588, 90.     , 90.     , 90.     ])]
#   8%|███▍                                       | 8/100 [00:30<05:49,  3.80s/it]
# Rp:22.304 | Rwp:28.712 | Rsquare:5.770
# WPEM 9-th iteration
# [array([ 4.52139,  4.52139,  3.12582, 90.     , 90.     , 90.     ])]
#   9%|███▊                                       | 9/100 [00:34<05:46,  3.80s/it]
# Rp:20.959 | Rwp:27.290 | Rsquare:4.952
# WPEM 10-th iteration
# [array([ 4.52247,  4.52247,  3.12578, 90.     , 90.     , 90.     ])]
#  10%|████▏                                     | 10/100 [00:37<05:42,  3.81s/it]
# Rp:19.920 | Rwp:26.179 | Rsquare:4.349
# WPEM 11-th iteration
# [array([ 4.5233 ,  4.5233 ,  3.12575, 90.     , 90.     , 90.     ])]
#  11%|████▌                                     | 11/100 [00:41<05:39,  3.81s/it]
# Rp:19.082 | Rwp:25.288 | Rsquare:3.893
# WPEM 12-th iteration
# [array([ 4.52396,  4.52396,  3.12573, 90.     , 90.     , 90.     ])]
#  12%|█████                                     | 12/100 [00:45<05:35,  3.81s/it]
# Rp:18.393 | Rwp:24.558 | Rsquare:3.539
# WPEM 13-th iteration
# [array([ 4.52446,  4.52446,  3.12573, 90.     , 90.     , 90.     ])]
#  13%|█████▍                                    | 13/100 [00:49<05:30,  3.80s/it]
# Rp:17.819 | Rwp:23.950 | Rsquare:3.260
# WPEM 14-th iteration
# [array([ 4.52485,  4.52485,  3.12573, 90.     , 90.     , 90.     ])]
#  14%|█████▉                                    | 14/100 [00:53<05:25,  3.78s/it]
# Rp:17.336 | Rwp:23.445 | Rsquare:3.041
# WPEM 15-th iteration
# [array([ 4.52512,  4.52512,  3.12574, 90.     , 90.     , 90.     ])]
#  15%|██████▎                                   | 15/100 [00:56<05:20,  3.77s/it]
# Rp:16.943 | Rwp:23.038 | Rsquare:2.874
# WPEM 16-th iteration
# [array([ 4.52522,  4.52522,  3.12576, 90.     , 90.     , 90.     ])]
#  16%|██████▋                                   | 16/100 [01:00<05:15,  3.76s/it]
# Rp:16.660 | Rwp:22.745 | Rsquare:2.767
# WPEM 17-th iteration
# [array([ 4.52508,  4.52508,  3.1258 , 90.     , 90.     , 90.     ])]
#  17%|███████▏                                  | 17/100 [01:04<05:11,  3.75s/it]
# Rp:16.516 | Rwp:22.605 | Rsquare:2.731
# WPEM 18-th iteration
# [array([ 4.52602,  4.52602,  3.12574, 90.     , 90.     , 90.     ])]
#  18%|███████▌                                  | 18/100 [01:08<05:06,  3.74s/it]
# Rp:15.838 | Rwp:21.905 | Rsquare:2.423
# WPEM 19-th iteration
# [array([ 4.52666,  4.52666,  3.12571, 90.     , 90.     , 90.     ])]
#  19%|███████▉                                  | 19/100 [01:11<05:03,  3.75s/it]
# Rp:15.351 | Rwp:21.395 | Rsquare:2.221
# WPEM 20-th iteration
# [array([ 4.52712,  4.52712,  3.12569, 90.     , 90.     , 90.     ])]
#  20%|████████▍                                 | 20/100 [01:15<05:01,  3.76s/it]
# Rp:14.971 | Rwp:21.001 | Rsquare:2.077
# WPEM 21-th iteration
# [array([ 4.52747,  4.52747,  3.12568, 90.     , 90.     , 90.     ])]
#  21%|████████▊                                 | 21/100 [01:19<04:55,  3.75s/it]
# Rp:14.660 | Rwp:20.683 | Rsquare:1.969
# WPEM 22-th iteration
# [array([ 4.52774,  4.52774,  3.12567, 90.     , 90.     , 90.     ])]
#  22%|█████████▏                                | 22/100 [01:23<04:51,  3.74s/it]
# Rp:14.396 | Rwp:20.419 | Rsquare:1.883
# WPEM 23-th iteration
# [array([ 4.52797,  4.52797,  3.12566, 90.     , 90.     , 90.     ])]
#  23%|█████████▋                                | 23/100 [01:26<04:47,  3.73s/it]
# Rp:14.166 | Rwp:20.194 | Rsquare:1.813
# WPEM 24-th iteration
# [array([ 4.52817,  4.52817,  3.12565, 90.     , 90.     , 90.     ])]
#  24%|██████████                                | 24/100 [01:30<04:43,  3.73s/it]
# Rp:13.964 | Rwp:20.001 | Rsquare:1.754
# WPEM 25-th iteration
# [array([ 4.52834,  4.52834,  3.12564, 90.     , 90.     , 90.     ])]
#  25%|██████████▌                               | 25/100 [01:34<04:39,  3.72s/it]
# Rp:13.784 | Rwp:19.835 | Rsquare:1.703
# WPEM 26-th iteration
# [array([ 4.52849,  4.52849,  3.12564, 90.     , 90.     , 90.     ])]
#  26%|██████████▉                               | 26/100 [01:37<04:36,  3.74s/it]
# Rp:13.627 | Rwp:19.693 | Rsquare:1.659
# WPEM 27-th iteration
# [array([ 4.52862,  4.52862,  3.12563, 90.     , 90.     , 90.     ])]
#  27%|███████████▎                              | 27/100 [01:41<04:33,  3.75s/it]
# Rp:13.487 | Rwp:19.573 | Rsquare:1.621
# WPEM 28-th iteration
# [array([ 4.52875,  4.52875,  3.12563, 90.     , 90.     , 90.     ])]
#  28%|███████████▊                              | 28/100 [01:45<04:29,  3.74s/it]
# Rp:13.361 | Rwp:19.472 | Rsquare:1.587
# WPEM 29-th iteration
# [array([ 4.52886,  4.52886,  3.12562, 90.     , 90.     , 90.     ])]
#  29%|████████████▏                             | 29/100 [01:49<04:24,  3.73s/it]
# Rp:13.249 | Rwp:19.390 | Rsquare:1.556
# WPEM 30-th iteration
# [array([ 4.52896,  4.52896,  3.12561, 90.     , 90.     , 90.     ])]
#  30%|████████████▌                             | 30/100 [01:52<04:20,  3.72s/it]
# Rp:13.147 | Rwp:19.322 | Rsquare:1.529
# WPEM 31-th iteration
# [array([ 4.52905,  4.52905,  3.12561, 90.     , 90.     , 90.     ])]
#  31%|█████████████                             | 31/100 [01:56<04:16,  3.72s/it]
# Rp:13.055 | Rwp:19.268 | Rsquare:1.504
# WPEM 32-th iteration
# [array([ 4.52914,  4.52914,  3.1256 , 90.     , 90.     , 90.     ])]
#  32%|█████████████▍                            | 32/100 [02:00<04:13,  3.72s/it]
# Rp:12.970 | Rwp:19.222 | Rsquare:1.481
# WPEM 33-th iteration
# [array([ 4.52922,  4.52922,  3.1256 , 90.     , 90.     , 90.     ])]
#  33%|█████████████▊                            | 33/100 [02:04<04:09,  3.72s/it]
# Rp:12.891 | Rwp:19.182 | Rsquare:1.460
# WPEM 34-th iteration
# [array([ 4.5293 ,  4.5293 ,  3.12559, 90.     , 90.     , 90.     ])]
#  34%|██████████████▎                           | 34/100 [02:07<04:05,  3.72s/it]
# Rp:12.817 | Rwp:19.145 | Rsquare:1.441
# WPEM 35-th iteration
# [array([ 4.52937,  4.52937,  3.12558, 90.     , 90.     , 90.     ])]
#  35%|██████████████▋                           | 35/100 [02:11<04:01,  3.72s/it]
# Rp:12.748 | Rwp:19.109 | Rsquare:1.423
# WPEM 36-th iteration
# [array([ 4.52944,  4.52944,  3.12558, 90.     , 90.     , 90.     ])]
#  36%|███████████████                           | 36/100 [02:15<03:57,  3.71s/it]
# Rp:12.682 | Rwp:19.074 | Rsquare:1.406
# WPEM 37-th iteration
# [array([ 4.5295 ,  4.5295 ,  3.12557, 90.     , 90.     , 90.     ])]
#  37%|███████████████▌                          | 37/100 [02:18<03:54,  3.72s/it]
# Rp:12.619 | Rwp:19.038 | Rsquare:1.391
# WPEM 38-th iteration
# [array([ 4.52955,  4.52955,  3.12557, 90.     , 90.     , 90.     ])]
#  38%|███████████████▉                          | 38/100 [02:22<03:50,  3.72s/it]
# Rp:12.559 | Rwp:19.002 | Rsquare:1.377
# WPEM 39-th iteration
# [array([ 4.5296 ,  4.5296 ,  3.12556, 90.     , 90.     , 90.     ])]
#  39%|████████████████▍                         | 39/100 [02:26<03:47,  3.72s/it]
# Rp:12.502 | Rwp:18.966 | Rsquare:1.363
# WPEM 40-th iteration
# [array([ 4.52965,  4.52965,  3.12556, 90.     , 90.     , 90.     ])]
#  40%|████████████████▊                         | 40/100 [02:30<03:43,  3.72s/it]
# Rp:12.448 | Rwp:18.930 | Rsquare:1.351
# WPEM 41-th iteration
# [array([ 4.52969,  4.52969,  3.12555, 90.     , 90.     , 90.     ])]
#  41%|█████████████████▏                        | 41/100 [02:33<03:39,  3.73s/it]
# Rp:12.396 | Rwp:18.895 | Rsquare:1.339
# WPEM 42-th iteration
# [array([ 4.52973,  4.52973,  3.12555, 90.     , 90.     , 90.     ])]
#  42%|█████████████████▋                        | 42/100 [02:37<03:36,  3.72s/it]
# Rp:12.347 | Rwp:18.860 | Rsquare:1.328
# WPEM 43-th iteration
# [array([ 4.52977,  4.52977,  3.12555, 90.     , 90.     , 90.     ])]
#  43%|██████████████████                        | 43/100 [02:41<03:32,  3.73s/it]
# Rp:12.299 | Rwp:18.826 | Rsquare:1.318
# WPEM 44-th iteration
# [array([ 4.5298 ,  4.5298 ,  3.12554, 90.     , 90.     , 90.     ])]
#  44%|██████████████████▍                       | 44/100 [02:44<03:27,  3.71s/it]
# Rp:12.253 | Rwp:18.794 | Rsquare:1.308
# WPEM 45-th iteration
# [array([ 4.52984,  4.52984,  3.12554, 90.     , 90.     , 90.     ])]
#  45%|██████████████████▉                       | 45/100 [02:48<03:23,  3.70s/it]
# Rp:12.210 | Rwp:18.762 | Rsquare:1.299
# WPEM 46-th iteration
# [array([ 4.52987,  4.52987,  3.12553, 90.     , 90.     , 90.     ])]
#  46%|███████████████████▎                      | 46/100 [02:52<03:19,  3.70s/it]
# Rp:12.168 | Rwp:18.731 | Rsquare:1.291
# WPEM 47-th iteration
# [array([ 4.52989,  4.52989,  3.12553, 90.     , 90.     , 90.     ])]
#  47%|███████████████████▋                      | 47/100 [02:55<03:15,  3.69s/it]
# Rp:12.128 | Rwp:18.701 | Rsquare:1.283
# WPEM 48-th iteration
# [array([ 4.52992,  4.52992,  3.12553, 90.     , 90.     , 90.     ])]
#  48%|████████████████████▏                     | 48/100 [02:59<03:11,  3.69s/it]
# Rp:12.090 | Rwp:18.672 | Rsquare:1.275
# WPEM 49-th iteration
# [array([ 4.52994,  4.52994,  3.12552, 90.     , 90.     , 90.     ])]
#  49%|████████████████████▌                     | 49/100 [03:03<03:08,  3.69s/it]
# Rp:12.053 | Rwp:18.645 | Rsquare:1.268
# WPEM 50-th iteration
# [array([ 4.52996,  4.52996,  3.12552, 90.     , 90.     , 90.     ])]
#  50%|█████████████████████                     | 50/100 [03:07<03:04,  3.69s/it]
# Rp:12.018 | Rwp:18.618 | Rsquare:1.261
# WPEM 51-th iteration
# [array([ 4.52998,  4.52998,  3.12552, 90.     , 90.     , 90.     ])]
#  51%|█████████████████████▍                    | 51/100 [03:10<03:00,  3.69s/it]
# Rp:11.984 | Rwp:18.593 | Rsquare:1.255
# WPEM 52-th iteration
# [array([ 4.53   ,  4.53   ,  3.12552, 90.     , 90.     , 90.     ])]
#  52%|█████████████████████▊                    | 52/100 [03:14<02:56,  3.69s/it]
# Rp:11.952 | Rwp:18.568 | Rsquare:1.249
# WPEM 53-th iteration
# [array([ 4.53002,  4.53002,  3.12551, 90.     , 90.     , 90.     ])]
#  53%|██████████████████████▎                   | 53/100 [03:18<02:53,  3.69s/it]
# Rp:11.921 | Rwp:18.544 | Rsquare:1.243
# WPEM 54-th iteration
# [array([ 4.53004,  4.53004,  3.12551, 90.     , 90.     , 90.     ])]
#  54%|██████████████████████▋                   | 54/100 [03:21<02:49,  3.68s/it]
# Rp:11.891 | Rwp:18.521 | Rsquare:1.237
# WPEM 55-th iteration
# [array([ 4.53006,  4.53006,  3.12551, 90.     , 90.     , 90.     ])]
#  55%|███████████████████████                   | 55/100 [03:25<02:45,  3.69s/it]
# Rp:11.862 | Rwp:18.499 | Rsquare:1.232
# WPEM 56-th iteration
# [array([ 4.53008,  4.53008,  3.1255 , 90.     , 90.     , 90.     ])]
#  56%|███████████████████████▌                  | 56/100 [03:29<02:42,  3.69s/it]
# Rp:11.834 | Rwp:18.477 | Rsquare:1.226
# WPEM 57-th iteration
# [array([ 4.53009,  4.53009,  3.1255 , 90.     , 90.     , 90.     ])]
#  57%|███████████████████████▉                  | 57/100 [03:32<02:38,  3.69s/it]
# Rp:11.807 | Rwp:18.457 | Rsquare:1.221
# WPEM 58-th iteration
# [array([ 4.53011,  4.53011,  3.1255 , 90.     , 90.     , 90.     ])]
#  58%|████████████████████████▎                 | 58/100 [03:36<02:34,  3.68s/it]
# Rp:11.781 | Rwp:18.436 | Rsquare:1.216
# WPEM 59-th iteration
# [array([ 4.53012,  4.53012,  3.1255 , 90.     , 90.     , 90.     ])]
#  59%|████████████████████████▊                 | 59/100 [03:40<02:32,  3.71s/it]
# Rp:11.756 | Rwp:18.417 | Rsquare:1.212
# WPEM 60-th iteration
# [array([ 4.53014,  4.53014,  3.1255 , 90.     , 90.     , 90.     ])]
#  60%|█████████████████████████▏                | 60/100 [03:43<02:27,  3.70s/it]
# Rp:11.732 | Rwp:18.398 | Rsquare:1.207
# WPEM 61-th iteration
# [array([ 4.53015,  4.53015,  3.12549, 90.     , 90.     , 90.     ])]
#  61%|█████████████████████████▌                | 61/100 [03:47<02:23,  3.69s/it]
# Rp:11.708 | Rwp:18.380 | Rsquare:1.203
# WPEM 62-th iteration
# [array([ 4.53017,  4.53017,  3.12549, 90.     , 90.     , 90.     ])]
#  62%|██████████████████████████                | 62/100 [03:51<02:20,  3.69s/it]
# Rp:11.686 | Rwp:18.362 | Rsquare:1.199
# WPEM 63-th iteration
# [array([ 4.53018,  4.53018,  3.12549, 90.     , 90.     , 90.     ])]
#  63%|██████████████████████████▍               | 63/100 [03:54<02:16,  3.68s/it]
# Rp:11.663 | Rwp:18.345 | Rsquare:1.195
# WPEM 64-th iteration
# [array([ 4.53019,  4.53019,  3.12549, 90.     , 90.     , 90.     ])]
#  64%|██████████████████████████▉               | 64/100 [03:58<02:12,  3.68s/it]
# Rp:11.642 | Rwp:18.328 | Rsquare:1.191
# WPEM 65-th iteration
# [array([ 4.53021,  4.53021,  3.12549, 90.     , 90.     , 90.     ])]
#  65%|███████████████████████████▎              | 65/100 [04:02<02:08,  3.68s/it]
# Rp:11.621 | Rwp:18.312 | Rsquare:1.187
# WPEM 66-th iteration
# [array([ 4.53022,  4.53022,  3.12549, 90.     , 90.     , 90.     ])]
#  66%|███████████████████████████▋              | 66/100 [04:06<02:05,  3.68s/it]
# Rp:11.601 | Rwp:18.296 | Rsquare:1.183
# WPEM 67-th iteration
# [array([ 4.53023,  4.53023,  3.12548, 90.     , 90.     , 90.     ])]
#  67%|████████████████████████████▏             | 67/100 [04:09<02:01,  3.67s/it]
# Rp:11.581 | Rwp:18.281 | Rsquare:1.179
# WPEM 68-th iteration
# [array([ 4.53024,  4.53024,  3.12548, 90.     , 90.     , 90.     ])]
#  68%|████████████████████████████▌             | 68/100 [04:13<01:57,  3.68s/it]
# Rp:11.561 | Rwp:18.266 | Rsquare:1.175
# WPEM 69-th iteration
# [array([ 4.53026,  4.53026,  3.12548, 90.     , 90.     , 90.     ])]
#  69%|████████████████████████████▉             | 69/100 [04:17<01:54,  3.68s/it]
# Rp:11.543 | Rwp:18.251 | Rsquare:1.172
# WPEM 70-th iteration
# [array([ 4.53027,  4.53027,  3.12548, 90.     , 90.     , 90.     ])]
#  70%|█████████████████████████████▍            | 70/100 [04:20<01:50,  3.69s/it]
# Rp:11.524 | Rwp:18.237 | Rsquare:1.168
# WPEM 71-th iteration
# [array([ 4.53028,  4.53028,  3.12548, 90.     , 90.     , 90.     ])]
#  71%|█████████████████████████████▊            | 71/100 [04:24<01:46,  3.67s/it]
# Rp:11.507 | Rwp:18.223 | Rsquare:1.165
# WPEM 72-th iteration
# [array([ 4.53029,  4.53029,  3.12548, 90.     , 90.     , 90.     ])]
#  72%|██████████████████████████████▏           | 72/100 [04:28<01:42,  3.68s/it]
# Rp:11.489 | Rwp:18.210 | Rsquare:1.162
# WPEM 73-th iteration
# [array([ 4.53031,  4.53031,  3.12548, 90.     , 90.     , 90.     ])]
#  73%|██████████████████████████████▋           | 73/100 [04:31<01:38,  3.66s/it]
# Rp:11.472 | Rwp:18.196 | Rsquare:1.159
# WPEM 74-th iteration
# [array([ 4.53032,  4.53032,  3.12548, 90.     , 90.     , 90.     ])]
#  74%|███████████████████████████████           | 74/100 [04:35<01:35,  3.67s/it]
# Rp:11.456 | Rwp:18.183 | Rsquare:1.155
# WPEM 75-th iteration
# [array([ 4.53033,  4.53033,  3.12547, 90.     , 90.     , 90.     ])]
#  75%|███████████████████████████████▌          | 75/100 [04:39<01:31,  3.68s/it]
# Rp:11.440 | Rwp:18.171 | Rsquare:1.152
# WPEM 76-th iteration
# [array([ 4.53034,  4.53034,  3.12547, 90.     , 90.     , 90.     ])]
#  76%|███████████████████████████████▉          | 76/100 [04:42<01:28,  3.68s/it]
# Rp:11.424 | Rwp:18.158 | Rsquare:1.149
# WPEM 77-th iteration
# [array([ 4.53035,  4.53035,  3.12547, 90.     , 90.     , 90.     ])]
#  77%|████████████████████████████████▎         | 77/100 [04:46<01:24,  3.68s/it]
# Rp:11.408 | Rwp:18.146 | Rsquare:1.146
# WPEM 78-th iteration
# [array([ 4.53037,  4.53037,  3.12547, 90.     , 90.     , 90.     ])]
#  78%|████████████████████████████████▊         | 78/100 [04:50<01:20,  3.67s/it]
# Rp:11.393 | Rwp:18.134 | Rsquare:1.143
# WPEM 79-th iteration
# [array([ 4.53038,  4.53038,  3.12547, 90.     , 90.     , 90.     ])]
#  79%|█████████████████████████████████▏        | 79/100 [04:53<01:17,  3.67s/it]
# Rp:11.378 | Rwp:18.123 | Rsquare:1.140
# WPEM 80-th iteration
# [array([ 4.53039,  4.53039,  3.12547, 90.     , 90.     , 90.     ])]
#  80%|█████████████████████████████████▌        | 80/100 [04:57<01:13,  3.68s/it]
# Rp:11.364 | Rwp:18.111 | Rsquare:1.138
# WPEM 81-th iteration
# [array([ 4.5304 ,  4.5304 ,  3.12547, 90.     , 90.     , 90.     ])]
#  81%|██████████████████████████████████        | 81/100 [05:01<01:09,  3.68s/it]
# Rp:11.350 | Rwp:18.100 | Rsquare:1.135
# WPEM 82-th iteration
# [array([ 4.53041,  4.53041,  3.12547, 90.     , 90.     , 90.     ])]
#  82%|██████████████████████████████████▍       | 82/100 [05:04<01:06,  3.68s/it]
# Rp:11.336 | Rwp:18.089 | Rsquare:1.132
# WPEM 83-th iteration
# [array([ 4.53043,  4.53043,  3.12547, 90.     , 90.     , 90.     ])]
#  83%|██████████████████████████████████▊       | 83/100 [05:08<01:02,  3.67s/it]
# Rp:11.322 | Rwp:18.079 | Rsquare:1.129
# WPEM 84-th iteration
# [array([ 4.53044,  4.53044,  3.12547, 90.     , 90.     , 90.     ])]
#  84%|███████████████████████████████████▎      | 84/100 [05:12<00:58,  3.67s/it]
# Rp:11.309 | Rwp:18.068 | Rsquare:1.127
# WPEM 85-th iteration
# [array([ 4.53045,  4.53045,  3.12547, 90.     , 90.     , 90.     ])]
#  85%|███████████████████████████████████▋      | 85/100 [05:15<00:55,  3.67s/it]
# Rp:11.296 | Rwp:18.058 | Rsquare:1.124
# WPEM 86-th iteration
# [array([ 4.53046,  4.53046,  3.12546, 90.     , 90.     , 90.     ])]
#  86%|████████████████████████████████████      | 86/100 [05:19<00:51,  3.67s/it]
# Rp:11.283 | Rwp:18.048 | Rsquare:1.122
# WPEM 87-th iteration
# [array([ 4.53047,  4.53047,  3.12546, 90.     , 90.     , 90.     ])]
#  87%|████████████████████████████████████▌     | 87/100 [05:23<00:47,  3.67s/it]
# Rp:11.271 | Rwp:18.038 | Rsquare:1.119
# WPEM 88-th iteration
# [array([ 4.53048,  4.53048,  3.12546, 90.     , 90.     , 90.     ])]
#  88%|████████████████████████████████████▉     | 88/100 [05:26<00:44,  3.68s/it]
# Rp:11.258 | Rwp:18.028 | Rsquare:1.117
# WPEM 89-th iteration
# [array([ 4.5305 ,  4.5305 ,  3.12546, 90.     , 90.     , 90.     ])]
#  89%|█████████████████████████████████████▍    | 89/100 [05:30<00:40,  3.68s/it]
# Rp:11.246 | Rwp:18.019 | Rsquare:1.115
# WPEM 90-th iteration
# [array([ 4.53051,  4.53051,  3.12546, 90.     , 90.     , 90.     ])]
#  90%|█████████████████████████████████████▊    | 90/100 [05:34<00:36,  3.68s/it]
# Rp:11.235 | Rwp:18.010 | Rsquare:1.112
# WPEM 91-th iteration
# [array([ 4.53052,  4.53052,  3.12546, 90.     , 90.     , 90.     ])]
#  91%|██████████████████████████████████████▏   | 91/100 [05:37<00:33,  3.68s/it]
# Rp:11.223 | Rwp:18.000 | Rsquare:1.110
# WPEM 92-th iteration
# [array([ 4.53053,  4.53053,  3.12546, 90.     , 90.     , 90.     ])]
#  92%|██████████████████████████████████████▋   | 92/100 [05:41<00:29,  3.68s/it]
# Rp:11.212 | Rwp:17.991 | Rsquare:1.108
# WPEM 93-th iteration
# [array([ 4.53054,  4.53054,  3.12545, 90.     , 90.     , 90.     ])]
#  93%|███████████████████████████████████████   | 93/100 [05:45<00:25,  3.68s/it]
# Rp:11.201 | Rwp:17.982 | Rsquare:1.106
# WPEM 94-th iteration
# [array([ 4.53055,  4.53055,  3.12545, 90.     , 90.     , 90.     ])]
#  94%|███████████████████████████████████████▍  | 94/100 [05:48<00:22,  3.68s/it]
# Rp:11.190 | Rwp:17.974 | Rsquare:1.104
# WPEM 95-th iteration
# [array([ 4.53056,  4.53056,  3.12545, 90.     , 90.     , 90.     ])]
#  95%|███████████████████████████████████████▉  | 95/100 [05:52<00:18,  3.69s/it]
# Rp:11.179 | Rwp:17.965 | Rsquare:1.102
# WPEM 96-th iteration
# [array([ 4.53058,  4.53058,  3.12545, 90.     , 90.     , 90.     ])]
#  96%|████████████████████████████████████████▎ | 96/100 [05:56<00:14,  3.68s/it]
# Rp:11.168 | Rwp:17.957 | Rsquare:1.100
# WPEM 97-th iteration
# [array([ 4.53059,  4.53059,  3.12545, 90.     , 90.     , 90.     ])]
#  97%|████████████████████████████████████████▋ | 97/100 [06:00<00:11,  3.69s/it]
# Rp:11.158 | Rwp:17.948 | Rsquare:1.098
# WPEM 98-th iteration
# [array([ 4.5306 ,  4.5306 ,  3.12544, 90.     , 90.     , 90.     ])]
#  98%|█████████████████████████████████████████▏| 98/100 [06:03<00:07,  3.68s/it]
# Rp:11.148 | Rwp:17.940 | Rsquare:1.096
# WPEM 99-th iteration
# [array([ 4.53061,  4.53061,  3.12544, 90.     , 90.     , 90.     ])]
#  99%|█████████████████████████████████████████▌| 99/100 [06:07<00:03,  3.68s/it]
# Rp:11.138 | Rwp:17.932 | Rsquare:1.094
# WPEM 100-th iteration
# [array([ 4.53062,  4.53062,  3.12544, 90.     , 90.     , 90.     ])]
# 100%|█████████████████████████████████████████| 100/100 [06:11<00:00,  3.71s/it]
# Rp:11.128 | Rwp:17.924 | Rsquare:1.092
# After update the background :   Rp = 9.543 | Rwp = 18.275 | Rsquare = 1.017
# Mass fraction without structure factor estimate in % : [100.0]
#  Saved at the result documents
# 100-th iterations, reach the maximum number of iteration steps.
#  Rp: 9.543
# Rwp: 18.275
#
#
# WPEM program running time :  0 hours 6 minute  16 second
# '0 hours 6 minute  16 second  '
