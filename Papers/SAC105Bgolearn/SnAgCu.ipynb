# %% [markdown]
# ## 1: background intensity

# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2023-11-25 17:57:30  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
Var = WPEM.BackgroundFit(intensity_csv, LFctg=0.2, lowAngleRange=30, window_length = 7, bac_num=500)
Var
# Out:
# 1.6366634951864674

# %%
latt, AtomCoordinates,_ = WPEM.CIFpreprocess(filepath='betaSn.cif',two_theta_range=(25, 100),cal_extinction=False)
# Out:
# the space group of input crystal is : I 41/a m d :1
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 0 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Tetragonal  |  The initial lattice constants : 5.8317 5.8317 3.1813 90.0 90.0 90.0

# %%
latt
# Out:
# [5.8317, 5.8317, 3.1813, 90.0, 90.0, 90.0]

# %%
latt, AtomCoordinates ,_= WPEM.CIFpreprocess(filepath='Ag3Sn.cif',two_theta_range=(25, 100),)
# Out:
# the space group of input crystal is : P m m n :2
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 12 extinction peaks
# Diffraction condition judgment end !

# %%
latt
# Out:
# [5.968, 4.7802, 5.1843, 90.0, 90.0, 90.0]

# %%
latt, AtomCoordinates,_ = WPEM.CIFpreprocess(filepath='Cu6Sn5.cif',two_theta_range=(25, 99),)
# Out:
# the space group of input crystal is : C 1 2/c 1
# cif file parse completed
# atom locations claculated by wyckoff site
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 383 extinction peaks
# Diffraction condition judgment end !

# %%
latt
# Out:
# [11.036, 7.288, 9.841, 90.0, 98.81, 90.0]

# %%
latt, AtomCoordinates,_  = WPEM.CIFpreprocess(filepath='Ti2Sn3.cif',two_theta_range=(25, 100))
# Out:
# the space group of input crystal is : C m c a
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 230 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Orthorhombic  |  The initial lattice constants : 5.9556 19.964 7.0281 90.0 90.0 90.0

# %%
latt
# Out:
# [5.9556, 19.964, 7.0281, 90.0, 90.0, 90.0]

# %% [markdown]
# ## 2: Wpen fitting

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]
Var = 12.9
# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.

Lattice_constants = [ [5.83, 5.83, 3.181, 90.0, 90.0, 90.0],
                     [5.953, 4.7802, 5.1733, 90.0, 90.0, 90.0],
                     [11.03, 7.299, 9.841, 90.0, 98.83608, 90.0],
                    [5.9556, 19.964, 7.0281, 90.0, 90.0, 90.0]]

# Execute the model
WPEM.XRDfit(
    wavelength, Var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=9 ,low_bound=30,up_bound=90,bta = 0.90,iter_max = 40, asy_C = 0, 
    InitializationEpoch=0,)
# Out:
# Started at Sat Nov 25 19:48:54 2023
#
# Initialization
# --------------------------------------------------------------------------------
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Tetragonal  |  The initial lattice constants : 5.83 5.83 3.181 90.0 90.0 90.0
# The input crystal system is: Orthorhombic  |  The initial lattice constants : 5.953 4.7802 5.1733 90.0 90.0 90.0
# The input crystal system is: Monoclinic  |  The initial lattice constants : 11.03 7.299 9.841 90.0 98.83608 90.0
# The input crystal system is: Orthorhombic  |  The initial lattice constants : 5.9556 19.964 7.0281 90.0 90.0 90.0
# —————————— Initilize the parameters by WPEM ——————————
# Parameter initialization has been completed
#   0%|                                                    | 0/40 [00:00<?, ?it/s]
# WPEM 1-th iteration
# [array([ 5.82999,  5.82999,  3.18108, 90.     , 90.     , 90.     ]), array([ 5.95309,  4.78008,  5.17328, 90.     , 90.     , 90.     ]), array([11.03007,  7.2991 ,  9.84105, 90.     , 98.83608, 90.     ]), array([ 5.95567, 19.96438,  7.02806, 90.     , 90.     , 90.     ])]
#   2%|█                                           | 1/40 [01:27<56:33, 87.00s/it]
# Rp:36.059 | Rwp:60.890 | Rsquare:9.579
# WPEM 2-th iteration
# [array([ 5.83003,  5.83003,  3.18126, 90.     , 90.     , 90.     ]), array([ 5.95302,  4.78003,  5.17333, 90.     , 90.     , 90.     ]), array([11.03002,  7.29915,  9.84106, 90.     , 98.83608, 90.     ]), array([ 5.95575, 19.96368,  7.02831, 90.     , 90.     , 90.     ])]
#   5%|██▏                                         | 2/40 [02:45<51:59, 82.10s/it]
# Rp:30.463 | Rwp:53.589 | Rsquare:5.382
# WPEM 3-th iteration
# [array([ 5.8301,  5.8301,  3.1814, 90.    , 90.    , 90.    ]), array([ 5.9528 ,  4.78001,  5.17343, 90.     , 90.     , 90.     ]), array([11.03002,  7.29915,  9.84106, 90.     , 98.83438, 90.     ]), array([ 5.95582, 19.96474,  7.02818, 90.     , 90.     , 90.     ])]
#   8%|███▎                                        | 3/40 [04:27<56:09, 91.06s/it]
# Rp:27.724 | Rwp:50.340 | Rsquare:4.024
# WPEM 4-th iteration
# [array([ 5.83015,  5.83015,  3.1815 , 90.     , 90.     , 90.     ]), array([ 5.95279,  4.77996,  5.17341, 90.     , 90.     , 90.     ]), array([11.02997,  7.29915,  9.84096, 90.     , 98.83438, 90.     ]), array([ 5.95584, 19.96568,  7.02803, 90.     , 90.     , 90.     ])]
#  10%|████                                     | 4/40 [06:46<1:05:56, 109.91s/it]
# Rp:26.452 | Rwp:48.700 | Rsquare:3.499
# WPEM 5-th iteration
# [array([ 5.83018,  5.83018,  3.18157, 90.     , 90.     , 90.     ]), array([ 5.9528 ,  4.77992,  5.17343, 90.     , 90.     , 90.     ]), array([11.02994,  7.29915,  9.84096, 90.     , 98.83438, 90.     ]), array([ 5.95585, 19.96672,  7.02792, 90.     , 90.     , 90.     ])]
#  12%|█████▏                                   | 5/40 [08:22<1:01:12, 104.94s/it]
# Rp:25.842 | Rwp:47.800 | Rsquare:3.266
# WPEM 6-th iteration
# [array([ 5.83019,  5.83019,  3.18162, 90.     , 90.     , 90.     ]), array([ 5.95282,  4.77986,  5.17346, 90.     , 90.     , 90.     ]), array([11.03001,  7.29918,  9.84104, 90.     , 98.83438, 90.     ]), array([ 5.95582, 19.96808,  7.0278 , 90.     , 90.     , 90.     ])]
#  15%|██████▌                                     | 6/40 [09:45<55:19, 97.62s/it]
# Rp:25.442 | Rwp:47.255 | Rsquare:3.149
# WPEM 7-th iteration
# [array([ 5.8302 ,  5.8302 ,  3.18166, 90.     , 90.     , 90.     ]), array([ 5.9528 ,  4.77981,  5.17344, 90.     , 90.     , 90.     ]), array([11.03001,  7.29918,  9.84104, 90.     , 98.83417, 90.     ]), array([ 5.95581, 19.96854,  7.02765, 90.     , 90.     , 90.     ])]
#  18%|███████▋                                    | 7/40 [11:10<51:19, 93.33s/it]
# Rp:25.160 | Rwp:46.867 | Rsquare:3.070
# WPEM 8-th iteration
# [array([ 5.83018,  5.83018,  3.18168, 90.     , 90.     , 90.     ]), array([ 5.95276,  4.77975,  5.17342, 90.     , 90.     , 90.     ]), array([11.02999,  7.29916,  9.841  , 90.     , 98.83417, 90.     ]), array([ 5.95579, 19.96859,  7.0276 , 90.     , 90.     , 90.     ])]
#  20%|████████▊                                   | 8/40 [12:35<48:28, 90.89s/it]
# Rp:24.933 | Rwp:46.593 | Rsquare:2.996
# WPEM 9-th iteration
# [array([ 5.83018,  5.83018,  3.18171, 90.     , 90.     , 90.     ]), array([ 5.95281,  4.77969,  5.17344, 90.     , 90.     , 90.     ]), array([11.02999,  7.29917,  9.84105, 90.     , 98.83417, 90.     ]), array([ 5.95579, 19.96876,  7.02752, 90.     , 90.     , 90.     ])]
#  22%|█████████▉                                  | 9/40 [13:54<44:59, 87.08s/it]
# Rp:24.776 | Rwp:46.390 | Rsquare:2.954
# WPEM 10-th iteration
# [array([ 5.83017,  5.83017,  3.18172, 90.     , 90.     , 90.     ]), array([ 5.95284,  4.77964,  5.17347, 90.     , 90.     , 90.     ]), array([11.02995,  7.29911,  9.84105, 90.     , 98.83417, 90.     ]), array([ 5.95577, 19.96894,  7.02754, 90.     , 90.     , 90.     ])]
#  25%|██████████▊                                | 10/40 [15:10<41:50, 83.67s/it]
# Rp:24.652 | Rwp:46.227 | Rsquare:2.916
# WPEM 11-th iteration
# [array([ 5.83017,  5.83017,  3.18174, 90.     , 90.     , 90.     ]), array([ 5.95286,  4.77956,  5.1735 , 90.     , 90.     , 90.     ]), array([11.02994,  7.29909,  9.84103, 90.     , 98.83417, 90.     ]), array([ 5.95582, 19.969  ,  7.02749, 90.     , 90.     , 90.     ])]
#  28%|███████████▊                               | 11/40 [16:30<39:56, 82.63s/it]
# Rp:24.557 | Rwp:46.094 | Rsquare:2.884
# WPEM 12-th iteration
# [array([ 5.83017,  5.83017,  3.18174, 90.     , 90.     , 90.     ]), array([ 5.95287,  4.77955,  5.17355, 90.     , 90.     , 90.     ]), array([11.02993,  7.29908,  9.84101, 90.     , 98.83417, 90.     ]), array([ 5.95581, 19.96929,  7.02748, 90.     , 90.     , 90.     ])]
#  30%|████████████▉                              | 12/40 [17:55<38:50, 83.22s/it]
# Rp:24.478 | Rwp:45.982 | Rsquare:2.858
# WPEM 13-th iteration
# [array([ 5.83018,  5.83018,  3.18175, 90.     , 90.     , 90.     ]), array([ 5.95288,  4.77953,  5.17358, 90.     , 90.     , 90.     ]), array([11.02993,  7.29908,  9.84101, 90.     , 98.8341 , 90.     ]), array([ 5.95583, 19.96953,  7.02746, 90.     , 90.     , 90.     ])]
#  32%|█████████████▉                             | 13/40 [19:22<37:59, 84.43s/it]
# Rp:24.408 | Rwp:45.884 | Rsquare:2.835
# WPEM 14-th iteration
# [array([ 5.83015,  5.83015,  3.18176, 90.     , 90.     , 90.     ]), array([ 5.9529 ,  4.77951,  5.17362, 90.     , 90.     , 90.     ]), array([11.02988,  7.29907,  9.84104, 90.     , 98.8341 , 90.     ]), array([ 5.95583, 19.96977,  7.02742, 90.     , 90.     , 90.     ])]
#  35%|███████████████                            | 14/40 [20:55<37:41, 86.98s/it]
# Rp:24.341 | Rwp:45.800 | Rsquare:2.810
# WPEM 15-th iteration
# [array([ 5.83013,  5.83013,  3.18177, 90.     , 90.     , 90.     ]), array([ 5.95291,  4.77951,  5.17366, 90.     , 90.     , 90.     ]), array([11.02988,  7.29907,  9.84104, 90.     , 98.83374, 90.     ]), array([ 5.95584, 19.9701 ,  7.02737, 90.     , 90.     , 90.     ])]
#  38%|████████████████▏                          | 15/40 [22:37<38:08, 91.52s/it]
# Rp:24.278 | Rwp:45.729 | Rsquare:2.785
# WPEM 16-th iteration
# [array([ 5.83012,  5.83012,  3.18177, 90.     , 90.     , 90.     ]), array([ 5.95294,  4.77944,  5.17369, 90.     , 90.     , 90.     ]), array([11.02986,  7.29909,  9.84104, 90.     , 98.83374, 90.     ]), array([ 5.95271, 19.93906,  7.0231 , 90.     , 90.     , 90.     ])]
#  38%|███████████████▊                          | 15/40 [25:06<41:50, 100.42s/it]
# Rp:25.774 | Rwp:47.676 | Rsquare:3.193
# After update the background :   Rp = 4.824 | Rwp = 26.624 | Rsquare = 0.859
# Mass fraction without structure factor estimate in % : [40.909825362902886, 33.25353852434993, 14.894228055157189, 10.942408057590004]
#  Saved at the result documents
# 16-th iterations, reach the limit of lock_num.
#  Rp: 4.824
# Rwp: 26.624
#
#
# WPEM program running time :  0 hours 25 minute  35 second
# '0 hours 25 minute  35 second  '

# %%
name = ['βSn','Ag\u2083(Sn,In)','Cu\u2086(Sn,In)\u2085','Ti\u2082Sn\u2083']
wavelength = [1.540593*2/3+ 1.544414*1/3]
WPEM.Plot_Components(lowboundary=10, upboundary=100,name = name, wavelength = wavelength, lifting=[300,200,100,0,400],phase=4,)
# Out:
# Name assigned successfully
# Mass fraction estimate in % (calculated by integral area): [44.02325983729356, 7.502854415508595, 34.39785945480088, 14.076026292396973]
#  Saved at the DecomposedComponents document
