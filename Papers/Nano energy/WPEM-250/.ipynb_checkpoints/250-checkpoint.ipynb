# %% [markdown]
# # background intensity

# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# A Diffraction Refinement Software : WPEM
# Bin Cao, MGI, Shanghai University, Shanghai, CHINA.
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2023-06-17 15:47:34  Have a great day.

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,lowAngleRange=22,poly_n=8,bac_split=8,bac_num=1000)
var
# Out:
# 235.26114577169727

# %% [markdown]
# # WPEM fitting

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]

var=235.261
# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c|, α, β, γ}, whose values need to be assumed at initialization.
Lattice_constants = [[9.411, 9.411, 9.411, 90, 90, 90],[ 4.41115, 4.41115, 3.04844, 90., 90. , 90.,'fixed']]

# Execute the model
WPEM.XRDfit(
    wavelength, var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=11,low_bound=20,up_bound=50,bta = 0.80,iter_max = 700, asy_C = 0
    )
# Out:
# Started at Fri Jun 16 12:05:24 2023
#
# The lattice constants of input system 1 are fixed
# viz., fixed : [4.41115, 4.41115, 3.04844, 90.0, 90.0, 90.0]
# Initialization
# --------------------------------------------------------------------------------
# Diffraction indexs have been obtained by WPEM
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Cubic  |  The initial lattice constants : 9.411 9.411 9.411 90 90 90
# The input crystal system is: Tetragonal  |  The initial lattice constants : 4.41115 4.41115 3.04844 90.0 90.0 90.0
# Parameter initialization has been completed
#
# WPEM 1-th iteration
# [array([ 9.41051,  9.41051,  9.41051, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:4.135 | Rwp:5.307 | Rsquare:3.515
# WPEM 2-th iteration
# [array([ 9.41018,  9.41018,  9.41018, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:4.009 | Rwp:5.134 | Rsquare:3.257
# WPEM 3-th iteration
# [array([ 9.40994,  9.40994,  9.40994, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.982 | Rwp:5.072 | Rsquare:3.184
# WPEM 4-th iteration
# [array([ 9.40976,  9.40976,  9.40976, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.965 | Rwp:5.033 | Rsquare:3.143
# WPEM 5-th iteration
# [array([ 9.40961,  9.40961,  9.40961, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.942 | Rwp:5.000 | Rsquare:3.098
# WPEM 6-th iteration
# [array([ 9.4096,  9.4096,  9.4096, 90.    , 90.    , 90.    ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.917 | Rwp:4.967 | Rsquare:3.043
# WPEM 7-th iteration
# [array([ 9.40957,  9.40957,  9.40957, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.893 | Rwp:4.936 | Rsquare:2.980
# WPEM 8-th iteration
# [array([ 9.40954,  9.40954,  9.40954, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.870 | Rwp:4.906 | Rsquare:2.915
# WPEM 9-th iteration
# [array([ 9.40951,  9.40951,  9.40951, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.847 | Rwp:4.877 | Rsquare:2.851
# WPEM 10-th iteration
# [array([ 9.40948,  9.40948,  9.40948, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.827 | Rwp:4.851 | Rsquare:2.790
# WPEM 11-th iteration
# [array([ 9.40945,  9.40945,  9.40945, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.807 | Rwp:4.827 | Rsquare:2.733
# WPEM 12-th iteration
# [array([ 9.40943,  9.40943,  9.40943, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.788 | Rwp:4.804 | Rsquare:2.680
# WPEM 13-th iteration
# [array([ 9.40941,  9.40941,  9.40941, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.770 | Rwp:4.783 | Rsquare:2.632
# WPEM 14-th iteration
# [array([ 9.4094,  9.4094,  9.4094, 90.    , 90.    , 90.    ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.753 | Rwp:4.765 | Rsquare:2.588
# WPEM 15-th iteration
# [array([ 9.40933,  9.40933,  9.40933, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.739 | Rwp:4.748 | Rsquare:2.549
# WPEM 16-th iteration
# [array([ 9.40926,  9.40926,  9.40926, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.725 | Rwp:4.732 | Rsquare:2.514
# WPEM 17-th iteration
# [array([ 9.40921,  9.40921,  9.40921, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.712 | Rwp:4.718 | Rsquare:2.482
# WPEM 18-th iteration
# [array([ 9.40916,  9.40916,  9.40916, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.700 | Rwp:4.705 | Rsquare:2.453
# WPEM 19-th iteration
# [array([ 9.40911,  9.40911,  9.40911, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.689 | Rwp:4.693 | Rsquare:2.427
# WPEM 20-th iteration
# [array([ 9.40907,  9.40907,  9.40907, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.678 | Rwp:4.682 | Rsquare:2.404
# WPEM 21-th iteration
# [array([ 9.40903,  9.40903,  9.40903, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.668 | Rwp:4.673 | Rsquare:2.383
# WPEM 22-th iteration
# [array([ 9.40908,  9.40908,  9.40908, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.657 | Rwp:4.663 | Rsquare:2.362
# WPEM 23-th iteration
# [array([ 9.40911,  9.40911,  9.40911, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.648 | Rwp:4.654 | Rsquare:2.344
# WPEM 24-th iteration
# [array([ 9.40912,  9.40912,  9.40912, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.640 | Rwp:4.646 | Rsquare:2.329
# WPEM 25-th iteration
# [array([ 9.40913,  9.40913,  9.40913, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.632 | Rwp:4.639 | Rsquare:2.315
# WPEM 26-th iteration
# [array([ 9.40914,  9.40914,  9.40914, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.626 | Rwp:4.633 | Rsquare:2.303
# WPEM 27-th iteration
# [array([ 9.40912,  9.40912,  9.40912, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.619 | Rwp:4.627 | Rsquare:2.293
# WPEM 28-th iteration
# [array([ 9.4091,  9.4091,  9.4091, 90.    , 90.    , 90.    ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.614 | Rwp:4.622 | Rsquare:2.284
# WPEM 29-th iteration
# [array([ 9.40909,  9.40909,  9.40909, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.609 | Rwp:4.618 | Rsquare:2.276
# WPEM 30-th iteration
# [array([ 9.40907,  9.40907,  9.40907, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.605 | Rwp:4.614 | Rsquare:2.268
# WPEM 31-th iteration
# [array([ 9.40905,  9.40905,  9.40905, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.601 | Rwp:4.610 | Rsquare:2.262
# WPEM 32-th iteration
# [array([ 9.40902,  9.40902,  9.40902, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.598 | Rwp:4.607 | Rsquare:2.256
# WPEM 33-th iteration
# [array([ 9.409,  9.409,  9.409, 90.   , 90.   , 90.   ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.595 | Rwp:4.604 | Rsquare:2.251
# WPEM 34-th iteration
# [array([ 9.40898,  9.40898,  9.40898, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.593 | Rwp:4.601 | Rsquare:2.247
# WPEM 35-th iteration
# [array([ 9.40895,  9.40895,  9.40895, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.591 | Rwp:4.599 | Rsquare:2.243
# WPEM 36-th iteration
# [array([ 9.40892,  9.40892,  9.40892, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.589 | Rwp:4.597 | Rsquare:2.240
# WPEM 37-th iteration
# [array([ 9.4089,  9.4089,  9.4089, 90.    , 90.    , 90.    ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.587 | Rwp:4.595 | Rsquare:2.236
# WPEM 38-th iteration
# [array([ 9.40887,  9.40887,  9.40887, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.585 | Rwp:4.593 | Rsquare:2.234
# WPEM 39-th iteration
# [array([ 9.40884,  9.40884,  9.40884, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.584 | Rwp:4.591 | Rsquare:2.231
# WPEM 40-th iteration
# [array([ 9.40881,  9.40881,  9.40881, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.582 | Rwp:4.590 | Rsquare:2.229
# WPEM 41-th iteration
# [array([ 9.40878,  9.40878,  9.40878, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.581 | Rwp:4.589 | Rsquare:2.227
# WPEM 42-th iteration
# [array([ 9.40875,  9.40875,  9.40875, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.580 | Rwp:4.587 | Rsquare:2.225
# WPEM 43-th iteration
# [array([ 9.40872,  9.40872,  9.40872, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.579 | Rwp:4.586 | Rsquare:2.224
# WPEM 44-th iteration
# [array([ 9.40868,  9.40868,  9.40868, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.579 | Rwp:4.585 | Rsquare:2.222
# WPEM 45-th iteration
# [array([ 9.40865,  9.40865,  9.40865, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.578 | Rwp:4.584 | Rsquare:2.221
# WPEM 46-th iteration
# [array([ 9.40862,  9.40862,  9.40862, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.577 | Rwp:4.583 | Rsquare:2.220
# WPEM 47-th iteration
# [array([ 9.40858,  9.40858,  9.40858, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.577 | Rwp:4.583 | Rsquare:2.219
# WPEM 48-th iteration
# [array([ 9.40855,  9.40855,  9.40855, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.577 | Rwp:4.582 | Rsquare:2.218
# WPEM 49-th iteration
# [array([ 9.40851,  9.40851,  9.40851, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.576 | Rwp:4.581 | Rsquare:2.217
# WPEM 50-th iteration
# [array([ 9.40848,  9.40848,  9.40848, 90.     , 90.     , 90.     ]), array([ 4.41115,  4.41115,  3.04844, 90.     , 90.     , 90.     ])]
# Rp:3.576 | Rwp:4.581 | Rsquare:2.216
# After update the background :   Rp = 1.957 | Rwp = 4.004 | Rsquare = 1.620
# volume fraction without structure factor estimate in % : [87.97002295136733, 12.02997704863267]
#  Saved at the result documents
# 50-th iterations, reach the limit of ϵ.
#  Rp: 1.957
# Rwp: 4.004
#
#
# WPEM program running time :  0 hours 6 minute  44 second
# '0 hours 6 minute  44 second  '

# %%
name = ['(Mn,Ru)2O3','RuO2',]
wavelength = [1.540593, 1.544414]
WPEM.Plot_Components(lowboundary=15, upboundary=80,name = name, wavelength = wavelength, phase=2)
# Out:
# Name assigned successfully
# volume fraction estimate in % (calculated by integral area): [93.43411556884799, 6.565884431152017]
#  Saved at the DecomposedComponents document

# %% [markdown]
# # search

# %%
WPEM.SubstitutionalSearch('wpem.csv','Mn2O3.cif',wavelength=[1.540593, 1.544414],SolventAtom = 'Mn3+', 
                          SoluteAtom= 'Ru3+',max_iter = 50)
# Out:
# the space group of input crystal is : I 2b 2c 3
# cif file parse completed
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 27 extinction peaks
# Diffraction condition judgment end !
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 WPEM.SubstitutionalSearch('wpem.csv','Mn2O3.cif',wavelength=[1.540593, 1.544414],SolventAtom = 'Mn3+',
#       2                           SoluteAtom= 'Ru3+',max_iter = 80)
#
# File ~/Documents/GitHub/PyWPEM/WPEM.py:305, in SubstitutionalSearch(xrd_pattern, cif_file, wavelength, SolventAtom, SoluteAtom, max_iter)
#     304 def SubstitutionalSearch(xrd_pattern, cif_file, wavelength='CuKa',SolventAtom = None, SoluteAtom= None,max_iter = 100):
# --> 305     return BgolearnOpt(xrd_pattern, cif_file, wavelength). Substitutional_SS(SolventAtom, SoluteAtom ,max_iter)
#
# File ~/Documents/GitHub/PyWPEM/StructureOpt/SiteOpt.py:162, in BgolearnOpt.Substitutional_SS(self, SolventAtom, SoluteAtom, max_iter)
#     159 opt_index = response_vector.index(min(response_vector))
#     160 structure = feature_matrix[opt_index]
# --> 162 real_structure = recover_atoms_coordinate(convert_to_2d_list(structure,atom_num+3),self.Atom_coordinate,SoluteAtom)
#     164 plotUnitCell(real_structure,self.LatticCs,).plot()
#     165 return real_structure
#
# UnboundLocalError: local variable 'atom_num' referenced before assignment
