# %% [markdown]
# # background intensity

# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# A Diffraction Refinement Software : WPEM
# Bin Cao, MGI, Shanghai University, Shanghai, CHINA.
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2023-06-30 17:00:18  Have a great day.

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,lowAngleRange=22,poly_n=8,bac_split=8,bac_num=1000)
var
# Out:
# 360.42488404715147

# %% [markdown]
# # WPEM fitting

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]
var = 275.25
# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c|, α, β, γ}, whose values need to be assumed at initialization.
Lattice_constants = [[9.411, 9.411, 9.411, 90, 90, 90]]

# Execute the model
WPEM.XRDfit(
    wavelength, var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=11,low_bound=20,up_bound=50,bta = 0.85,iter_max = 700, asy_C = 0
    )
# Out:
# Started at Fri Jun 30 17:02:48 2023
#
# Initialization
# --------------------------------------------------------------------------------
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Cubic  |  The initial lattice constants : 9.411 9.411 9.411 90 90 90
# Parameter initialization has been completed
#
# WPEM 1-th iteration
# [array([ 9.40991,  9.40991,  9.40991, 90.     , 90.     , 90.     ])]
# Rp:3.422 | Rwp:4.811 | Rsquare:4.181
# WPEM 2-th iteration
# [array([ 9.40841,  9.40841,  9.40841, 90.     , 90.     , 90.     ])]
# Rp:3.156 | Rwp:4.293 | Rsquare:2.835
# WPEM 3-th iteration
# [array([ 9.40807,  9.40807,  9.40807, 90.     , 90.     , 90.     ])]
# Rp:3.077 | Rwp:4.129 | Rsquare:2.519
# WPEM 4-th iteration
# [array([ 9.40782,  9.40782,  9.40782, 90.     , 90.     , 90.     ])]
# Rp:3.027 | Rwp:4.025 | Rsquare:2.353
# WPEM 5-th iteration
# [array([ 9.40762,  9.40762,  9.40762, 90.     , 90.     , 90.     ])]
# Rp:2.983 | Rwp:3.948 | Rsquare:2.252
# WPEM 6-th iteration
# [array([ 9.40745,  9.40745,  9.40745, 90.     , 90.     , 90.     ])]
# Rp:2.945 | Rwp:3.888 | Rsquare:2.181
# WPEM 7-th iteration
# [array([ 9.40731,  9.40731,  9.40731, 90.     , 90.     , 90.     ])]
# Rp:2.916 | Rwp:3.839 | Rsquare:2.122
# WPEM 8-th iteration
# [array([ 9.40718,  9.40718,  9.40718, 90.     , 90.     , 90.     ])]
# Rp:2.891 | Rwp:3.797 | Rsquare:2.067
# WPEM 9-th iteration
# [array([ 9.40707,  9.40707,  9.40707, 90.     , 90.     , 90.     ])]
# Rp:2.870 | Rwp:3.760 | Rsquare:2.011
# WPEM 10-th iteration
# [array([ 9.40697,  9.40697,  9.40697, 90.     , 90.     , 90.     ])]
# Rp:2.850 | Rwp:3.726 | Rsquare:1.955
# WPEM 11-th iteration
# [array([ 9.40688,  9.40688,  9.40688, 90.     , 90.     , 90.     ])]
# Rp:2.832 | Rwp:3.694 | Rsquare:1.901
# WPEM 12-th iteration
# [array([ 9.40679,  9.40679,  9.40679, 90.     , 90.     , 90.     ])]
# Rp:2.816 | Rwp:3.665 | Rsquare:1.848
# WPEM 13-th iteration
# [array([ 9.40672,  9.40672,  9.40672, 90.     , 90.     , 90.     ])]
# Rp:2.800 | Rwp:3.638 | Rsquare:1.798
# WPEM 14-th iteration
# [array([ 9.40664,  9.40664,  9.40664, 90.     , 90.     , 90.     ])]
# Rp:2.786 | Rwp:3.612 | Rsquare:1.750
# WPEM 15-th iteration
# [array([ 9.40657,  9.40657,  9.40657, 90.     , 90.     , 90.     ])]
# Rp:2.772 | Rwp:3.589 | Rsquare:1.705
# WPEM 16-th iteration
# [array([ 9.40651,  9.40651,  9.40651, 90.     , 90.     , 90.     ])]
# Rp:2.759 | Rwp:3.566 | Rsquare:1.663
# WPEM 17-th iteration
# [array([ 9.40645,  9.40645,  9.40645, 90.     , 90.     , 90.     ])]
# Rp:2.747 | Rwp:3.545 | Rsquare:1.623
# WPEM 18-th iteration
# [array([ 9.4064,  9.4064,  9.4064, 90.    , 90.    , 90.    ])]
# Rp:2.735 | Rwp:3.526 | Rsquare:1.585
# WPEM 19-th iteration
# [array([ 9.40635,  9.40635,  9.40635, 90.     , 90.     , 90.     ])]
# Rp:2.724 | Rwp:3.507 | Rsquare:1.549
# WPEM 20-th iteration
# [array([ 9.40631,  9.40631,  9.40631, 90.     , 90.     , 90.     ])]
# Rp:2.713 | Rwp:3.489 | Rsquare:1.516
# WPEM 21-th iteration
# [array([ 9.40627,  9.40627,  9.40627, 90.     , 90.     , 90.     ])]
# Rp:2.703 | Rwp:3.472 | Rsquare:1.484
# WPEM 22-th iteration
# [array([ 9.40623,  9.40623,  9.40623, 90.     , 90.     , 90.     ])]
# Rp:2.693 | Rwp:3.455 | Rsquare:1.453
# WPEM 23-th iteration
# [array([ 9.4062,  9.4062,  9.4062, 90.    , 90.    , 90.    ])]
# Rp:2.683 | Rwp:3.439 | Rsquare:1.424
# WPEM 24-th iteration
# [array([ 9.40617,  9.40617,  9.40617, 90.     , 90.     , 90.     ])]
# Rp:2.673 | Rwp:3.424 | Rsquare:1.397
# WPEM 25-th iteration
# [array([ 9.40614,  9.40614,  9.40614, 90.     , 90.     , 90.     ])]
# Rp:2.663 | Rwp:3.409 | Rsquare:1.370
# WPEM 26-th iteration
# [array([ 9.40611,  9.40611,  9.40611, 90.     , 90.     , 90.     ])]
# Rp:2.654 | Rwp:3.395 | Rsquare:1.345
# WPEM 27-th iteration
# [array([ 9.40609,  9.40609,  9.40609, 90.     , 90.     , 90.     ])]
# Rp:2.645 | Rwp:3.381 | Rsquare:1.321
# WPEM 28-th iteration
# [array([ 9.40607,  9.40607,  9.40607, 90.     , 90.     , 90.     ])]
# Rp:2.637 | Rwp:3.368 | Rsquare:1.298
# WPEM 29-th iteration
# [array([ 9.40605,  9.40605,  9.40605, 90.     , 90.     , 90.     ])]
# Rp:2.628 | Rwp:3.355 | Rsquare:1.277
# WPEM 30-th iteration
# [array([ 9.40603,  9.40603,  9.40603, 90.     , 90.     , 90.     ])]
# Rp:2.620 | Rwp:3.343 | Rsquare:1.256
# WPEM 31-th iteration
# [array([ 9.40602,  9.40602,  9.40602, 90.     , 90.     , 90.     ])]
# Rp:2.611 | Rwp:3.330 | Rsquare:1.236
# WPEM 32-th iteration
# [array([ 9.406,  9.406,  9.406, 90.   , 90.   , 90.   ])]
# Rp:2.603 | Rwp:3.319 | Rsquare:1.218
# WPEM 33-th iteration
# [array([ 9.40599,  9.40599,  9.40599, 90.     , 90.     , 90.     ])]
# Rp:2.595 | Rwp:3.307 | Rsquare:1.200
# WPEM 34-th iteration
# [array([ 9.40598,  9.40598,  9.40598, 90.     , 90.     , 90.     ])]
# Rp:2.587 | Rwp:3.297 | Rsquare:1.183
# WPEM 35-th iteration
# [array([ 9.40597,  9.40597,  9.40597, 90.     , 90.     , 90.     ])]
# Rp:2.580 | Rwp:3.286 | Rsquare:1.168
# WPEM 36-th iteration
# [array([ 9.40596,  9.40596,  9.40596, 90.     , 90.     , 90.     ])]
# Rp:2.572 | Rwp:3.276 | Rsquare:1.153
# WPEM 37-th iteration
# [array([ 9.40595,  9.40595,  9.40595, 90.     , 90.     , 90.     ])]
# Rp:2.565 | Rwp:3.267 | Rsquare:1.139
# WPEM 38-th iteration
# [array([ 9.40594,  9.40594,  9.40594, 90.     , 90.     , 90.     ])]
# Rp:2.558 | Rwp:3.258 | Rsquare:1.126
# WPEM 39-th iteration
# [array([ 9.40593,  9.40593,  9.40593, 90.     , 90.     , 90.     ])]
# Rp:2.551 | Rwp:3.249 | Rsquare:1.114
# WPEM 40-th iteration
# [array([ 9.40593,  9.40593,  9.40593, 90.     , 90.     , 90.     ])]
# Rp:2.544 | Rwp:3.241 | Rsquare:1.103
# WPEM 41-th iteration
# [array([ 9.40592,  9.40592,  9.40592, 90.     , 90.     , 90.     ])]
# Rp:2.538 | Rwp:3.233 | Rsquare:1.093
# WPEM 42-th iteration
# [array([ 9.40591,  9.40591,  9.40591, 90.     , 90.     , 90.     ])]
# Rp:2.532 | Rwp:3.226 | Rsquare:1.084
# WPEM 43-th iteration
# [array([ 9.4059,  9.4059,  9.4059, 90.    , 90.    , 90.    ])]
# Rp:2.526 | Rwp:3.219 | Rsquare:1.075
# WPEM 44-th iteration
# [array([ 9.4059,  9.4059,  9.4059, 90.    , 90.    , 90.    ])]
# Rp:2.521 | Rwp:3.213 | Rsquare:1.067
# WPEM 45-th iteration
# [array([ 9.40589,  9.40589,  9.40589, 90.     , 90.     , 90.     ])]
# Rp:2.516 | Rwp:3.207 | Rsquare:1.060
# WPEM 46-th iteration
# [array([ 9.40588,  9.40588,  9.40588, 90.     , 90.     , 90.     ])]
# Rp:2.511 | Rwp:3.202 | Rsquare:1.054
# WPEM 47-th iteration
# [array([ 9.40588,  9.40588,  9.40588, 90.     , 90.     , 90.     ])]
# Rp:2.507 | Rwp:3.197 | Rsquare:1.048
# WPEM 48-th iteration
# [array([ 9.40587,  9.40587,  9.40587, 90.     , 90.     , 90.     ])]
# Rp:2.503 | Rwp:3.192 | Rsquare:1.043
# WPEM 49-th iteration
# [array([ 9.40586,  9.40586,  9.40586, 90.     , 90.     , 90.     ])]
# Rp:2.499 | Rwp:3.188 | Rsquare:1.038
# WPEM 50-th iteration
# [array([ 9.40585,  9.40585,  9.40585, 90.     , 90.     , 90.     ])]
# Rp:2.496 | Rwp:3.184 | Rsquare:1.034
# WPEM 51-th iteration
# [array([ 9.40584,  9.40584,  9.40584, 90.     , 90.     , 90.     ])]
# Rp:2.492 | Rwp:3.181 | Rsquare:1.030
# WPEM 52-th iteration
# [array([ 9.40584,  9.40584,  9.40584, 90.     , 90.     , 90.     ])]
# Rp:2.489 | Rwp:3.178 | Rsquare:1.026
# WPEM 53-th iteration
# [array([ 9.40583,  9.40583,  9.40583, 90.     , 90.     , 90.     ])]
# Rp:2.486 | Rwp:3.175 | Rsquare:1.023
# WPEM 54-th iteration
# [array([ 9.40582,  9.40582,  9.40582, 90.     , 90.     , 90.     ])]
# Rp:2.483 | Rwp:3.172 | Rsquare:1.020
# WPEM 55-th iteration
# [array([ 9.40581,  9.40581,  9.40581, 90.     , 90.     , 90.     ])]
# Rp:2.481 | Rwp:3.170 | Rsquare:1.018
# WPEM 56-th iteration
# [array([ 9.4058,  9.4058,  9.4058, 90.    , 90.    , 90.    ])]
# Rp:2.479 | Rwp:3.167 | Rsquare:1.015
# WPEM 57-th iteration
# [array([ 9.40579,  9.40579,  9.40579, 90.     , 90.     , 90.     ])]
# Rp:2.477 | Rwp:3.165 | Rsquare:1.013
# WPEM 58-th iteration
# [array([ 9.40579,  9.40579,  9.40579, 90.     , 90.     , 90.     ])]
# Rp:2.474 | Rwp:3.163 | Rsquare:1.011
# WPEM 59-th iteration
# [array([ 9.40578,  9.40578,  9.40578, 90.     , 90.     , 90.     ])]
# Rp:2.473 | Rwp:3.161 | Rsquare:1.009
# WPEM 60-th iteration
# [array([ 9.40577,  9.40577,  9.40577, 90.     , 90.     , 90.     ])]
# Rp:2.471 | Rwp:3.160 | Rsquare:1.008
# WPEM 61-th iteration
# [array([ 9.40576,  9.40576,  9.40576, 90.     , 90.     , 90.     ])]
# Rp:2.469 | Rwp:3.158 | Rsquare:1.007
# WPEM 62-th iteration
# [array([ 9.40575,  9.40575,  9.40575, 90.     , 90.     , 90.     ])]
# Rp:2.468 | Rwp:3.157 | Rsquare:1.005
# WPEM 63-th iteration
# [array([ 9.40574,  9.40574,  9.40574, 90.     , 90.     , 90.     ])]
# Rp:2.466 | Rwp:3.155 | Rsquare:1.004
# WPEM 64-th iteration
# [array([ 9.40573,  9.40573,  9.40573, 90.     , 90.     , 90.     ])]
# Rp:2.465 | Rwp:3.154 | Rsquare:1.003
# WPEM 65-th iteration
# [array([ 9.40573,  9.40573,  9.40573, 90.     , 90.     , 90.     ])]
# Rp:2.464 | Rwp:3.153 | Rsquare:1.002
# WPEM 66-th iteration
# [array([ 9.40572,  9.40572,  9.40572, 90.     , 90.     , 90.     ])]
# Rp:2.463 | Rwp:3.152 | Rsquare:1.001
# WPEM 67-th iteration
# [array([ 9.40571,  9.40571,  9.40571, 90.     , 90.     , 90.     ])]
# Rp:2.462 | Rwp:3.151 | Rsquare:1.000
# WPEM 68-th iteration
# [array([ 9.4057,  9.4057,  9.4057, 90.    , 90.    , 90.    ])]
# Rp:2.461 | Rwp:3.150 | Rsquare:0.999
# WPEM 69-th iteration
# [array([ 9.4057,  9.4057,  9.4057, 90.    , 90.    , 90.    ])]
# Rp:2.460 | Rwp:3.149 | Rsquare:0.999
# WPEM 70-th iteration
# [array([ 9.40569,  9.40569,  9.40569, 90.     , 90.     , 90.     ])]
# Rp:2.460 | Rwp:3.148 | Rsquare:0.998
# WPEM 71-th iteration
# [array([ 9.40568,  9.40568,  9.40568, 90.     , 90.     , 90.     ])]
# Rp:2.459 | Rwp:3.147 | Rsquare:0.997
# WPEM 72-th iteration
# [array([ 9.40567,  9.40567,  9.40567, 90.     , 90.     , 90.     ])]
# Rp:2.458 | Rwp:3.147 | Rsquare:0.997
# WPEM 73-th iteration
# [array([ 9.40567,  9.40567,  9.40567, 90.     , 90.     , 90.     ])]
# Rp:2.458 | Rwp:3.146 | Rsquare:0.996
# WPEM 74-th iteration
# [array([ 9.40566,  9.40566,  9.40566, 90.     , 90.     , 90.     ])]
# Rp:2.457 | Rwp:3.145 | Rsquare:0.996
# WPEM 75-th iteration
# [array([ 9.40565,  9.40565,  9.40565, 90.     , 90.     , 90.     ])]
# Rp:2.457 | Rwp:3.145 | Rsquare:0.995
# WPEM 76-th iteration
# [array([ 9.40565,  9.40565,  9.40565, 90.     , 90.     , 90.     ])]
# Rp:2.456 | Rwp:3.144 | Rsquare:0.995
# WPEM 77-th iteration
# [array([ 9.40564,  9.40564,  9.40564, 90.     , 90.     , 90.     ])]
# Rp:2.456 | Rwp:3.143 | Rsquare:0.995
# WPEM 78-th iteration
# [array([ 9.40563,  9.40563,  9.40563, 90.     , 90.     , 90.     ])]
# Rp:2.455 | Rwp:3.143 | Rsquare:0.994
# WPEM 79-th iteration
# [array([ 9.40563,  9.40563,  9.40563, 90.     , 90.     , 90.     ])]
# Rp:2.455 | Rwp:3.142 | Rsquare:0.994
# WPEM 80-th iteration
# [array([ 9.40562,  9.40562,  9.40562, 90.     , 90.     , 90.     ])]
# Rp:2.454 | Rwp:3.142 | Rsquare:0.993
# WPEM 81-th iteration
# [array([ 9.40561,  9.40561,  9.40561, 90.     , 90.     , 90.     ])]
# Rp:2.454 | Rwp:3.141 | Rsquare:0.993
# WPEM 82-th iteration
# [array([ 9.40561,  9.40561,  9.40561, 90.     , 90.     , 90.     ])]
# Rp:2.454 | Rwp:3.141 | Rsquare:0.993
# WPEM 83-th iteration
# [array([ 9.4056,  9.4056,  9.4056, 90.    , 90.    , 90.    ])]
# Rp:2.453 | Rwp:3.141 | Rsquare:0.992
# WPEM 84-th iteration
# [array([ 9.40559,  9.40559,  9.40559, 90.     , 90.     , 90.     ])]
# Rp:2.453 | Rwp:3.140 | Rsquare:0.992
# WPEM 85-th iteration
# [array([ 9.40559,  9.40559,  9.40559, 90.     , 90.     , 90.     ])]
# Rp:2.453 | Rwp:3.140 | Rsquare:0.992
# WPEM 86-th iteration
# [array([ 9.40558,  9.40558,  9.40558, 90.     , 90.     , 90.     ])]
# Rp:2.453 | Rwp:3.139 | Rsquare:0.992
# WPEM 87-th iteration
# [array([ 9.40558,  9.40558,  9.40558, 90.     , 90.     , 90.     ])]
# Rp:2.452 | Rwp:3.139 | Rsquare:0.991
# WPEM 88-th iteration
# [array([ 9.40557,  9.40557,  9.40557, 90.     , 90.     , 90.     ])]
# Rp:2.452 | Rwp:3.139 | Rsquare:0.991
# WPEM 89-th iteration
# [array([ 9.40556,  9.40556,  9.40556, 90.     , 90.     , 90.     ])]
# Rp:2.452 | Rwp:3.138 | Rsquare:0.991
# WPEM 90-th iteration
# [array([ 9.40556,  9.40556,  9.40556, 90.     , 90.     , 90.     ])]
# Rp:2.452 | Rwp:3.138 | Rsquare:0.991
# WPEM 91-th iteration
# [array([ 9.40555,  9.40555,  9.40555, 90.     , 90.     , 90.     ])]
# Rp:2.452 | Rwp:3.138 | Rsquare:0.991
# WPEM 92-th iteration
# [array([ 9.40555,  9.40555,  9.40555, 90.     , 90.     , 90.     ])]
# Rp:2.451 | Rwp:3.138 | Rsquare:0.990
# WPEM 93-th iteration
# [array([ 9.40554,  9.40554,  9.40554, 90.     , 90.     , 90.     ])]
# Rp:2.451 | Rwp:3.137 | Rsquare:0.990
# WPEM 94-th iteration
# [array([ 9.40553,  9.40553,  9.40553, 90.     , 90.     , 90.     ])]
# Rp:2.451 | Rwp:3.137 | Rsquare:0.990
# WPEM 95-th iteration
# [array([ 9.40553,  9.40553,  9.40553, 90.     , 90.     , 90.     ])]
# Rp:2.451 | Rwp:3.137 | Rsquare:0.990
# WPEM 96-th iteration
# [array([ 9.40552,  9.40552,  9.40552, 90.     , 90.     , 90.     ])]
# Rp:2.451 | Rwp:3.137 | Rsquare:0.990
# WPEM 97-th iteration
# [array([ 9.40552,  9.40552,  9.40552, 90.     , 90.     , 90.     ])]
# Rp:2.451 | Rwp:3.137 | Rsquare:0.990
# WPEM 98-th iteration
# [array([ 9.40551,  9.40551,  9.40551, 90.     , 90.     , 90.     ])]
# Rp:2.451 | Rwp:3.136 | Rsquare:0.990
# WPEM 99-th iteration
# [array([ 9.40551,  9.40551,  9.40551, 90.     , 90.     , 90.     ])]
# Rp:2.451 | Rwp:3.136 | Rsquare:0.989
# WPEM 100-th iteration
# [array([ 9.4055,  9.4055,  9.4055, 90.    , 90.    , 90.    ])]
# Rp:2.450 | Rwp:3.136 | Rsquare:0.989
# WPEM 101-th iteration
# [array([ 9.4055,  9.4055,  9.4055, 90.    , 90.    , 90.    ])]
# Rp:2.450 | Rwp:3.136 | Rsquare:0.989
# WPEM 102-th iteration
# [array([ 9.40549,  9.40549,  9.40549, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.136 | Rsquare:0.989
# WPEM 103-th iteration
# [array([ 9.40548,  9.40548,  9.40548, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.136 | Rsquare:0.989
# WPEM 104-th iteration
# [array([ 9.40548,  9.40548,  9.40548, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.989
# WPEM 105-th iteration
# [array([ 9.40547,  9.40547,  9.40547, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.989
# WPEM 106-th iteration
# [array([ 9.40547,  9.40547,  9.40547, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.989
# WPEM 107-th iteration
# [array([ 9.40546,  9.40546,  9.40546, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.989
# WPEM 108-th iteration
# [array([ 9.40546,  9.40546,  9.40546, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.989
# WPEM 109-th iteration
# [array([ 9.40545,  9.40545,  9.40545, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.989
# WPEM 110-th iteration
# [array([ 9.40545,  9.40545,  9.40545, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.989
# WPEM 111-th iteration
# [array([ 9.40544,  9.40544,  9.40544, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.989
# WPEM 112-th iteration
# [array([ 9.40544,  9.40544,  9.40544, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.989
# WPEM 113-th iteration
# [array([ 9.40544,  9.40544,  9.40544, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.990
# WPEM 114-th iteration
# [array([ 9.40543,  9.40543,  9.40543, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.990
# WPEM 115-th iteration
# [array([ 9.40543,  9.40543,  9.40543, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.990
# WPEM 116-th iteration
# [array([ 9.40542,  9.40542,  9.40542, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.990
# WPEM 117-th iteration
# [array([ 9.40542,  9.40542,  9.40542, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.990
# WPEM 118-th iteration
# [array([ 9.40541,  9.40541,  9.40541, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.990
# WPEM 119-th iteration
# [array([ 9.40541,  9.40541,  9.40541, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.990
# WPEM 120-th iteration
# [array([ 9.4054,  9.4054,  9.4054, 90.    , 90.    , 90.    ])]
# Rp:2.450 | Rwp:3.135 | Rsquare:0.991
# WPEM 121-th iteration
# [array([ 9.4073,  9.4073,  9.4073, 90.    , 90.    , 90.    ])]
# Rp:2.516 | Rwp:3.207 | Rsquare:1.124
# WPEM 122-th iteration
# [array([ 9.40661,  9.40661,  9.40661, 90.     , 90.     , 90.     ])]
# Rp:2.462 | Rwp:3.146 | Rsquare:1.016
# WPEM 123-th iteration
# [array([ 9.40625,  9.40625,  9.40625, 90.     , 90.     , 90.     ])]
# Rp:2.450 | Rwp:3.133 | Rsquare:0.992
# WPEM 124-th iteration
# [array([ 9.40606,  9.40606,  9.40606, 90.     , 90.     , 90.     ])]
# Rp:2.447 | Rwp:3.131 | Rsquare:0.988
# WPEM 125-th iteration
# [array([ 9.40595,  9.40595,  9.40595, 90.     , 90.     , 90.     ])]
# Rp:2.447 | Rwp:3.131 | Rsquare:0.988
# WPEM 126-th iteration
# [array([ 9.40783,  9.40783,  9.40783, 90.     , 90.     , 90.     ])]
# Rp:2.523 | Rwp:3.216 | Rsquare:1.136
# After update the background :   Rp = 1.315 | Rwp = 2.504 | Rsquare = 0.696
# volume fraction without structure factor estimate in % : [100.0]
#  Saved at the result documents
# 126-th iterations, reach the limit of lock_num.
#  Rp: 1.315
# Rwp: 2.504
#
#
# WPEM program running time :  0 hours 13 minute  17 second
# '0 hours 13 minute  17 second  '
