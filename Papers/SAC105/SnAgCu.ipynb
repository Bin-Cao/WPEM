# %% [markdown]
# ## 1: background intensity

# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2024-02-15 20:04:31  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'intensity.csv',header=None )
Var = WPEM.BackgroundFit(intensity_csv, LFctg=0.2, lowAngleRange=30, window_length = 7, bac_num=500)
Var
# Out:
# 1.6366634951864674

# %%
latt, AtomCoordinates,_ = WPEM.CIFpreprocess(filepath='betaSn.cif',two_theta_range=(25, 100),cal_extinction=False)
# Out:
# the space group of input crystal is : I 41/a m d :1
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 0 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Tetragonal  |  The initial lattice constants : 5.8317 5.8317 3.1813 90.0 90.0 90.0

# %%
latt
# Out:
# [5.8317, 5.8317, 3.1813, 90.0, 90.0, 90.0]

# %%
latt, AtomCoordinates ,_= WPEM.CIFpreprocess(filepath='Ag3Sn.cif',two_theta_range=(25, 100),)
# Out:
# the space group of input crystal is : P m m n :2
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 12 extinction peaks
# Diffraction condition judgment end !

# %%
latt
# Out:
# [5.968, 4.7802, 5.1843, 90.0, 90.0, 90.0]

# %%
latt, AtomCoordinates,_ = WPEM.CIFpreprocess(filepath='Cu6Sn5.cif',two_theta_range=(25, 99),)
# Out:
# the space group of input crystal is : C 1 2/c 1
# cif file parse completed
# atom locations claculated by wyckoff site
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 383 extinction peaks
# Diffraction condition judgment end !

# %%
latt
# Out:
# [11.036, 7.288, 9.841, 90.0, 98.81, 90.0]

# %%
latt, AtomCoordinates,_  = WPEM.CIFpreprocess(filepath='Ti2Sn3.cif',two_theta_range=(25, 100))
# Out:
# the space group of input crystal is : C m c a
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 230 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Orthorhombic  |  The initial lattice constants : 5.9556 19.964 7.0281 90.0 90.0 90.0

# %%
latt
# Out:
# [5.9556, 19.964, 7.0281, 90.0, 90.0, 90.0]

# %% [markdown]
# ## 2: Wpen fitting

# %%
# The wavelength is set according to the actual light source
wavelength = [1.540593, 1.544414]
Var = 12.9
# Enter the file name to read on the right side of the equal sign. 
# Please remember to quote, string.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "intensity.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  


# Input the initial lattice constants {a, b, c, α, β, γ}, whose values need to be assumed at initialization.

Lattice_constants = [ [5.83, 5.83, 3.181, 90.0, 90.0, 90.0],
                     [5.968, 4.7802, 5.1843, 90.0, 90.0, 90.0,],
                     [11.03, 7.299, 9.841, 90.0, 98.83608, 90.0,],
                    [5.9556, 19.964, 7.0281, 90.0, 90.0, 90.0,]]

# Execute the model
WPEM.XRDfit(
    wavelength, Var, Lattice_constants,no_bac_intensity_file, original_file, bacground_file, 
    subset_number=9 ,low_bound=30,up_bound=90,bta = 0.90,iter_max = 40, asy_C = 0, 
    InitializationEpoch=1,num=5,)
# Out:
# Started at Fri Feb 16 11:38:05 2024
#
# Initialization
# --------------------------------------------------------------------------------
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
# The input HKL document is matched with WPEM
# Diffraction indexs have been obtained by WPEM
#
#
# The input crystal system is: Tetragonal  |  The initial lattice constants : 5.83 5.83 3.181 90.0 90.0 90.0
# The input crystal system is: Orthorhombic  |  The initial lattice constants : 5.968 4.7802 5.1843 90.0 90.0 90.0
# The input crystal system is: Monoclinic  |  The initial lattice constants : 11.03 7.299 9.841 90.0 98.83608 90.0
# The input crystal system is: Orthorhombic  |  The initial lattice constants : 5.9556 19.964 7.0281 90.0 90.0 90.0
# —————————— Initilize the parameters by WPEM ——————————
# Parameter initialization has been completed
#   0%|                                                    | 0/40 [00:00<?, ?it/s]WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 1-th iteration
# [array([ 5.83 ,  5.83 ,  3.181, 90.   , 90.   , 90.   ]), array([ 5.968 ,  4.7802,  5.1843, 90.    , 90.    , 90.    ]), array([11.03   ,  7.299  ,  9.841  , 90.     , 98.83608, 90.     ]), array([ 5.9556, 19.964 ,  7.0281, 90.    , 90.    , 90.    ])]
#   2%|█                                           | 1/40 [01:08<44:22, 68.26s/it]
# Rp:38.032 | Rwp:64.929 | Rsquare:10.232
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 2-th iteration
# [array([ 5.83011,  5.83011,  3.181  , 90.     , 90.     , 90.     ]), array([ 5.96854,  4.78007,  5.18418, 90.     , 90.     , 90.     ]), array([11.03   ,  7.299  ,  9.841  , 90.     , 98.92499, 90.     ]), array([ 5.95899, 19.96171,  7.02633, 90.     , 90.     , 90.     ])]
#   5%|██▏                                         | 2/40 [02:30<48:25, 76.47s/it]
# Rp:33.293 | Rwp:58.413 | Rsquare:6.680
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 3-th iteration
# [array([ 5.82998,  5.82998,  3.18118, 90.     , 90.     , 90.     ]), array([ 5.96853,  4.77997,  5.18397, 90.     , 90.     , 90.     ]), array([11.03004,  7.29893,  9.84087, 90.     , 98.92499, 90.     ]), array([ 5.95916, 19.96204,  7.0263 , 90.     , 90.     , 90.     ])]
#   8%|███▎                                        | 3/40 [04:03<51:52, 84.11s/it]
# Rp:30.425 | Rwp:54.697 | Rsquare:4.934
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 4-th iteration
# [array([ 5.82992,  5.82992,  3.18129, 90.     , 90.     , 90.     ]), array([ 5.96858,  4.77972,  5.18379, 90.     , 90.     , 90.     ]), array([11.02996,  7.29895,  9.84073, 90.     , 98.92499, 90.     ]), array([ 5.95907, 19.96277,  7.02626, 90.     , 90.     , 90.     ])]
#  10%|████▍                                       | 4/40 [05:27<50:25, 84.05s/it]
# Rp:28.930 | Rwp:52.567 | Rsquare:4.180
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 5-th iteration
# [array([ 5.82981,  5.82981,  3.18138, 90.     , 90.     , 90.     ]), array([ 5.96866,  4.77941,  5.18365, 90.     , 90.     , 90.     ]), array([11.02984,  7.29896,  9.84069, 90.     , 98.92499, 90.     ]), array([ 5.95916, 19.96296,  7.02617, 90.     , 90.     , 90.     ])]
#  12%|█████▌                                      | 5/40 [07:02<51:24, 88.12s/it]
# Rp:28.015 | Rwp:51.218 | Rsquare:3.777
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 6-th iteration
# [array([ 5.82981,  5.82981,  3.18137, 90.     , 90.     , 90.     ]), array([ 5.96869,  4.77925,  5.18365, 90.     , 90.     , 90.     ]), array([11.02984,  7.29896,  9.84069, 90.     , 98.92352, 90.     ]), array([ 5.95926, 19.96319,  7.02622, 90.     , 90.     , 90.     ])]
#  15%|██████▌                                     | 6/40 [09:03<56:15, 99.28s/it]
# Rp:27.386 | Rwp:50.273 | Rsquare:3.534
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 7-th iteration
# [array([ 5.82978,  5.82978,  3.18135, 90.     , 90.     , 90.     ]), array([ 5.96877,  4.77922,  5.18355, 90.     , 90.     , 90.     ]), array([11.02984,  7.29896,  9.84069, 90.     , 98.92229, 90.     ]), array([ 5.95932, 19.96319,  7.02628, 90.     , 90.     , 90.     ])]
#  18%|███████▏                                 | 7/40 [11:21<1:01:26, 111.72s/it]
# Rp:26.900 | Rwp:49.543 | Rsquare:3.349
# WARNING:tensorflow:From /Users/jacob/miniconda3/lib/python3.9/site-packages/tensorflow/python/util/deprecation.py:576: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# WPEM 8-th iteration
# [array([ 5.82977,  5.82977,  3.18136, 90.     , 90.     , 90.     ]), array([ 5.96878,  4.7792 ,  5.18352, 90.     , 90.     , 90.     ]), array([11.02988,  7.29895,  9.84076, 90.     , 98.92229, 90.     ]), array([ 5.98853, 20.04657,  7.03696, 90.     , 90.     , 90.     ])]
#  18%|███████▏                                 | 7/40 [12:58<1:01:08, 111.16s/it]
# Rp:29.437 | Rwp:53.848 | Rsquare:4.254
# After update the background :   Rp = 5.595 | Rwp = 27.114 | Rsquare = 1.169
# Mass fraction without structure factor estimate in % : [59.029916324358126, 11.165989445553667, 25.835944446715676, 3.9681497833725445]
#  Saved at the result documents
# 8-th iterations, reach the limit of lock_num.
#  Rp: 5.595
# Rwp: 27.114
#
#
# WPEM program running time :  0 hours 13 minute  27 second
# '0 hours 13 minute  27 second  '

# %%
name = ['βSn','Ag\u2083(Sn,In)','Cu\u2086(Sn,In)\u2085','Ti\u2082Sn\u2083']
wavelength = [1.540593*2/3+ 1.544414*1/3]
WPEM.Plot_Components(lowboundary=10, upboundary=100,name = name, wavelength = wavelength, lifting=[300,200,100,0,400],phase=4,)
# Out:
# Name assigned successfully
# Mass fraction estimate in % (calculated by integral area): [41.50277008155916, 8.455195118136997, 35.83370374324501, 14.208331057058835]
#  Saved at the DecomposedComponents document
